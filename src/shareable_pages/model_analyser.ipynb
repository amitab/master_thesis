# %%
from google.colab import drive 
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Colab\ Notebooks

# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/Colab Notebooks

# %%
# import sys
# sys.path.append("/content/drive/MyDrive/Colab Notebooks")

import tensorflow as tf
import numpy as np

from analyse_model_weights import analyse_model_weights
from analyse_models import analyse_models, analyse_models_v2, analyse_models_v2_and_dedup
from analyse_weights import analyse_weights

# %%
vgg16 = tf.keras.applications.VGG16()
vgg19 = tf.keras.applications.VGG19()

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        500,
        500,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Splitting model layers with size > 16 MB into blocks of size 500 X 500 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 69.78it/s]
# Splitting model into blocks:  81%|████████  | 21/26 [00:00<00:00, 204.45it/s]
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 38.99it/s]
# Dedup S1:   0%|          | 0/648 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1: 100%|██████████| 648/648 [03:46<00:00,  2.87it/s]
# Dedup S2: 100%|██████████| 684/684 [04:07<00:00,  2.76it/s]
# Dedup S1 and S2: 100%|██████████| 648/648 [07:48<00:00,  1.38it/s]
# Gathering results: 100%|██████████| 2/2 [00:00<00:00,  7.33it/s]
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (1323 / 1332) | Bytes (2646000000 / 2592000000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_500_500/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_500_500/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:18<01:34, 18.92s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (1245 / 1332) | Bytes (2490000000 / 2592000000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_500_500/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_500_500/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:36<01:14, 18.61s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (1207 / 1332) | Bytes (2414000000 / 2592000000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_500_500/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_500_500/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:57<00:57, 19.17s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (274 / 1332) | Bytes (548000000 / 2592000000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_500_500/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_500_500/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:19<00:40, 20.05s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (273 / 1332) | Bytes (546000000 / 2592000000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_500_500/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_500_500/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:39<00:20, 20.06s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (15 / 1332) | Bytes (30000000 / 2592000000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_500_500/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_500_500/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:59<00:00, 19.92s/it]
# None

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        600,
        600,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Splitting model layers with size > 16 MB into blocks of size 600 X 600 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 61.34it/s]
#
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
# Splitting model into blocks:  73%|███████▎  | 19/26 [00:00<00:00, 175.94it/s]
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 54.69it/s]
#
# Dedup S1:   0%|          | 0/397 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1:   0%|          | 1/397 [00:00<05:28,  1.20it/s]
# Dedup S1:   1%|          | 2/397 [00:01<05:23,  1.22it/s]
# Dedup S1:   1%|          | 3/397 [00:02<05:20,  1.23it/s]
# Dedup S1:   1%|          | 4/397 [00:03<06:05,  1.07it/s]
# Dedup S1:   1%|▏         | 5/397 [00:05<06:58,  1.07s/it]
# Dedup S1:   2%|▏         | 6/397 [00:06<07:26,  1.14s/it]
# Dedup S1:   2%|▏         | 7/397 [00:07<07:29,  1.15s/it]
# Dedup S1:   2%|▏         | 8/397 [00:08<07:31,  1.16s/it]
# Dedup S1:   2%|▏         | 9/397 [00:09<06:44,  1.04s/it]
# Dedup S1:   3%|▎         | 10/397 [00:10<06:14,  1.03it/s]
# Dedup S1:   3%|▎         | 11/397 [00:11<06:22,  1.01it/s]
# Dedup S1:   3%|▎         | 12/397 [00:12<06:46,  1.06s/it]
# Dedup S1:   3%|▎         | 13/397 [00:13<06:54,  1.08s/it]
# Dedup S1:   4%|▎         | 14/397 [00:14<07:09,  1.12s/it]
# Dedup S1:   4%|▍         | 15/397 [00:15<06:58,  1.10s/it]
# Dedup S1:   4%|▍         | 16/397 [00:16<06:52,  1.08s/it]
# Dedup S1:   4%|▍         | 17/397 [00:17<06:04,  1.04it/s]
# Dedup S1:   5%|▍         | 18/397 [00:18<05:31,  1.14it/s]
# Dedup S1:   5%|▍         | 19/397 [00:18<05:06,  1.23it/s]
# Dedup S1:   5%|▌         | 20/397 [00:19<05:27,  1.15it/s]
# Dedup S1:   5%|▌         | 21/397 [00:20<05:41,  1.10it/s]
# Dedup S1:   6%|▌         | 22/397 [00:21<05:48,  1.08it/s]
# Dedup S1:   6%|▌         | 23/397 [00:22<05:54,  1.05it/s]
# Dedup S1:   6%|▌         | 24/397 [00:23<05:58,  1.04it/s]
# Dedup S1:   6%|▋         | 25/397 [00:24<05:24,  1.15it/s]
# Dedup S1:   7%|▋         | 26/397 [00:25<05:03,  1.22it/s]
# Dedup S1:   7%|▋         | 27/397 [00:25<04:45,  1.30it/s]
# Dedup S1:   7%|▋         | 28/397 [00:27<05:20,  1.15it/s]
# Dedup S1:   7%|▋         | 29/397 [00:28<05:39,  1.08it/s]
# Dedup S1:   8%|▊         | 30/397 [00:29<05:52,  1.04it/s]
# Dedup S1:   8%|▊         | 31/397 [00:30<05:57,  1.02it/s]
# Dedup S1:   8%|▊         | 32/397 [00:31<05:59,  1.02it/s]
# Dedup S1:   8%|▊         | 33/397 [00:31<05:19,  1.14it/s]
# Dedup S1:   9%|▊         | 34/397 [00:32<04:52,  1.24it/s]
# Dedup S1:   9%|▉         | 35/397 [00:33<04:28,  1.35it/s]
# Dedup S1:   9%|▉         | 36/397 [00:33<04:50,  1.24it/s]
# Dedup S1:   9%|▉         | 37/397 [00:34<05:07,  1.17it/s]
# Dedup S1:  10%|▉         | 38/397 [00:35<05:17,  1.13it/s]
# Dedup S1:  10%|▉         | 39/397 [00:36<05:23,  1.11it/s]
# Dedup S1:  10%|█         | 40/397 [00:37<05:28,  1.09it/s]
# Dedup S1:  10%|█         | 41/397 [00:38<04:56,  1.20it/s]
# Dedup S1:  11%|█         | 42/397 [00:39<04:31,  1.31it/s]
# Dedup S1:  11%|█         | 43/397 [00:39<04:15,  1.38it/s]
# Dedup S1:  11%|█         | 44/397 [00:40<04:04,  1.44it/s]
# Dedup S1:  11%|█▏        | 45/397 [00:40<03:54,  1.50it/s]
# Dedup S1:  12%|█▏        | 46/397 [00:41<03:51,  1.51it/s]
# Dedup S1:  12%|█▏        | 47/397 [00:42<04:25,  1.32it/s]
# Dedup S1:  12%|█▏        | 48/397 [00:43<04:06,  1.41it/s]
# Dedup S1:  12%|█▏        | 49/397 [00:43<03:55,  1.48it/s]
# Dedup S1:  13%|█▎        | 50/397 [00:44<03:48,  1.52it/s]
# Dedup S1:  13%|█▎        | 51/397 [00:44<03:44,  1.54it/s]
# Dedup S1:  13%|█▎        | 52/397 [00:45<03:37,  1.59it/s]
# Dedup S1:  13%|█▎        | 53/397 [00:46<03:35,  1.60it/s]
# Dedup S1:  14%|█▎        | 54/397 [00:47<04:06,  1.39it/s]
# Dedup S1:  14%|█▍        | 55/397 [00:47<03:52,  1.47it/s]
# Dedup S1:  14%|█▍        | 56/397 [00:48<03:42,  1.53it/s]
# Dedup S1:  14%|█▍        | 57/397 [00:48<03:39,  1.55it/s]
# Dedup S1:  15%|█▍        | 58/397 [00:49<03:35,  1.58it/s]
# Dedup S1:  15%|█▍        | 59/397 [00:50<03:29,  1.61it/s]
# Dedup S1:  15%|█▌        | 60/397 [00:50<03:28,  1.62it/s]
# Dedup S1:  15%|█▌        | 61/397 [00:51<03:59,  1.40it/s]
# Dedup S1:  16%|█▌        | 62/397 [00:52<03:45,  1.49it/s]
# Dedup S1:  16%|█▌        | 63/397 [00:52<03:35,  1.55it/s]
# Dedup S1:  16%|█▌        | 64/397 [00:53<03:25,  1.62it/s]
# Dedup S1:  16%|█▋        | 65/397 [00:53<03:22,  1.64it/s]
# Dedup S1:  17%|█▋        | 66/397 [00:54<03:18,  1.67it/s]
# Dedup S1:  17%|█▋        | 67/397 [00:55<03:14,  1.69it/s]
# Dedup S1:  17%|█▋        | 68/397 [00:55<03:44,  1.46it/s]
# Dedup S1:  17%|█▋        | 69/397 [00:56<03:34,  1.53it/s]
# Dedup S1:  18%|█▊        | 70/397 [00:57<03:28,  1.57it/s]
# Dedup S1:  18%|█▊        | 71/397 [00:57<03:23,  1.60it/s]
# Dedup S1:  18%|█▊        | 72/397 [00:58<03:18,  1.64it/s]
# Dedup S1:  18%|█▊        | 73/397 [00:59<03:36,  1.50it/s]
# Dedup S1:  19%|█▊        | 74/397 [00:59<03:32,  1.52it/s]
# Dedup S1:  19%|█▉        | 75/397 [01:00<03:54,  1.37it/s]
# Dedup S1:  19%|█▉        | 76/397 [01:01<03:37,  1.48it/s]
# Dedup S1:  19%|█▉        | 77/397 [01:01<03:24,  1.56it/s]
# Dedup S1:  20%|█▉        | 78/397 [01:02<03:16,  1.63it/s]
# Dedup S1:  20%|█▉        | 79/397 [01:02<03:10,  1.67it/s]
# Dedup S1:  20%|██        | 80/397 [01:03<03:05,  1.71it/s]
# Dedup S1:  20%|██        | 81/397 [01:04<03:02,  1.73it/s]
# Dedup S1:  21%|██        | 82/397 [01:04<03:28,  1.51it/s]
# Dedup S1:  21%|██        | 83/397 [01:05<03:17,  1.59it/s]
# Dedup S1:  21%|██        | 84/397 [01:05<03:08,  1.66it/s]
# Dedup S1:  21%|██▏       | 85/397 [01:06<03:01,  1.72it/s]
# Dedup S1:  22%|██▏       | 86/397 [01:07<02:57,  1.75it/s]
# Dedup S1:  22%|██▏       | 87/397 [01:07<02:54,  1.78it/s]
# Dedup S1:  22%|██▏       | 88/397 [01:08<02:50,  1.81it/s]
# Dedup S1:  22%|██▏       | 89/397 [01:08<03:12,  1.60it/s]
# Dedup S1:  23%|██▎       | 90/397 [01:09<03:05,  1.66it/s]
# Dedup S1:  23%|██▎       | 91/397 [01:10<02:58,  1.71it/s]
# Dedup S1:  23%|██▎       | 92/397 [01:10<02:52,  1.77it/s]
# Dedup S1:  23%|██▎       | 93/397 [01:11<02:49,  1.79it/s]
# Dedup S1:  24%|██▎       | 94/397 [01:11<02:48,  1.80it/s]
# Dedup S1:  24%|██▍       | 95/397 [01:12<02:46,  1.81it/s]
# Dedup S1:  24%|██▍       | 96/397 [01:12<03:10,  1.58it/s]
# Dedup S1:  24%|██▍       | 97/397 [01:13<02:58,  1.68it/s]
# Dedup S1:  25%|██▍       | 98/397 [01:14<02:50,  1.76it/s]
# Dedup S1:  25%|██▍       | 99/397 [01:14<02:43,  1.83it/s]
# Dedup S1:  25%|██▌       | 100/397 [01:15<02:39,  1.86it/s]
# Dedup S1:  25%|██▌       | 101/397 [01:15<02:36,  1.89it/s]
# Dedup S1:  26%|██▌       | 102/397 [01:16<02:37,  1.88it/s]
# Dedup S1:  26%|██▌       | 103/397 [01:16<03:00,  1.63it/s]
# Dedup S1:  26%|██▌       | 104/397 [01:17<02:52,  1.69it/s]
# Dedup S1:  26%|██▋       | 105/397 [01:17<02:46,  1.76it/s]
# Dedup S1:  27%|██▋       | 106/397 [01:18<02:38,  1.83it/s]
# Dedup S1:  27%|██▋       | 107/397 [01:18<02:34,  1.88it/s]
# Dedup S1:  27%|██▋       | 108/397 [01:19<02:31,  1.91it/s]
# Dedup S1:  27%|██▋       | 109/397 [01:19<02:29,  1.93it/s]
# Dedup S1:  28%|██▊       | 110/397 [01:20<02:50,  1.68it/s]
# Dedup S1:  28%|██▊       | 111/397 [01:21<02:42,  1.77it/s]
# Dedup S1:  28%|██▊       | 112/397 [01:21<02:35,  1.84it/s]
# Dedup S1:  28%|██▊       | 113/397 [01:22<02:30,  1.89it/s]
# Dedup S1:  29%|██▊       | 114/397 [01:22<02:28,  1.91it/s]
# Dedup S1:  29%|██▉       | 115/397 [01:23<02:25,  1.94it/s]
# Dedup S1:  29%|██▉       | 116/397 [01:23<02:23,  1.96it/s]
# Dedup S1:  29%|██▉       | 117/397 [01:24<02:47,  1.67it/s]
# Dedup S1:  30%|██▉       | 118/397 [01:24<02:38,  1.76it/s]
# Dedup S1:  30%|██▉       | 119/397 [01:25<02:31,  1.84it/s]
# Dedup S1:  30%|███       | 120/397 [01:25<02:26,  1.89it/s]
# Dedup S1:  30%|███       | 121/397 [01:26<02:24,  1.92it/s]
# Dedup S1:  31%|███       | 122/397 [01:26<02:20,  1.96it/s]
# Dedup S1:  31%|███       | 123/397 [01:27<02:19,  1.96it/s]
# Dedup S1:  31%|███       | 124/397 [01:28<02:39,  1.71it/s]
# Dedup S1:  31%|███▏      | 125/397 [01:28<02:30,  1.81it/s]
# Dedup S1:  32%|███▏      | 126/397 [01:29<02:25,  1.87it/s]
# Dedup S1:  32%|███▏      | 127/397 [01:29<02:18,  1.95it/s]
# Dedup S1:  32%|███▏      | 128/397 [01:30<02:14,  2.00it/s]
# Dedup S1:  32%|███▏      | 129/397 [01:30<02:12,  2.03it/s]
# Dedup S1:  33%|███▎      | 130/397 [01:31<02:09,  2.05it/s]
# Dedup S1:  33%|███▎      | 131/397 [01:31<02:26,  1.81it/s]
# Dedup S1:  33%|███▎      | 132/397 [01:32<02:19,  1.90it/s]
# Dedup S1:  34%|███▎      | 133/397 [01:32<02:12,  1.99it/s]
# Dedup S1:  34%|███▍      | 134/397 [01:33<02:07,  2.06it/s]
# Dedup S1:  34%|███▍      | 135/397 [01:33<02:04,  2.10it/s]
# Dedup S1:  34%|███▍      | 136/397 [01:34<02:02,  2.13it/s]
# Dedup S1:  35%|███▍      | 137/397 [01:34<02:02,  2.12it/s]
# Dedup S1:  35%|███▍      | 138/397 [01:35<02:19,  1.86it/s]
# Dedup S1:  35%|███▌      | 139/397 [01:35<02:12,  1.95it/s]
# Dedup S1:  35%|███▌      | 140/397 [01:36<02:08,  2.00it/s]
# Dedup S1:  36%|███▌      | 141/397 [01:36<02:05,  2.04it/s]
# Dedup S1:  36%|███▌      | 142/397 [01:37<02:02,  2.08it/s]
# Dedup S1:  36%|███▌      | 143/397 [01:37<02:00,  2.10it/s]
# Dedup S1:  36%|███▋      | 144/397 [01:38<01:59,  2.11it/s]
# Dedup S1:  37%|███▋      | 145/397 [01:38<02:19,  1.80it/s]
# Dedup S1:  37%|███▋      | 146/397 [01:39<02:13,  1.88it/s]
# Dedup S1:  37%|███▋      | 147/397 [01:39<02:10,  1.92it/s]
# Dedup S1:  37%|███▋      | 148/397 [01:40<02:05,  1.98it/s]
# Dedup S1:  38%|███▊      | 149/397 [01:40<02:03,  2.00it/s]
# Dedup S1:  38%|███▊      | 150/397 [01:41<02:01,  2.04it/s]
# Dedup S1:  38%|███▊      | 151/397 [01:41<01:59,  2.05it/s]
# Dedup S1:  38%|███▊      | 152/397 [01:42<02:17,  1.79it/s]
# Dedup S1:  39%|███▊      | 153/397 [01:42<02:08,  1.90it/s]
# Dedup S1:  39%|███▉      | 154/397 [01:43<02:02,  1.99it/s]
# Dedup S1:  39%|███▉      | 155/397 [01:43<01:57,  2.05it/s]
# Dedup S1:  39%|███▉      | 156/397 [01:44<01:54,  2.10it/s]
# Dedup S1:  40%|███▉      | 157/397 [01:44<01:51,  2.15it/s]
# Dedup S1:  40%|███▉      | 158/397 [01:45<01:48,  2.20it/s]
# Dedup S1:  40%|████      | 159/397 [01:45<02:01,  1.95it/s]
# Dedup S1:  40%|████      | 160/397 [01:46<01:55,  2.06it/s]
# Dedup S1:  41%|████      | 161/397 [01:46<01:52,  2.09it/s]
# Dedup S1:  41%|████      | 162/397 [01:46<01:48,  2.17it/s]
# Dedup S1:  41%|████      | 163/397 [01:47<01:45,  2.21it/s]
# Dedup S1:  41%|████▏     | 164/397 [01:47<01:43,  2.25it/s]
# Dedup S1:  42%|████▏     | 165/397 [01:48<01:41,  2.29it/s]
# Dedup S1:  42%|████▏     | 166/397 [01:48<01:55,  2.00it/s]
# Dedup S1:  42%|████▏     | 167/397 [01:49<01:49,  2.10it/s]
# Dedup S1:  42%|████▏     | 168/397 [01:49<01:44,  2.20it/s]
# Dedup S1:  43%|████▎     | 169/397 [01:50<01:41,  2.25it/s]
# Dedup S1:  43%|████▎     | 170/397 [01:50<01:39,  2.27it/s]
# Dedup S1:  43%|████▎     | 171/397 [01:50<01:37,  2.31it/s]
# Dedup S1:  43%|████▎     | 172/397 [01:51<01:35,  2.35it/s]
# Dedup S1:  44%|████▎     | 173/397 [01:52<01:46,  2.10it/s]
# Dedup S1:  44%|████▍     | 174/397 [01:52<01:40,  2.22it/s]
# Dedup S1:  44%|████▍     | 175/397 [01:52<01:36,  2.31it/s]
# Dedup S1:  44%|████▍     | 176/397 [01:53<01:32,  2.38it/s]
# Dedup S1:  45%|████▍     | 177/397 [01:53<01:30,  2.42it/s]
# Dedup S1:  45%|████▍     | 178/397 [01:53<01:28,  2.48it/s]
# Dedup S1:  45%|████▌     | 179/397 [01:54<01:28,  2.47it/s]
# Dedup S1:  45%|████▌     | 180/397 [01:54<01:41,  2.13it/s]
# Dedup S1:  46%|████▌     | 181/397 [01:55<01:36,  2.24it/s]
# Dedup S1:  46%|████▌     | 182/397 [01:55<01:32,  2.31it/s]
# Dedup S1:  46%|████▌     | 183/397 [01:56<01:28,  2.40it/s]
# Dedup S1:  46%|████▋     | 184/397 [01:56<01:27,  2.43it/s]
# Dedup S1:  47%|████▋     | 185/397 [01:56<01:26,  2.46it/s]
# Dedup S1:  47%|████▋     | 186/397 [01:57<01:24,  2.49it/s]
# Dedup S1:  47%|████▋     | 187/397 [01:57<01:38,  2.13it/s]
# Dedup S1:  47%|████▋     | 188/397 [01:58<01:33,  2.23it/s]
# Dedup S1:  48%|████▊     | 189/397 [01:58<01:30,  2.29it/s]
# Dedup S1:  48%|████▊     | 190/397 [01:59<01:27,  2.35it/s]
# Dedup S1:  48%|████▊     | 191/397 [01:59<01:24,  2.45it/s]
# Dedup S1:  48%|████▊     | 192/397 [01:59<01:22,  2.50it/s]
# Dedup S1:  49%|████▊     | 193/397 [02:00<01:20,  2.54it/s]
# Dedup S1:  49%|████▉     | 194/397 [02:00<01:29,  2.27it/s]
# Dedup S1:  49%|████▉     | 195/397 [02:01<01:24,  2.38it/s]
# Dedup S1:  49%|████▉     | 196/397 [02:01<01:21,  2.47it/s]
# Dedup S1:  50%|████▉     | 197/397 [02:01<01:19,  2.50it/s]
# Dedup S1:  50%|████▉     | 198/397 [02:02<01:17,  2.57it/s]
# Dedup S1:  50%|█████     | 199/397 [02:02<01:15,  2.63it/s]
# Dedup S1:  50%|█████     | 200/397 [02:03<01:14,  2.66it/s]
# Dedup S1:  51%|█████     | 201/397 [02:03<01:21,  2.41it/s]
# Dedup S1:  51%|█████     | 202/397 [02:03<01:17,  2.52it/s]
# Dedup S1:  51%|█████     | 203/397 [02:04<01:14,  2.60it/s]
# Dedup S1:  51%|█████▏    | 204/397 [02:04<01:11,  2.70it/s]
# Dedup S1:  52%|█████▏    | 205/397 [02:04<01:10,  2.72it/s]
# Dedup S1:  52%|█████▏    | 206/397 [02:05<01:09,  2.75it/s]
# Dedup S1:  52%|█████▏    | 207/397 [02:05<01:08,  2.79it/s]
# Dedup S1:  52%|█████▏    | 208/397 [02:06<01:16,  2.47it/s]
# Dedup S1:  53%|█████▎    | 209/397 [02:06<01:12,  2.59it/s]
# Dedup S1:  53%|█████▎    | 210/397 [02:06<01:10,  2.67it/s]
# Dedup S1:  53%|█████▎    | 211/397 [02:07<01:07,  2.76it/s]
# Dedup S1:  53%|█████▎    | 212/397 [02:07<01:04,  2.85it/s]
# Dedup S1:  54%|█████▎    | 213/397 [02:07<01:04,  2.87it/s]
# Dedup S1:  54%|█████▍    | 214/397 [02:08<01:02,  2.91it/s]
# Dedup S1:  54%|█████▍    | 215/397 [02:08<01:10,  2.60it/s]
# Dedup S1:  54%|█████▍    | 216/397 [02:09<01:06,  2.72it/s]
# Dedup S1:  55%|█████▍    | 217/397 [02:09<01:05,  2.76it/s]
# Dedup S1:  55%|█████▍    | 218/397 [02:09<01:03,  2.84it/s]
# Dedup S1:  55%|█████▌    | 219/397 [02:10<01:01,  2.87it/s]
# Dedup S1:  55%|█████▌    | 220/397 [02:10<01:00,  2.94it/s]
# Dedup S1:  56%|█████▌    | 221/397 [02:10<00:59,  2.98it/s]
# Dedup S1:  56%|█████▌    | 222/397 [02:11<01:06,  2.62it/s]
# Dedup S1:  56%|█████▌    | 223/397 [02:11<01:03,  2.75it/s]
# Dedup S1:  56%|█████▋    | 224/397 [02:11<01:01,  2.83it/s]
# Dedup S1:  57%|█████▋    | 225/397 [02:12<00:59,  2.87it/s]
# Dedup S1:  57%|█████▋    | 226/397 [02:12<00:57,  2.95it/s]
# Dedup S1:  57%|█████▋    | 227/397 [02:12<00:56,  3.02it/s]
# Dedup S1:  57%|█████▋    | 228/397 [02:13<00:56,  3.00it/s]
# Dedup S1:  58%|█████▊    | 229/397 [02:13<01:02,  2.69it/s]
# Dedup S1:  58%|█████▊    | 230/397 [02:13<00:59,  2.82it/s]
# Dedup S1:  58%|█████▊    | 231/397 [02:14<00:56,  2.93it/s]
# Dedup S1:  58%|█████▊    | 232/397 [02:14<00:54,  3.04it/s]
# Dedup S1:  59%|█████▊    | 233/397 [02:14<00:52,  3.10it/s]
# Dedup S1:  59%|█████▉    | 234/397 [02:15<00:51,  3.14it/s]
# Dedup S1:  59%|█████▉    | 235/397 [02:15<00:50,  3.20it/s]
# Dedup S1:  59%|█████▉    | 236/397 [02:15<00:56,  2.86it/s]
# Dedup S1:  60%|█████▉    | 237/397 [02:16<00:54,  2.92it/s]
# Dedup S1:  60%|█████▉    | 238/397 [02:16<00:52,  3.05it/s]
# Dedup S1:  60%|██████    | 239/397 [02:16<00:50,  3.15it/s]
# Dedup S1:  60%|██████    | 240/397 [02:17<00:49,  3.17it/s]
# Dedup S1:  61%|██████    | 241/397 [02:17<00:48,  3.25it/s]
# Dedup S1:  61%|██████    | 242/397 [02:17<00:47,  3.29it/s]
# Dedup S1:  61%|██████    | 243/397 [02:18<00:53,  2.90it/s]
# Dedup S1:  61%|██████▏   | 244/397 [02:18<00:50,  3.03it/s]
# Dedup S1:  62%|██████▏   | 245/397 [02:18<00:48,  3.14it/s]
# Dedup S1:  62%|██████▏   | 246/397 [02:19<00:47,  3.20it/s]
# Dedup S1:  62%|██████▏   | 247/397 [02:19<00:46,  3.25it/s]
# Dedup S1:  62%|██████▏   | 248/397 [02:19<00:44,  3.32it/s]
# Dedup S1:  63%|██████▎   | 249/397 [02:19<00:43,  3.38it/s]
# Dedup S1:  63%|██████▎   | 250/397 [02:20<00:49,  2.98it/s]
# Dedup S1:  63%|██████▎   | 251/397 [02:20<00:46,  3.13it/s]
# Dedup S1:  63%|██████▎   | 252/397 [02:20<00:44,  3.26it/s]
# Dedup S1:  64%|██████▎   | 253/397 [02:21<00:43,  3.33it/s]
# Dedup S1:  64%|██████▍   | 254/397 [02:21<00:42,  3.36it/s]
# Dedup S1:  64%|██████▍   | 255/397 [02:21<00:41,  3.46it/s]
# Dedup S1:  64%|██████▍   | 256/397 [02:21<00:40,  3.52it/s]
# Dedup S1:  65%|██████▍   | 257/397 [02:22<00:44,  3.18it/s]
# Dedup S1:  65%|██████▍   | 258/397 [02:22<00:41,  3.35it/s]
# Dedup S1:  65%|██████▌   | 259/397 [02:22<00:40,  3.42it/s]
# Dedup S1:  65%|██████▌   | 260/397 [02:23<00:39,  3.47it/s]
# Dedup S1:  66%|██████▌   | 261/397 [02:23<00:38,  3.53it/s]
# Dedup S1:  66%|██████▌   | 262/397 [02:23<00:37,  3.64it/s]
# Dedup S1:  66%|██████▌   | 263/397 [02:23<00:36,  3.68it/s]
# Dedup S1:  66%|██████▋   | 264/397 [02:24<00:39,  3.33it/s]
# Dedup S1:  67%|██████▋   | 265/397 [02:24<00:38,  3.41it/s]
# Dedup S1:  67%|██████▋   | 266/397 [02:24<00:36,  3.55it/s]
# Dedup S1:  67%|██████▋   | 267/397 [02:25<00:35,  3.64it/s]
# Dedup S1:  68%|██████▊   | 268/397 [02:25<00:35,  3.68it/s]
# Dedup S1:  68%|██████▊   | 269/397 [02:25<00:33,  3.78it/s]
# Dedup S1:  68%|██████▊   | 270/397 [02:25<00:33,  3.81it/s]
# Dedup S1:  68%|██████▊   | 271/397 [02:26<00:37,  3.39it/s]
# Dedup S1:  69%|██████▊   | 272/397 [02:26<00:34,  3.59it/s]
# Dedup S1:  69%|██████▉   | 273/397 [02:26<00:33,  3.71it/s]
# Dedup S1:  69%|██████▉   | 274/397 [02:27<00:32,  3.81it/s]
# Dedup S1:  69%|██████▉   | 275/397 [02:27<00:32,  3.77it/s]
# Dedup S1:  70%|██████▉   | 276/397 [02:27<00:31,  3.89it/s]
# Dedup S1:  70%|██████▉   | 277/397 [02:27<00:30,  4.00it/s]
# Dedup S1:  70%|███████   | 278/397 [02:28<00:32,  3.70it/s]
# Dedup S1:  70%|███████   | 279/397 [02:28<00:30,  3.82it/s]
# Dedup S1:  71%|███████   | 280/397 [02:28<00:30,  3.87it/s]
# Dedup S1:  71%|███████   | 281/397 [02:28<00:29,  3.97it/s]
# Dedup S1:  71%|███████   | 282/397 [02:29<00:28,  4.02it/s]
# Dedup S1:  71%|███████▏  | 283/397 [02:29<00:27,  4.12it/s]
# Dedup S1:  72%|███████▏  | 284/397 [02:29<00:26,  4.21it/s]
# Dedup S1:  72%|███████▏  | 285/397 [02:29<00:28,  3.97it/s]
# Dedup S1:  72%|███████▏  | 286/397 [02:29<00:26,  4.17it/s]
# Dedup S1:  72%|███████▏  | 287/397 [02:30<00:25,  4.29it/s]
# Dedup S1:  73%|███████▎  | 288/397 [02:30<00:24,  4.41it/s]
# Dedup S1:  73%|███████▎  | 289/397 [02:30<00:24,  4.46it/s]
# Dedup S1:  73%|███████▎  | 290/397 [02:30<00:24,  4.35it/s]
# Dedup S1:  73%|███████▎  | 291/397 [02:31<00:24,  4.30it/s]
# Dedup S1:  74%|███████▎  | 292/397 [02:31<00:26,  4.02it/s]
# Dedup S1:  74%|███████▍  | 293/397 [02:31<00:24,  4.20it/s]
# Dedup S1:  74%|███████▍  | 294/397 [02:31<00:23,  4.36it/s]
# Dedup S1:  74%|███████▍  | 295/397 [02:32<00:22,  4.52it/s]
# Dedup S1:  75%|███████▍  | 296/397 [02:32<00:22,  4.55it/s]
# Dedup S1:  75%|███████▍  | 297/397 [02:32<00:21,  4.66it/s]
# Dedup S1:  75%|███████▌  | 298/397 [02:32<00:20,  4.78it/s]
# Dedup S1:  75%|███████▌  | 299/397 [02:32<00:21,  4.47it/s]
# Dedup S1:  76%|███████▌  | 300/397 [02:33<00:20,  4.66it/s]
# Dedup S1:  76%|███████▌  | 301/397 [02:33<00:20,  4.67it/s]
# Dedup S1:  76%|███████▌  | 302/397 [02:33<00:19,  4.85it/s]
# Dedup S1:  76%|███████▋  | 303/397 [02:33<00:19,  4.93it/s]
# Dedup S1:  77%|███████▋  | 304/397 [02:33<00:18,  4.97it/s]
# Dedup S1:  77%|███████▋  | 305/397 [02:34<00:18,  4.98it/s]
# Dedup S1:  77%|███████▋  | 306/397 [02:34<00:19,  4.60it/s]
# Dedup S1:  77%|███████▋  | 307/397 [02:34<00:18,  4.80it/s]
# Dedup S1:  78%|███████▊  | 308/397 [02:34<00:17,  5.00it/s]
# Dedup S1:  78%|███████▊  | 309/397 [02:34<00:17,  5.13it/s]
# Dedup S1:  78%|███████▊  | 310/397 [02:35<00:16,  5.21it/s]
# Dedup S1:  78%|███████▊  | 311/397 [02:35<00:16,  5.27it/s]
# Dedup S1:  79%|███████▊  | 312/397 [02:35<00:15,  5.33it/s]
# Dedup S1:  79%|███████▉  | 313/397 [02:35<00:16,  4.98it/s]
# Dedup S1:  79%|███████▉  | 314/397 [02:35<00:16,  5.19it/s]
# Dedup S1:  79%|███████▉  | 315/397 [02:36<00:15,  5.26it/s]
# Dedup S1:  80%|███████▉  | 316/397 [02:36<00:14,  5.40it/s]
# Dedup S1:  80%|███████▉  | 317/397 [02:36<00:14,  5.43it/s]
# Dedup S1:  80%|████████  | 318/397 [02:36<00:14,  5.61it/s]
# Dedup S1:  80%|████████  | 319/397 [02:36<00:13,  5.68it/s]
# Dedup S1:  81%|████████  | 320/397 [02:36<00:14,  5.32it/s]
# Dedup S1:  81%|████████  | 321/397 [02:37<00:13,  5.54it/s]
# Dedup S1:  81%|████████  | 322/397 [02:37<00:13,  5.66it/s]
# Dedup S1:  81%|████████▏ | 323/397 [02:37<00:12,  5.88it/s]
# Dedup S1:  82%|████████▏ | 324/397 [02:37<00:12,  5.96it/s]
# Dedup S1:  82%|████████▏ | 325/397 [02:37<00:11,  6.21it/s]
# Dedup S1:  82%|████████▏ | 326/397 [02:37<00:11,  6.28it/s]
# Dedup S1:  82%|████████▏ | 327/397 [02:38<00:11,  5.96it/s]
# Dedup S1:  83%|████████▎ | 328/397 [02:38<00:12,  5.74it/s]
# Dedup S1:  83%|████████▎ | 329/397 [02:38<00:12,  5.56it/s]
# Dedup S1:  83%|████████▎ | 330/397 [02:38<00:11,  5.61it/s]
# Dedup S1:  83%|████████▎ | 331/397 [02:38<00:11,  5.55it/s]
# Dedup S1:  84%|████████▎ | 332/397 [02:39<00:11,  5.48it/s]
# Dedup S1:  84%|████████▍ | 333/397 [02:39<00:11,  5.36it/s]
# Dedup S1:  84%|████████▍ | 334/397 [02:39<00:11,  5.28it/s]
# Dedup S1:  84%|████████▍ | 335/397 [02:39<00:10,  5.69it/s]
# Dedup S1:  85%|████████▍ | 336/397 [02:39<00:09,  6.16it/s]
# Dedup S1:  85%|████████▍ | 337/397 [02:39<00:09,  6.48it/s]
# Dedup S1:  85%|████████▌ | 338/397 [02:39<00:08,  6.73it/s]
# Dedup S1:  85%|████████▌ | 339/397 [02:40<00:08,  7.04it/s]
# Dedup S1:  86%|████████▌ | 340/397 [02:40<00:07,  7.19it/s]
# Dedup S1:  86%|████████▌ | 341/397 [02:40<00:08,  6.75it/s]
# Dedup S1:  86%|████████▌ | 342/397 [02:40<00:07,  7.02it/s]
# Dedup S1:  86%|████████▋ | 343/397 [02:40<00:07,  7.38it/s]
# Dedup S1:  87%|████████▋ | 344/397 [02:40<00:07,  7.54it/s]
# Dedup S1:  87%|████████▋ | 345/397 [02:40<00:06,  7.64it/s]
# Dedup S1:  87%|████████▋ | 346/397 [02:40<00:06,  7.83it/s]
# Dedup S1:  87%|████████▋ | 347/397 [02:41<00:06,  7.90it/s]
# Dedup S1:  88%|████████▊ | 348/397 [02:41<00:06,  7.68it/s]
# Dedup S1:  88%|████████▊ | 349/397 [02:41<00:06,  7.85it/s]
# Dedup S1:  88%|████████▊ | 350/397 [02:41<00:05,  8.04it/s]
# Dedup S1:  88%|████████▊ | 351/397 [02:41<00:05,  8.36it/s]
# Dedup S1:  89%|████████▊ | 352/397 [02:41<00:05,  8.01it/s]
# Dedup S1:  89%|████████▉ | 353/397 [02:41<00:05,  8.35it/s]
# Dedup S1:  89%|████████▉ | 354/397 [02:41<00:05,  8.52it/s]
# Dedup S1:  89%|████████▉ | 355/397 [02:42<00:05,  8.26it/s]
# Dedup S1:  90%|████████▉ | 356/397 [02:42<00:04,  8.60it/s]
# Dedup S1:  90%|████████▉ | 357/397 [02:42<00:04,  8.77it/s]
# Dedup S1:  90%|█████████ | 358/397 [02:42<00:04,  8.73it/s]
# Dedup S1:  91%|█████████ | 360/397 [02:42<00:03,  9.34it/s]
# Dedup S1:  91%|█████████ | 362/397 [02:42<00:03,  9.77it/s]
# Dedup S1:  92%|█████████▏| 364/397 [02:42<00:03, 10.53it/s]
# Dedup S1:  92%|█████████▏| 366/397 [02:43<00:02, 11.17it/s]
# Dedup S1:  93%|█████████▎| 368/397 [02:43<00:02, 11.64it/s]
# Dedup S1:  93%|█████████▎| 370/397 [02:43<00:02, 11.83it/s]
# Dedup S1:  94%|█████████▎| 372/397 [02:43<00:01, 12.62it/s]
# Dedup S1:  94%|█████████▍| 374/397 [02:43<00:01, 13.38it/s]
# Dedup S1:  95%|█████████▍| 376/397 [02:43<00:01, 14.06it/s]
# Dedup S1:  95%|█████████▌| 378/397 [02:43<00:01, 14.59it/s]
# Dedup S1:  96%|█████████▌| 380/397 [02:44<00:01, 15.70it/s]
# Dedup S1:  96%|█████████▋| 383/397 [02:44<00:00, 17.26it/s]
# Dedup S1:  97%|█████████▋| 386/397 [02:44<00:00, 19.66it/s]
# Dedup S1: 100%|██████████| 397/397 [02:44<00:00,  2.41it/s]
#
# Dedup S2:   0%|          | 0/413 [00:00<?, ?it/s]
# Dedup S2:   0%|          | 1/413 [00:00<05:13,  1.31it/s]
# Dedup S2:   0%|          | 2/413 [00:01<05:11,  1.32it/s]
# Dedup S2:   1%|          | 3/413 [00:02<05:11,  1.32it/s]
# Dedup S2:   1%|          | 4/413 [00:03<05:52,  1.16it/s]
# Dedup S2:   1%|          | 5/413 [00:04<06:17,  1.08it/s]
# Dedup S2:   1%|▏         | 6/413 [00:05<06:39,  1.02it/s]
# Dedup S2:   2%|▏         | 7/413 [00:06<06:50,  1.01s/it]
# Dedup S2:   2%|▏         | 8/413 [00:07<07:02,  1.04s/it]
# Dedup S2:   2%|▏         | 9/413 [00:08<06:23,  1.05it/s]
# Dedup S2:   2%|▏         | 10/413 [00:09<06:01,  1.12it/s]
# Dedup S2:   3%|▎         | 11/413 [00:09<05:40,  1.18it/s]
# Dedup S2:   3%|▎         | 12/413 [00:11<06:12,  1.08it/s]
# Dedup S2:   3%|▎         | 13/413 [00:12<06:29,  1.03it/s]
# Dedup S2:   3%|▎         | 14/413 [00:13<06:46,  1.02s/it]
# Dedup S2:   4%|▎         | 15/413 [00:14<06:51,  1.03s/it]
# Dedup S2:   4%|▍         | 16/413 [00:15<06:58,  1.05s/it]
# Dedup S2:   4%|▍         | 17/413 [00:16<06:15,  1.05it/s]
# Dedup S2:   4%|▍         | 18/413 [00:16<05:48,  1.13it/s]
# Dedup S2:   5%|▍         | 19/413 [00:17<05:27,  1.20it/s]
# Dedup S2:   5%|▍         | 20/413 [00:18<06:01,  1.09it/s]
# Dedup S2:   5%|▌         | 21/413 [00:19<06:21,  1.03it/s]
# Dedup S2:   5%|▌         | 22/413 [00:20<06:31,  1.00s/it]
# Dedup S2:   6%|▌         | 23/413 [00:22<06:41,  1.03s/it]
# Dedup S2:   6%|▌         | 24/413 [00:23<06:43,  1.04s/it]
# Dedup S2:   6%|▌         | 25/413 [00:23<06:00,  1.07it/s]
# Dedup S2:   6%|▋         | 26/413 [00:24<05:31,  1.17it/s]
# Dedup S2:   7%|▋         | 27/413 [00:25<05:11,  1.24it/s]
# Dedup S2:   7%|▋         | 28/413 [00:26<05:42,  1.12it/s]
# Dedup S2:   7%|▋         | 29/413 [00:27<05:58,  1.07it/s]
# Dedup S2:   7%|▋         | 30/413 [00:28<06:06,  1.04it/s]
# Dedup S2:   8%|▊         | 31/413 [00:29<06:13,  1.02it/s]
# Dedup S2:   8%|▊         | 32/413 [00:30<06:14,  1.02it/s]
# Dedup S2:   8%|▊         | 33/413 [00:30<05:37,  1.13it/s]
# Dedup S2:   8%|▊         | 34/413 [00:31<05:12,  1.21it/s]
# Dedup S2:   8%|▊         | 35/413 [00:32<04:53,  1.29it/s]
# Dedup S2:   9%|▊         | 36/413 [00:33<05:14,  1.20it/s]
# Dedup S2:   9%|▉         | 37/413 [00:34<05:34,  1.13it/s]
# Dedup S2:   9%|▉         | 38/413 [00:35<05:44,  1.09it/s]
# Dedup S2:   9%|▉         | 39/413 [00:36<06:10,  1.01it/s]
# Dedup S2:  10%|▉         | 40/413 [00:37<06:09,  1.01it/s]
# Dedup S2:  10%|▉         | 41/413 [00:38<05:27,  1.13it/s]
# Dedup S2:  10%|█         | 42/413 [00:38<05:03,  1.22it/s]
# Dedup S2:  10%|█         | 43/413 [00:39<04:45,  1.29it/s]
# Dedup S2:  11%|█         | 44/413 [00:40<05:13,  1.18it/s]
# Dedup S2:  11%|█         | 45/413 [00:41<05:29,  1.12it/s]
# Dedup S2:  11%|█         | 46/413 [00:42<05:45,  1.06it/s]
# Dedup S2:  11%|█▏        | 47/413 [00:43<05:48,  1.05it/s]
# Dedup S2:  12%|█▏        | 48/413 [00:44<05:48,  1.05it/s]
# Dedup S2:  12%|█▏        | 49/413 [00:45<05:12,  1.17it/s]
# Dedup S2:  12%|█▏        | 50/413 [00:45<04:44,  1.28it/s]
# Dedup S2:  12%|█▏        | 51/413 [00:46<04:26,  1.36it/s]
# Dedup S2:  13%|█▎        | 52/413 [00:47<04:53,  1.23it/s]
# Dedup S2:  13%|█▎        | 53/413 [00:48<05:07,  1.17it/s]
# Dedup S2:  13%|█▎        | 54/413 [00:49<05:21,  1.12it/s]
# Dedup S2:  13%|█▎        | 55/413 [00:50<05:31,  1.08it/s]
# Dedup S2:  14%|█▎        | 56/413 [00:51<05:34,  1.07it/s]
# Dedup S2:  14%|█▍        | 57/413 [00:51<04:59,  1.19it/s]
# Dedup S2:  14%|█▍        | 58/413 [00:52<04:35,  1.29it/s]
# Dedup S2:  14%|█▍        | 59/413 [00:53<04:16,  1.38it/s]
# Dedup S2:  15%|█▍        | 60/413 [00:53<04:04,  1.44it/s]
# Dedup S2:  15%|█▍        | 61/413 [00:54<03:54,  1.50it/s]
# Dedup S2:  15%|█▌        | 62/413 [00:54<03:48,  1.53it/s]
# Dedup S2:  15%|█▌        | 63/413 [00:55<04:17,  1.36it/s]
# Dedup S2:  15%|█▌        | 64/413 [00:56<04:02,  1.44it/s]
# Dedup S2:  16%|█▌        | 65/413 [00:56<03:52,  1.50it/s]
# Dedup S2:  16%|█▌        | 66/413 [00:57<03:47,  1.53it/s]
# Dedup S2:  16%|█▌        | 67/413 [00:58<03:44,  1.54it/s]
# Dedup S2:  16%|█▋        | 68/413 [00:58<03:37,  1.58it/s]
# Dedup S2:  17%|█▋        | 69/413 [00:59<03:34,  1.61it/s]
# Dedup S2:  17%|█▋        | 70/413 [01:00<04:12,  1.36it/s]
# Dedup S2:  17%|█▋        | 71/413 [01:01<03:57,  1.44it/s]
# Dedup S2:  17%|█▋        | 72/413 [01:01<03:46,  1.51it/s]
# Dedup S2:  18%|█▊        | 73/413 [01:02<03:38,  1.55it/s]
# Dedup S2:  18%|█▊        | 74/413 [01:02<03:34,  1.58it/s]
# Dedup S2:  18%|█▊        | 75/413 [01:03<03:29,  1.61it/s]
# Dedup S2:  18%|█▊        | 76/413 [01:04<03:27,  1.62it/s]
# Dedup S2:  19%|█▊        | 77/413 [01:04<03:57,  1.41it/s]
# Dedup S2:  19%|█▉        | 78/413 [01:05<03:43,  1.50it/s]
# Dedup S2:  19%|█▉        | 79/413 [01:06<03:36,  1.55it/s]
# Dedup S2:  19%|█▉        | 80/413 [01:06<03:27,  1.60it/s]
# Dedup S2:  20%|█▉        | 81/413 [01:07<03:23,  1.63it/s]
# Dedup S2:  20%|█▉        | 82/413 [01:07<03:21,  1.64it/s]
# Dedup S2:  20%|██        | 83/413 [01:08<03:17,  1.67it/s]
# Dedup S2:  20%|██        | 84/413 [01:09<03:46,  1.45it/s]
# Dedup S2:  21%|██        | 85/413 [01:09<03:34,  1.53it/s]
# Dedup S2:  21%|██        | 86/413 [01:10<03:28,  1.57it/s]
# Dedup S2:  21%|██        | 87/413 [01:11<03:20,  1.62it/s]
# Dedup S2:  21%|██▏       | 88/413 [01:11<03:15,  1.66it/s]
# Dedup S2:  22%|██▏       | 89/413 [01:12<03:14,  1.67it/s]
# Dedup S2:  22%|██▏       | 90/413 [01:12<03:11,  1.69it/s]
# Dedup S2:  22%|██▏       | 91/413 [01:13<03:37,  1.48it/s]
# Dedup S2:  22%|██▏       | 92/413 [01:14<03:26,  1.56it/s]
# Dedup S2:  23%|██▎       | 93/413 [01:14<03:18,  1.61it/s]
# Dedup S2:  23%|██▎       | 94/413 [01:15<03:10,  1.68it/s]
# Dedup S2:  23%|██▎       | 95/413 [01:15<03:04,  1.73it/s]
# Dedup S2:  23%|██▎       | 96/413 [01:16<03:00,  1.75it/s]
# Dedup S2:  23%|██▎       | 97/413 [01:17<02:59,  1.76it/s]
# Dedup S2:  24%|██▎       | 98/413 [01:17<03:30,  1.50it/s]
# Dedup S2:  24%|██▍       | 99/413 [01:18<03:20,  1.56it/s]
# Dedup S2:  24%|██▍       | 100/413 [01:19<03:12,  1.62it/s]
# Dedup S2:  24%|██▍       | 101/413 [01:19<03:05,  1.68it/s]
# Dedup S2:  25%|██▍       | 102/413 [01:20<03:03,  1.70it/s]
# Dedup S2:  25%|██▍       | 103/413 [01:20<03:00,  1.72it/s]
# Dedup S2:  25%|██▌       | 104/413 [01:21<02:55,  1.76it/s]
# Dedup S2:  25%|██▌       | 105/413 [01:22<03:19,  1.54it/s]
# Dedup S2:  26%|██▌       | 106/413 [01:22<03:07,  1.63it/s]
# Dedup S2:  26%|██▌       | 107/413 [01:23<02:59,  1.70it/s]
# Dedup S2:  26%|██▌       | 108/413 [01:23<02:53,  1.76it/s]
# Dedup S2:  26%|██▋       | 109/413 [01:24<02:48,  1.81it/s]
# Dedup S2:  27%|██▋       | 110/413 [01:24<02:45,  1.83it/s]
# Dedup S2:  27%|██▋       | 111/413 [01:25<02:43,  1.85it/s]
# Dedup S2:  27%|██▋       | 112/413 [01:26<03:05,  1.62it/s]
# Dedup S2:  27%|██▋       | 113/413 [01:26<02:55,  1.71it/s]
# Dedup S2:  28%|██▊       | 114/413 [01:27<02:49,  1.76it/s]
# Dedup S2:  28%|██▊       | 115/413 [01:27<02:44,  1.81it/s]
# Dedup S2:  28%|██▊       | 116/413 [01:28<02:41,  1.84it/s]
# Dedup S2:  28%|██▊       | 117/413 [01:28<02:39,  1.86it/s]
# Dedup S2:  29%|██▊       | 118/413 [01:29<02:36,  1.89it/s]
# Dedup S2:  29%|██▉       | 119/413 [01:29<02:57,  1.65it/s]
# Dedup S2:  29%|██▉       | 120/413 [01:30<02:48,  1.74it/s]
# Dedup S2:  29%|██▉       | 121/413 [01:31<02:44,  1.77it/s]
# Dedup S2:  30%|██▉       | 122/413 [01:31<02:40,  1.81it/s]
# Dedup S2:  30%|██▉       | 123/413 [01:32<02:36,  1.85it/s]
# Dedup S2:  30%|███       | 124/413 [01:32<02:35,  1.85it/s]
# Dedup S2:  30%|███       | 125/413 [01:33<02:32,  1.89it/s]
# Dedup S2:  31%|███       | 126/413 [01:33<02:56,  1.63it/s]
# Dedup S2:  31%|███       | 127/413 [01:34<02:47,  1.71it/s]
# Dedup S2:  31%|███       | 128/413 [01:34<02:39,  1.79it/s]
# Dedup S2:  31%|███       | 129/413 [01:35<02:34,  1.84it/s]
# Dedup S2:  31%|███▏      | 130/413 [01:35<02:28,  1.91it/s]
# Dedup S2:  32%|███▏      | 131/413 [01:36<02:24,  1.95it/s]
# Dedup S2:  32%|███▏      | 132/413 [01:36<02:22,  1.97it/s]
# Dedup S2:  32%|███▏      | 133/413 [01:37<02:43,  1.71it/s]
# Dedup S2:  32%|███▏      | 134/413 [01:38<02:35,  1.80it/s]
# Dedup S2:  33%|███▎      | 135/413 [01:38<02:30,  1.85it/s]
# Dedup S2:  33%|███▎      | 136/413 [01:39<02:26,  1.89it/s]
# Dedup S2:  33%|███▎      | 137/413 [01:39<02:23,  1.93it/s]
# Dedup S2:  33%|███▎      | 138/413 [01:40<02:20,  1.96it/s]
# Dedup S2:  34%|███▎      | 139/413 [01:40<02:18,  1.98it/s]
# Dedup S2:  34%|███▍      | 140/413 [01:41<02:37,  1.73it/s]
# Dedup S2:  34%|███▍      | 141/413 [01:41<02:29,  1.82it/s]
# Dedup S2:  34%|███▍      | 142/413 [01:42<02:24,  1.88it/s]
# Dedup S2:  35%|███▍      | 143/413 [01:42<02:20,  1.92it/s]
# Dedup S2:  35%|███▍      | 144/413 [01:43<02:16,  1.97it/s]
# Dedup S2:  35%|███▌      | 145/413 [01:43<02:14,  2.00it/s]
# Dedup S2:  35%|███▌      | 146/413 [01:44<02:11,  2.03it/s]
# Dedup S2:  36%|███▌      | 147/413 [01:45<02:29,  1.77it/s]
# Dedup S2:  36%|███▌      | 148/413 [01:45<02:20,  1.88it/s]
# Dedup S2:  36%|███▌      | 149/413 [01:45<02:15,  1.95it/s]
# Dedup S2:  36%|███▋      | 150/413 [01:46<02:10,  2.02it/s]
# Dedup S2:  37%|███▋      | 151/413 [01:46<02:07,  2.06it/s]
# Dedup S2:  37%|███▋      | 152/413 [01:47<02:03,  2.11it/s]
# Dedup S2:  37%|███▋      | 153/413 [01:47<02:02,  2.11it/s]
# Dedup S2:  37%|███▋      | 154/413 [01:48<02:21,  1.83it/s]
# Dedup S2:  38%|███▊      | 155/413 [01:48<02:14,  1.93it/s]
# Dedup S2:  38%|███▊      | 156/413 [01:49<02:09,  1.99it/s]
# Dedup S2:  38%|███▊      | 157/413 [01:49<02:05,  2.04it/s]
# Dedup S2:  38%|███▊      | 158/413 [01:50<02:03,  2.07it/s]
# Dedup S2:  38%|███▊      | 159/413 [01:50<02:00,  2.11it/s]
# Dedup S2:  39%|███▊      | 160/413 [01:51<01:57,  2.15it/s]
# Dedup S2:  39%|███▉      | 161/413 [01:51<02:15,  1.86it/s]
# Dedup S2:  39%|███▉      | 162/413 [01:52<02:07,  1.97it/s]
# Dedup S2:  39%|███▉      | 163/413 [01:52<02:01,  2.05it/s]
# Dedup S2:  40%|███▉      | 164/413 [01:53<01:56,  2.13it/s]
# Dedup S2:  40%|███▉      | 165/413 [01:53<01:56,  2.14it/s]
# Dedup S2:  40%|████      | 166/413 [01:54<01:53,  2.17it/s]
# Dedup S2:  40%|████      | 167/413 [01:54<01:52,  2.18it/s]
# Dedup S2:  41%|████      | 168/413 [01:55<02:10,  1.88it/s]
# Dedup S2:  41%|████      | 169/413 [01:55<02:04,  1.96it/s]
# Dedup S2:  41%|████      | 170/413 [01:56<02:00,  2.01it/s]
# Dedup S2:  41%|████▏     | 171/413 [01:56<01:57,  2.06it/s]
# Dedup S2:  42%|████▏     | 172/413 [01:57<01:55,  2.08it/s]
# Dedup S2:  42%|████▏     | 173/413 [01:57<01:53,  2.11it/s]
# Dedup S2:  42%|████▏     | 174/413 [01:58<01:51,  2.15it/s]
# Dedup S2:  42%|████▏     | 175/413 [01:58<02:04,  1.91it/s]
# Dedup S2:  43%|████▎     | 176/413 [01:59<01:58,  2.00it/s]
# Dedup S2:  43%|████▎     | 177/413 [01:59<01:54,  2.07it/s]
# Dedup S2:  43%|████▎     | 178/413 [02:00<01:52,  2.09it/s]
# Dedup S2:  43%|████▎     | 179/413 [02:00<01:49,  2.13it/s]
# Dedup S2:  44%|████▎     | 180/413 [02:00<01:46,  2.19it/s]
# Dedup S2:  44%|████▍     | 181/413 [02:01<01:44,  2.22it/s]
# Dedup S2:  44%|████▍     | 182/413 [02:02<01:57,  1.97it/s]
# Dedup S2:  44%|████▍     | 183/413 [02:02<01:51,  2.06it/s]
# Dedup S2:  45%|████▍     | 184/413 [02:02<01:47,  2.14it/s]
# Dedup S2:  45%|████▍     | 185/413 [02:03<01:42,  2.23it/s]
# Dedup S2:  45%|████▌     | 186/413 [02:03<01:39,  2.28it/s]
# Dedup S2:  45%|████▌     | 187/413 [02:04<01:37,  2.33it/s]
# Dedup S2:  46%|████▌     | 188/413 [02:04<01:37,  2.31it/s]
# Dedup S2:  46%|████▌     | 189/413 [02:05<01:53,  1.97it/s]
# Dedup S2:  46%|████▌     | 190/413 [02:05<01:47,  2.08it/s]
# Dedup S2:  46%|████▌     | 191/413 [02:06<01:43,  2.14it/s]
# Dedup S2:  46%|████▋     | 192/413 [02:06<01:40,  2.20it/s]
# Dedup S2:  47%|████▋     | 193/413 [02:06<01:37,  2.25it/s]
# Dedup S2:  47%|████▋     | 194/413 [02:07<01:34,  2.31it/s]
# Dedup S2:  47%|████▋     | 195/413 [02:07<01:33,  2.32it/s]
# Dedup S2:  47%|████▋     | 196/413 [02:08<01:44,  2.07it/s]
# Dedup S2:  48%|████▊     | 197/413 [02:08<01:39,  2.16it/s]
# Dedup S2:  48%|████▊     | 198/413 [02:09<01:36,  2.24it/s]
# Dedup S2:  48%|████▊     | 199/413 [02:09<01:33,  2.29it/s]
# Dedup S2:  48%|████▊     | 200/413 [02:10<01:33,  2.29it/s]
# Dedup S2:  49%|████▊     | 201/413 [02:10<01:30,  2.34it/s]
# Dedup S2:  49%|████▉     | 202/413 [02:10<01:28,  2.38it/s]
# Dedup S2:  49%|████▉     | 203/413 [02:11<01:38,  2.13it/s]
# Dedup S2:  49%|████▉     | 204/413 [02:11<01:32,  2.25it/s]
# Dedup S2:  50%|████▉     | 205/413 [02:12<01:29,  2.33it/s]
# Dedup S2:  50%|████▉     | 206/413 [02:12<01:27,  2.36it/s]
# Dedup S2:  50%|█████     | 207/413 [02:13<01:25,  2.40it/s]
# Dedup S2:  50%|█████     | 208/413 [02:13<01:25,  2.41it/s]
# Dedup S2:  51%|█████     | 209/413 [02:13<01:24,  2.40it/s]
# Dedup S2:  51%|█████     | 210/413 [02:14<01:37,  2.08it/s]
# Dedup S2:  51%|█████     | 211/413 [02:14<01:32,  2.19it/s]
# Dedup S2:  51%|█████▏    | 212/413 [02:15<01:29,  2.24it/s]
# Dedup S2:  52%|█████▏    | 213/413 [02:15<01:27,  2.29it/s]
# Dedup S2:  52%|█████▏    | 214/413 [02:16<01:26,  2.31it/s]
# Dedup S2:  52%|█████▏    | 215/413 [02:16<01:24,  2.33it/s]
# Dedup S2:  52%|█████▏    | 216/413 [02:17<01:24,  2.33it/s]
# Dedup S2:  53%|█████▎    | 217/413 [02:17<01:34,  2.08it/s]
# Dedup S2:  53%|█████▎    | 218/413 [02:17<01:27,  2.22it/s]
# Dedup S2:  53%|█████▎    | 219/413 [02:18<01:25,  2.27it/s]
# Dedup S2:  53%|█████▎    | 220/413 [02:18<01:21,  2.38it/s]
# Dedup S2:  54%|█████▎    | 221/413 [02:19<01:18,  2.43it/s]
# Dedup S2:  54%|█████▍    | 222/413 [02:19<01:16,  2.49it/s]
# Dedup S2:  54%|█████▍    | 223/413 [02:19<01:14,  2.55it/s]
# Dedup S2:  54%|█████▍    | 224/413 [02:20<01:23,  2.26it/s]
# Dedup S2:  54%|█████▍    | 225/413 [02:20<01:18,  2.39it/s]
# Dedup S2:  55%|█████▍    | 226/413 [02:21<01:15,  2.48it/s]
# Dedup S2:  55%|█████▍    | 227/413 [02:21<01:12,  2.57it/s]
# Dedup S2:  55%|█████▌    | 228/413 [02:21<01:09,  2.68it/s]
# Dedup S2:  55%|█████▌    | 229/413 [02:22<01:06,  2.75it/s]
# Dedup S2:  56%|█████▌    | 230/413 [02:22<01:06,  2.76it/s]
# Dedup S2:  56%|█████▌    | 231/413 [02:23<01:13,  2.48it/s]
# Dedup S2:  56%|█████▌    | 232/413 [02:23<01:10,  2.57it/s]
# Dedup S2:  56%|█████▋    | 233/413 [02:23<01:07,  2.67it/s]
# Dedup S2:  57%|█████▋    | 234/413 [02:24<01:04,  2.76it/s]
# Dedup S2:  57%|█████▋    | 235/413 [02:24<01:03,  2.80it/s]
# Dedup S2:  57%|█████▋    | 236/413 [02:24<01:02,  2.85it/s]
# Dedup S2:  57%|█████▋    | 237/413 [02:25<01:00,  2.92it/s]
# Dedup S2:  58%|█████▊    | 238/413 [02:25<01:07,  2.59it/s]
# Dedup S2:  58%|█████▊    | 239/413 [02:25<01:03,  2.73it/s]
# Dedup S2:  58%|█████▊    | 240/413 [02:26<01:00,  2.85it/s]
# Dedup S2:  58%|█████▊    | 241/413 [02:26<00:58,  2.94it/s]
# Dedup S2:  59%|█████▊    | 242/413 [02:26<00:58,  2.94it/s]
# Dedup S2:  59%|█████▉    | 243/413 [02:27<00:57,  2.97it/s]
# Dedup S2:  59%|█████▉    | 244/413 [02:27<00:56,  2.98it/s]
# Dedup S2:  59%|█████▉    | 245/413 [02:28<01:04,  2.61it/s]
# Dedup S2:  60%|█████▉    | 246/413 [02:28<01:00,  2.76it/s]
# Dedup S2:  60%|█████▉    | 247/413 [02:28<00:57,  2.90it/s]
# Dedup S2:  60%|██████    | 248/413 [02:28<00:54,  3.01it/s]
# Dedup S2:  60%|██████    | 249/413 [02:29<00:54,  3.01it/s]
# Dedup S2:  61%|██████    | 250/413 [02:29<00:53,  3.05it/s]
# Dedup S2:  61%|██████    | 251/413 [02:29<00:52,  3.10it/s]
# Dedup S2:  61%|██████    | 252/413 [02:30<00:59,  2.71it/s]
# Dedup S2:  61%|██████▏   | 253/413 [02:30<00:56,  2.85it/s]
# Dedup S2:  62%|██████▏   | 254/413 [02:31<00:53,  2.96it/s]
# Dedup S2:  62%|██████▏   | 255/413 [02:31<00:51,  3.05it/s]
# Dedup S2:  62%|██████▏   | 256/413 [02:31<00:51,  3.08it/s]
# Dedup S2:  62%|██████▏   | 257/413 [02:31<00:49,  3.15it/s]
# Dedup S2:  62%|██████▏   | 258/413 [02:32<00:48,  3.18it/s]
# Dedup S2:  63%|██████▎   | 259/413 [02:32<00:55,  2.78it/s]
# Dedup S2:  63%|██████▎   | 260/413 [02:33<00:52,  2.93it/s]
# Dedup S2:  63%|██████▎   | 261/413 [02:33<00:49,  3.07it/s]
# Dedup S2:  63%|██████▎   | 262/413 [02:33<00:47,  3.20it/s]
# Dedup S2:  64%|██████▎   | 263/413 [02:33<00:46,  3.24it/s]
# Dedup S2:  64%|██████▍   | 264/413 [02:34<00:44,  3.34it/s]
# Dedup S2:  64%|██████▍   | 265/413 [02:34<00:44,  3.34it/s]
# Dedup S2:  64%|██████▍   | 266/413 [02:34<00:49,  2.98it/s]
# Dedup S2:  65%|██████▍   | 267/413 [02:35<00:46,  3.14it/s]
# Dedup S2:  65%|██████▍   | 268/413 [02:35<00:44,  3.28it/s]
# Dedup S2:  65%|██████▌   | 269/413 [02:35<00:42,  3.40it/s]
# Dedup S2:  65%|██████▌   | 270/413 [02:36<00:41,  3.46it/s]
# Dedup S2:  66%|██████▌   | 271/413 [02:36<00:40,  3.51it/s]
# Dedup S2:  66%|██████▌   | 272/413 [02:36<00:39,  3.54it/s]
# Dedup S2:  66%|██████▌   | 273/413 [02:36<00:43,  3.24it/s]
# Dedup S2:  66%|██████▋   | 274/413 [02:37<00:41,  3.37it/s]
# Dedup S2:  67%|██████▋   | 275/413 [02:37<00:39,  3.47it/s]
# Dedup S2:  67%|██████▋   | 276/413 [02:37<00:38,  3.53it/s]
# Dedup S2:  67%|██████▋   | 277/413 [02:38<00:37,  3.61it/s]
# Dedup S2:  67%|██████▋   | 278/413 [02:38<00:36,  3.68it/s]
# Dedup S2:  68%|██████▊   | 279/413 [02:38<00:35,  3.74it/s]
# Dedup S2:  68%|██████▊   | 280/413 [02:38<00:39,  3.37it/s]
# Dedup S2:  68%|██████▊   | 281/413 [02:39<00:37,  3.52it/s]
# Dedup S2:  68%|██████▊   | 282/413 [02:39<00:36,  3.59it/s]
# Dedup S2:  69%|██████▊   | 283/413 [02:39<00:36,  3.59it/s]
# Dedup S2:  69%|██████▉   | 284/413 [02:39<00:35,  3.58it/s]
# Dedup S2:  69%|██████▉   | 285/413 [02:40<00:34,  3.66it/s]
# Dedup S2:  69%|██████▉   | 286/413 [02:40<00:34,  3.67it/s]
# Dedup S2:  69%|██████▉   | 287/413 [02:40<00:37,  3.34it/s]
# Dedup S2:  70%|██████▉   | 288/413 [02:41<00:35,  3.50it/s]
# Dedup S2:  70%|██████▉   | 289/413 [02:41<00:34,  3.64it/s]
# Dedup S2:  70%|███████   | 290/413 [02:41<00:33,  3.72it/s]
# Dedup S2:  70%|███████   | 291/413 [02:41<00:32,  3.80it/s]
# Dedup S2:  71%|███████   | 292/413 [02:42<00:31,  3.83it/s]
# Dedup S2:  71%|███████   | 293/413 [02:42<00:31,  3.86it/s]
# Dedup S2:  71%|███████   | 294/413 [02:42<00:35,  3.40it/s]
# Dedup S2:  71%|███████▏  | 295/413 [02:42<00:32,  3.58it/s]
# Dedup S2:  72%|███████▏  | 296/413 [02:43<00:31,  3.74it/s]
# Dedup S2:  72%|███████▏  | 297/413 [02:43<00:30,  3.80it/s]
# Dedup S2:  72%|███████▏  | 298/413 [02:43<00:29,  3.85it/s]
# Dedup S2:  72%|███████▏  | 299/413 [02:43<00:28,  3.96it/s]
# Dedup S2:  73%|███████▎  | 300/413 [02:44<00:28,  4.00it/s]
# Dedup S2:  73%|███████▎  | 301/413 [02:44<00:30,  3.62it/s]
# Dedup S2:  73%|███████▎  | 302/413 [02:44<00:29,  3.82it/s]
# Dedup S2:  73%|███████▎  | 303/413 [02:45<00:27,  3.99it/s]
# Dedup S2:  74%|███████▎  | 304/413 [02:45<00:26,  4.12it/s]
# Dedup S2:  74%|███████▍  | 305/413 [02:45<00:25,  4.20it/s]
# Dedup S2:  74%|███████▍  | 306/413 [02:45<00:25,  4.28it/s]
# Dedup S2:  74%|███████▍  | 307/413 [02:45<00:24,  4.40it/s]
# Dedup S2:  75%|███████▍  | 308/413 [02:46<00:26,  4.01it/s]
# Dedup S2:  75%|███████▍  | 309/413 [02:46<00:25,  4.14it/s]
# Dedup S2:  75%|███████▌  | 310/413 [02:46<00:24,  4.26it/s]
# Dedup S2:  75%|███████▌  | 311/413 [02:46<00:23,  4.38it/s]
# Dedup S2:  76%|███████▌  | 312/413 [02:47<00:22,  4.48it/s]
# Dedup S2:  76%|███████▌  | 313/413 [02:47<00:22,  4.52it/s]
# Dedup S2:  76%|███████▌  | 314/413 [02:47<00:21,  4.59it/s]
# Dedup S2:  76%|███████▋  | 315/413 [02:47<00:23,  4.24it/s]
# Dedup S2:  77%|███████▋  | 316/413 [02:47<00:22,  4.40it/s]
# Dedup S2:  77%|███████▋  | 317/413 [02:48<00:21,  4.52it/s]
# Dedup S2:  77%|███████▋  | 318/413 [02:48<00:20,  4.64it/s]
# Dedup S2:  77%|███████▋  | 319/413 [02:48<00:20,  4.63it/s]
# Dedup S2:  77%|███████▋  | 320/413 [02:48<00:19,  4.70it/s]
# Dedup S2:  78%|███████▊  | 321/413 [02:48<00:18,  4.86it/s]
# Dedup S2:  78%|███████▊  | 322/413 [02:49<00:20,  4.48it/s]
# Dedup S2:  78%|███████▊  | 323/413 [02:49<00:19,  4.65it/s]
# Dedup S2:  78%|███████▊  | 324/413 [02:49<00:18,  4.73it/s]
# Dedup S2:  79%|███████▊  | 325/413 [02:49<00:18,  4.84it/s]
# Dedup S2:  79%|███████▉  | 326/413 [02:50<00:17,  4.86it/s]
# Dedup S2:  79%|███████▉  | 327/413 [02:50<00:17,  4.98it/s]
# Dedup S2:  79%|███████▉  | 328/413 [02:50<00:16,  5.17it/s]
# Dedup S2:  80%|███████▉  | 329/413 [02:50<00:17,  4.77it/s]
# Dedup S2:  80%|███████▉  | 330/413 [02:50<00:16,  5.03it/s]
# Dedup S2:  80%|████████  | 331/413 [02:51<00:15,  5.18it/s]
# Dedup S2:  80%|████████  | 332/413 [02:51<00:15,  5.36it/s]
# Dedup S2:  81%|████████  | 333/413 [02:51<00:14,  5.48it/s]
# Dedup S2:  81%|████████  | 334/413 [02:51<00:14,  5.54it/s]
# Dedup S2:  81%|████████  | 335/413 [02:51<00:14,  5.53it/s]
# Dedup S2:  81%|████████▏ | 336/413 [02:51<00:14,  5.20it/s]
# Dedup S2:  82%|████████▏ | 337/413 [02:52<00:14,  5.41it/s]
# Dedup S2:  82%|████████▏ | 338/413 [02:52<00:13,  5.59it/s]
# Dedup S2:  82%|████████▏ | 339/413 [02:52<00:13,  5.69it/s]
# Dedup S2:  82%|████████▏ | 340/413 [02:52<00:12,  5.79it/s]
# Dedup S2:  83%|████████▎ | 341/413 [02:52<00:12,  5.70it/s]
# Dedup S2:  83%|████████▎ | 342/413 [02:52<00:12,  5.83it/s]
# Dedup S2:  83%|████████▎ | 343/413 [02:53<00:12,  5.54it/s]
# Dedup S2:  83%|████████▎ | 344/413 [02:53<00:12,  5.37it/s]
# Dedup S2:  84%|████████▎ | 345/413 [02:53<00:12,  5.28it/s]
# Dedup S2:  84%|████████▍ | 346/413 [02:53<00:13,  5.04it/s]
# Dedup S2:  84%|████████▍ | 347/413 [02:53<00:13,  5.05it/s]
# Dedup S2:  84%|████████▍ | 348/413 [02:54<00:12,  5.02it/s]
# Dedup S2:  85%|████████▍ | 349/413 [02:54<00:12,  5.10it/s]
# Dedup S2:  85%|████████▍ | 350/413 [02:54<00:12,  4.97it/s]
# Dedup S2:  85%|████████▍ | 351/413 [02:54<00:11,  5.27it/s]
# Dedup S2:  85%|████████▌ | 352/413 [02:54<00:10,  5.59it/s]
# Dedup S2:  85%|████████▌ | 353/413 [02:55<00:09,  6.07it/s]
# Dedup S2:  86%|████████▌ | 354/413 [02:55<00:09,  6.33it/s]
# Dedup S2:  86%|████████▌ | 355/413 [02:55<00:08,  6.72it/s]
# Dedup S2:  86%|████████▌ | 356/413 [02:55<00:08,  6.84it/s]
# Dedup S2:  86%|████████▋ | 357/413 [02:55<00:08,  6.44it/s]
# Dedup S2:  87%|████████▋ | 358/413 [02:55<00:08,  6.71it/s]
# Dedup S2:  87%|████████▋ | 359/413 [02:55<00:07,  6.86it/s]
# Dedup S2:  87%|████████▋ | 360/413 [02:56<00:07,  7.08it/s]
# Dedup S2:  87%|████████▋ | 361/413 [02:56<00:07,  7.34it/s]
# Dedup S2:  88%|████████▊ | 362/413 [02:56<00:06,  7.52it/s]
# Dedup S2:  88%|████████▊ | 363/413 [02:56<00:06,  7.47it/s]
# Dedup S2:  88%|████████▊ | 364/413 [02:56<00:06,  7.22it/s]
# Dedup S2:  88%|████████▊ | 365/413 [02:56<00:06,  7.42it/s]
# Dedup S2:  89%|████████▊ | 366/413 [02:56<00:06,  7.72it/s]
# Dedup S2:  89%|████████▉ | 367/413 [02:56<00:05,  8.04it/s]
# Dedup S2:  89%|████████▉ | 368/413 [02:57<00:05,  8.24it/s]
# Dedup S2:  89%|████████▉ | 369/413 [02:57<00:05,  8.25it/s]
# Dedup S2:  90%|████████▉ | 370/413 [02:57<00:05,  8.17it/s]
# Dedup S2:  90%|████████▉ | 371/413 [02:57<00:05,  7.80it/s]
# Dedup S2:  90%|█████████ | 372/413 [02:57<00:05,  8.04it/s]
# Dedup S2:  90%|█████████ | 373/413 [02:57<00:04,  8.34it/s]
# Dedup S2:  91%|█████████ | 374/413 [02:57<00:04,  8.71it/s]
# Dedup S2:  91%|█████████ | 375/413 [02:57<00:04,  8.85it/s]
# Dedup S2:  91%|█████████▏| 377/413 [02:58<00:03,  9.36it/s]
# Dedup S2:  92%|█████████▏| 378/413 [02:58<00:03,  9.26it/s]
# Dedup S2:  92%|█████████▏| 380/413 [02:58<00:03,  9.87it/s]
# Dedup S2:  92%|█████████▏| 382/413 [02:58<00:02, 10.51it/s]
# Dedup S2:  93%|█████████▎| 384/413 [02:58<00:02, 11.15it/s]
# Dedup S2:  93%|█████████▎| 386/413 [02:58<00:02, 11.63it/s]
# Dedup S2:  94%|█████████▍| 388/413 [02:58<00:02, 12.21it/s]
# Dedup S2:  94%|█████████▍| 390/413 [02:59<00:01, 12.61it/s]
# Dedup S2:  95%|█████████▍| 392/413 [02:59<00:01, 13.36it/s]
# Dedup S2:  95%|█████████▌| 394/413 [02:59<00:01, 14.29it/s]
# Dedup S2:  96%|█████████▌| 396/413 [02:59<00:01, 15.48it/s]
# Dedup S2:  97%|█████████▋| 399/413 [02:59<00:00, 16.98it/s]
# Dedup S2:  97%|█████████▋| 402/413 [02:59<00:00, 18.86it/s]
# Dedup S2: 100%|██████████| 413/413 [02:59<00:00,  2.30it/s]
#
# Dedup S1 and S2:   0%|          | 0/397 [00:00<?, ?it/s]
# Dedup S1 and S2:   0%|          | 1/397 [00:00<05:10,  1.27it/s]
# Dedup S1 and S2:   1%|          | 2/397 [00:01<05:08,  1.28it/s]
# Dedup S1 and S2:   1%|          | 3/397 [00:02<05:06,  1.29it/s]
# Dedup S1 and S2:   1%|          | 4/397 [00:03<05:46,  1.14it/s]
# Dedup S1 and S2:   1%|▏         | 5/397 [00:04<06:18,  1.04it/s]
# Dedup S1 and S2:   2%|▏         | 6/397 [00:05<06:33,  1.01s/it]
# Dedup S1 and S2:   2%|▏         | 7/397 [00:06<06:46,  1.04s/it]
# Dedup S1 and S2:   2%|▏         | 8/397 [00:07<06:51,  1.06s/it]
# Dedup S1 and S2:   2%|▏         | 9/397 [00:08<06:16,  1.03it/s]
# Dedup S1 and S2:   3%|▎         | 10/397 [00:09<05:50,  1.10it/s]
# Dedup S1 and S2:   3%|▎         | 11/397 [00:10<05:34,  1.15it/s]
# Dedup S1 and S2:   3%|▎         | 12/397 [00:11<06:00,  1.07it/s]
# Dedup S1 and S2:   3%|▎         | 13/397 [00:12<06:17,  1.02it/s]
# Dedup S1 and S2:   4%|▎         | 14/397 [00:13<06:30,  1.02s/it]
# Dedup S1 and S2:   4%|▍         | 15/397 [00:14<06:36,  1.04s/it]
# Dedup S1 and S2:   4%|▍         | 16/397 [00:15<06:46,  1.07s/it]
# Dedup S1 and S2:   4%|▍         | 17/397 [00:16<06:12,  1.02it/s]
# Dedup S1 and S2:   5%|▍         | 18/397 [00:17<05:46,  1.09it/s]
# Dedup S1 and S2:   5%|▍         | 19/397 [00:18<05:27,  1.16it/s]
# Dedup S1 and S2:   5%|▌         | 20/397 [00:19<05:50,  1.08it/s]
# Dedup S1 and S2:   5%|▌         | 21/397 [00:20<06:09,  1.02it/s]
# ...
# Dedup S1 and S2:  50%|█████     | 200/397 [02:52<02:35,  1.26it/s]
# Dedup S1 and S2:  51%|█████     | 201/397 [02:53<02:55,  1.12it/s]
# Dedup S1 and S2:  51%|█████     | 202/397 [02:53<02:47,  1.16it/s]
# Dedup S1 and S2:  51%|█████     | 203/397 [02:54<02:40,  1.21it/s]
# Dedup S1 and S2:  51%|█████▏    | 204/397 [02:55<02:35,  1.24it/s]
# Dedup S1 and S2:  52%|█████▏    | 205/397 [02:56<02:33,  1.25it/s]
# Dedup S1 and S2:  52%|█████▏    | 206/397 [02:56<02:30,  1.27it/s]
# Dedup S1 and S2:  52%|█████▏    | 207/397 [02:57<02:28,  1.28it/s]
# Dedup S1 and S2:  52%|█████▏    | 208/397 [02:58<02:48,  1.12it/s]
# Dedup S1 and S2:  53%|█████▎    | 209/397 [02:59<02:40,  1.17it/s]
# Dedup S1 and S2:  53%|█████▎    | 210/397 [03:00<02:35,  1.20it/s]
# Dedup S1 and S2:  53%|█████▎    | 211/397 [03:01<02:32,  1.22it/s]
# Dedup S1 and S2:  53%|█████▎    | 212/397 [03:02<02:30,  1.23it/s]
# Dedup S1 and S2:  54%|█████▎    | 213/397 [03:02<02:26,  1.26it/s]
# Dedup S1 and S2:  54%|█████▍    | 214/397 [03:03<02:26,  1.25it/s]
# Dedup S1 and S2:  54%|█████▍    | 215/397 [03:04<02:44,  1.11it/s]
# Dedup S1 and S2:  54%|█████▍    | 216/397 [03:05<02:36,  1.16it/s]
# Dedup S1 and S2:  55%|█████▍    | 217/397 [03:06<02:30,  1.20it/s]
# Dedup S1 and S2:  55%|█████▍    | 218/397 [03:07<02:25,  1.23it/s]
# Dedup S1 and S2:  55%|█████▌    | 219/397 [03:07<02:22,  1.25it/s]
# Dedup S1 and S2:  55%|█████▌    | 220/397 [03:08<02:20,  1.26it/s]
# Dedup S1 and S2:  56%|█████▌    | 221/397 [03:09<02:18,  1.27it/s]
# Dedup S1 and S2:  56%|█████▌    | 222/397 [03:10<02:38,  1.10it/s]
# Dedup S1 and S2:  56%|█████▌    | 223/397 [03:11<02:31,  1.15it/s]
# Dedup S1 and S2:  56%|█████▋    | 224/397 [03:12<02:27,  1.17it/s]
# Dedup S1 and S2:  57%|█████▋    | 225/397 [03:12<02:22,  1.21it/s]
# Dedup S1 and S2:  57%|█████▋    | 226/397 [03:13<02:23,  1.19it/s]
# Dedup S1 and S2:  57%|█████▋    | 227/397 [03:14<02:23,  1.19it/s]
# Dedup S1 and S2:  57%|█████▋    | 228/397 [03:15<02:19,  1.21it/s]
# Dedup S1 and S2:  58%|█████▊    | 229/397 [03:16<02:36,  1.07it/s]
# Dedup S1 and S2:  58%|█████▊    | 230/397 [03:17<02:29,  1.12it/s]
# Dedup S1 and S2:  58%|█████▊    | 231/397 [03:18<02:25,  1.14it/s]
# Dedup S1 and S2:  58%|█████▊    | 232/397 [03:19<02:18,  1.19it/s]
# Dedup S1 and S2:  59%|█████▊    | 233/397 [03:19<02:15,  1.21it/s]
# Dedup S1 and S2:  59%|█████▉    | 234/397 [03:20<02:13,  1.22it/s]
# Dedup S1 and S2:  59%|█████▉    | 235/397 [03:21<02:09,  1.25it/s]
# Dedup S1 and S2:  59%|█████▉    | 236/397 [03:22<02:29,  1.08it/s]
# Dedup S1 and S2:  60%|█████▉    | 237/397 [03:23<02:23,  1.11it/s]
# Dedup S1 and S2:  60%|█████▉    | 238/397 [03:24<02:19,  1.14it/s]
# Dedup S1 and S2:  60%|██████    | 239/397 [03:25<02:15,  1.16it/s]
# Dedup S1 and S2:  60%|██████    | 240/397 [03:25<02:14,  1.17it/s]
# Dedup S1 and S2:  61%|██████    | 241/397 [03:26<02:12,  1.18it/s]
# Dedup S1 and S2:  61%|██████    | 242/397 [03:27<02:10,  1.19it/s]
# Dedup S1 and S2:  61%|██████    | 243/397 [03:28<02:26,  1.05it/s]
# Dedup S1 and S2:  61%|██████▏   | 244/397 [03:29<02:17,  1.12it/s]
# Dedup S1 and S2:  62%|██████▏   | 245/397 [03:30<02:11,  1.15it/s]
# Dedup S1 and S2:  62%|██████▏   | 246/397 [03:31<02:07,  1.18it/s]
# Dedup S1 and S2:  62%|██████▏   | 247/397 [03:31<02:04,  1.20it/s]
# Dedup S1 and S2:  62%|██████▏   | 248/397 [03:32<02:03,  1.21it/s]
# Dedup S1 and S2:  63%|██████▎   | 249/397 [03:33<02:02,  1.21it/s]
# Dedup S1 and S2:  63%|██████▎   | 250/397 [03:34<02:20,  1.05it/s]
# Dedup S1 and S2:  63%|██████▎   | 251/397 [03:35<02:11,  1.11it/s]
# Dedup S1 and S2:  63%|██████▎   | 252/397 [03:36<02:04,  1.16it/s]
# Dedup S1 and S2:  64%|██████▎   | 253/397 [03:37<01:59,  1.20it/s]
# Dedup S1 and S2:  64%|██████▍   | 254/397 [03:37<01:56,  1.22it/s]
# Dedup S1 and S2:  64%|██████▍   | 255/397 [03:38<01:54,  1.24it/s]
# Dedup S1 and S2:  64%|██████▍   | 256/397 [03:39<01:54,  1.23it/s]
# Dedup S1 and S2:  65%|██████▍   | 257/397 [03:40<02:12,  1.05it/s]
# Dedup S1 and S2:  65%|██████▍   | 258/397 [03:41<02:05,  1.11it/s]
# Dedup S1 and S2:  65%|██████▌   | 259/397 [03:42<02:02,  1.13it/s]
# Dedup S1 and S2:  65%|██████▌   | 260/397 [03:43<01:57,  1.16it/s]
# Dedup S1 and S2:  66%|██████▌   | 261/397 [03:44<01:55,  1.17it/s]
# Dedup S1 and S2:  66%|██████▌   | 262/397 [03:44<01:54,  1.18it/s]
# Dedup S1 and S2:  66%|██████▌   | 263/397 [03:45<01:52,  1.19it/s]
# Dedup S1 and S2:  66%|██████▋   | 264/397 [03:47<02:08,  1.03it/s]
# Dedup S1 and S2:  67%|██████▋   | 265/397 [03:47<02:02,  1.08it/s]
# Dedup S1 and S2:  67%|██████▋   | 266/397 [03:48<01:58,  1.10it/s]
# Dedup S1 and S2:  67%|██████▋   | 267/397 [03:49<01:54,  1.14it/s]
# Dedup S1 and S2:  68%|██████▊   | 268/397 [03:50<01:50,  1.16it/s]
# Dedup S1 and S2:  68%|██████▊   | 269/397 [03:51<01:47,  1.19it/s]
# Dedup S1 and S2:  68%|██████▊   | 270/397 [03:51<01:45,  1.20it/s]
# Dedup S1 and S2:  68%|██████▊   | 271/397 [03:53<01:58,  1.06it/s]
# Dedup S1 and S2:  69%|██████▊   | 272/397 [03:53<01:51,  1.12it/s]
# Dedup S1 and S2:  69%|██████▉   | 273/397 [03:54<01:49,  1.13it/s]
# Dedup S1 and S2:  69%|██████▉   | 274/397 [03:55<01:44,  1.17it/s]
# Dedup S1 and S2:  69%|██████▉   | 275/397 [03:56<01:41,  1.20it/s]
# Dedup S1 and S2:  70%|██████▉   | 276/397 [03:57<01:39,  1.22it/s]
# Dedup S1 and S2:  70%|██████▉   | 277/397 [03:57<01:38,  1.21it/s]
# Dedup S1 and S2:  70%|███████   | 278/397 [03:59<01:50,  1.08it/s]
# Dedup S1 and S2:  70%|███████   | 279/397 [03:59<01:44,  1.13it/s]
# Dedup S1 and S2:  71%|███████   | 280/397 [04:00<01:39,  1.17it/s]
# Dedup S1 and S2:  71%|███████   | 281/397 [04:01<01:36,  1.20it/s]
# Dedup S1 and S2:  71%|███████   | 282/397 [04:02<01:34,  1.21it/s]
# Dedup S1 and S2:  71%|███████▏  | 283/397 [04:03<01:32,  1.23it/s]
# Dedup S1 and S2:  72%|███████▏  | 284/397 [04:03<01:31,  1.23it/s]
# Dedup S1 and S2:  72%|███████▏  | 285/397 [04:05<01:42,  1.09it/s]
# Dedup S1 and S2:  72%|███████▏  | 286/397 [04:05<01:38,  1.13it/s]
# Dedup S1 and S2:  72%|███████▏  | 287/397 [04:06<01:33,  1.17it/s]
# Dedup S1 and S2:  73%|███████▎  | 288/397 [04:07<01:30,  1.21it/s]
# Dedup S1 and S2:  73%|███████▎  | 289/397 [04:08<01:28,  1.22it/s]
# Dedup S1 and S2:  73%|███████▎  | 290/397 [04:09<01:26,  1.24it/s]
# Dedup S1 and S2:  73%|███████▎  | 291/397 [04:09<01:25,  1.23it/s]
# Dedup S1 and S2:  74%|███████▎  | 292/397 [04:10<01:35,  1.10it/s]
# Dedup S1 and S2:  74%|███████▍  | 293/397 [04:11<01:30,  1.15it/s]
# Dedup S1 and S2:  74%|███████▍  | 294/397 [04:12<01:27,  1.18it/s]
# Dedup S1 and S2:  74%|███████▍  | 295/397 [04:13<01:24,  1.21it/s]
# Dedup S1 and S2:  75%|███████▍  | 296/397 [04:14<01:22,  1.22it/s]
# Dedup S1 and S2:  75%|███████▍  | 297/397 [04:14<01:20,  1.25it/s]
# Dedup S1 and S2:  75%|███████▌  | 298/397 [04:15<01:18,  1.25it/s]
# Dedup S1 and S2:  75%|███████▌  | 299/397 [04:16<01:29,  1.10it/s]
# Dedup S1 and S2:  76%|███████▌  | 300/397 [04:17<01:23,  1.16it/s]
# Dedup S1 and S2:  76%|███████▌  | 301/397 [04:18<01:20,  1.19it/s]
# Dedup S1 and S2:  76%|███████▌  | 302/397 [04:19<01:17,  1.22it/s]
# Dedup S1 and S2:  76%|███████▋  | 303/397 [04:19<01:16,  1.22it/s]
# Dedup S1 and S2:  77%|███████▋  | 304/397 [04:20<01:14,  1.24it/s]
# Dedup S1 and S2:  77%|███████▋  | 305/397 [04:21<01:13,  1.26it/s]
# Dedup S1 and S2:  77%|███████▋  | 306/397 [04:22<01:21,  1.11it/s]
# Dedup S1 and S2:  77%|███████▋  | 307/397 [04:23<01:17,  1.16it/s]
# Dedup S1 and S2:  78%|███████▊  | 308/397 [04:24<01:14,  1.20it/s]
# Dedup S1 and S2:  78%|███████▊  | 309/397 [04:25<01:12,  1.21it/s]
# Dedup S1 and S2:  78%|███████▊  | 310/397 [04:25<01:11,  1.22it/s]
# Dedup S1 and S2:  78%|███████▊  | 311/397 [04:26<01:09,  1.23it/s]
# Dedup S1 and S2:  79%|███████▊  | 312/397 [04:27<01:08,  1.24it/s]
# Dedup S1 and S2:  79%|███████▉  | 313/397 [04:28<01:17,  1.09it/s]
# Dedup S1 and S2:  79%|███████▉  | 314/397 [04:29<01:12,  1.14it/s]
# Dedup S1 and S2:  79%|███████▉  | 315/397 [04:30<01:09,  1.17it/s]
# Dedup S1 and S2:  80%|███████▉  | 316/397 [04:30<01:07,  1.20it/s]
# Dedup S1 and S2:  80%|███████▉  | 317/397 [04:31<01:06,  1.21it/s]
# Dedup S1 and S2:  80%|████████  | 318/397 [04:32<01:04,  1.22it/s]
# Dedup S1 and S2:  80%|████████  | 319/397 [04:33<01:03,  1.23it/s]
# Dedup S1 and S2:  81%|████████  | 320/397 [04:34<01:11,  1.07it/s]
# Dedup S1 and S2:  81%|████████  | 321/397 [04:35<01:08,  1.11it/s]
# Dedup S1 and S2:  81%|████████  | 322/397 [04:36<01:05,  1.15it/s]
# Dedup S1 and S2:  81%|████████▏ | 323/397 [04:36<01:02,  1.19it/s]
# Dedup S1 and S2:  82%|████████▏ | 324/397 [04:37<01:00,  1.20it/s]
# Dedup S1 and S2:  82%|████████▏ | 325/397 [04:38<00:58,  1.23it/s]
# Dedup S1 and S2:  82%|████████▏ | 326/397 [04:39<00:57,  1.22it/s]
# Dedup S1 and S2:  82%|████████▏ | 327/397 [04:40<01:05,  1.07it/s]
# Dedup S1 and S2:  83%|████████▎ | 328/397 [04:41<01:10,  1.03s/it]
# Dedup S1 and S2:  83%|████████▎ | 329/397 [04:43<01:13,  1.08s/it]
# Dedup S1 and S2:  83%|████████▎ | 330/397 [04:44<01:14,  1.11s/it]
# Dedup S1 and S2:  83%|████████▎ | 331/397 [04:45<01:16,  1.15s/it]
# Dedup S1 and S2:  84%|████████▎ | 332/397 [04:46<01:19,  1.23s/it]
# Dedup S1 and S2:  84%|████████▍ | 333/397 [04:48<01:17,  1.21s/it]
# Dedup S1 and S2:  84%|████████▍ | 334/397 [04:49<01:15,  1.20s/it]
# Dedup S1 and S2:  84%|████████▍ | 335/397 [04:50<01:06,  1.08s/it]
# Dedup S1 and S2:  85%|████████▍ | 336/397 [04:50<01:00,  1.01it/s]
# Dedup S1 and S2:  85%|████████▍ | 337/397 [04:51<00:55,  1.08it/s]
# Dedup S1 and S2:  85%|████████▌ | 338/397 [04:52<00:52,  1.13it/s]
# Dedup S1 and S2:  85%|████████▌ | 339/397 [04:53<00:49,  1.18it/s]
# Dedup S1 and S2:  86%|████████▌ | 340/397 [04:53<00:46,  1.21it/s]
# Dedup S1 and S2:  86%|████████▌ | 341/397 [04:55<00:51,  1.09it/s]
# Dedup S1 and S2:  86%|████████▌ | 342/397 [04:55<00:48,  1.14it/s]
# Dedup S1 and S2:  86%|████████▋ | 343/397 [04:56<00:45,  1.18it/s]
# Dedup S1 and S2:  87%|████████▋ | 344/397 [04:57<00:43,  1.22it/s]
# Dedup S1 and S2:  87%|████████▋ | 345/397 [04:58<00:42,  1.22it/s]
# Dedup S1 and S2:  87%|████████▋ | 346/397 [04:58<00:41,  1.24it/s]
# Dedup S1 and S2:  87%|████████▋ | 347/397 [04:59<00:40,  1.24it/s]
# Dedup S1 and S2:  88%|████████▊ | 348/397 [05:00<00:44,  1.10it/s]
# Dedup S1 and S2:  88%|████████▊ | 349/397 [05:01<00:41,  1.14it/s]
# Dedup S1 and S2:  88%|████████▊ | 350/397 [05:02<00:40,  1.17it/s]
# Dedup S1 and S2:  88%|████████▊ | 351/397 [05:03<00:38,  1.20it/s]
# Dedup S1 and S2:  89%|████████▊ | 352/397 [05:04<00:37,  1.22it/s]
# Dedup S1 and S2:  89%|████████▉ | 353/397 [05:04<00:35,  1.23it/s]
# Dedup S1 and S2:  89%|████████▉ | 354/397 [05:05<00:34,  1.24it/s]
# Dedup S1 and S2:  89%|████████▉ | 355/397 [05:06<00:37,  1.11it/s]
# Dedup S1 and S2:  90%|████████▉ | 356/397 [05:07<00:35,  1.16it/s]
# Dedup S1 and S2:  90%|████████▉ | 357/397 [05:08<00:33,  1.19it/s]
# Dedup S1 and S2:  90%|█████████ | 358/397 [05:09<00:31,  1.22it/s]
# Dedup S1 and S2:  90%|█████████ | 359/397 [05:09<00:30,  1.24it/s]
# Dedup S1 and S2:  91%|█████████ | 360/397 [05:10<00:29,  1.25it/s]
# Dedup S1 and S2:  91%|█████████ | 361/397 [05:11<00:28,  1.27it/s]
# Dedup S1 and S2:  91%|█████████ | 362/397 [05:12<00:31,  1.11it/s]
# Dedup S1 and S2:  91%|█████████▏| 363/397 [05:13<00:29,  1.15it/s]
# Dedup S1 and S2:  92%|█████████▏| 364/397 [05:14<00:28,  1.17it/s]
# Dedup S1 and S2:  92%|█████████▏| 365/397 [05:14<00:26,  1.20it/s]
# Dedup S1 and S2:  92%|█████████▏| 366/397 [05:15<00:25,  1.21it/s]
# Dedup S1 and S2:  92%|█████████▏| 367/397 [05:16<00:24,  1.23it/s]
# Dedup S1 and S2:  93%|█████████▎| 368/397 [05:17<00:23,  1.25it/s]
# Dedup S1 and S2:  93%|█████████▎| 369/397 [05:18<00:25,  1.09it/s]
# Dedup S1 and S2:  93%|█████████▎| 370/397 [05:19<00:23,  1.13it/s]
# Dedup S1 and S2:  93%|█████████▎| 371/397 [05:20<00:22,  1.16it/s]
# Dedup S1 and S2:  94%|█████████▎| 372/397 [05:20<00:20,  1.20it/s]
# Dedup S1 and S2:  94%|█████████▍| 373/397 [05:21<00:19,  1.20it/s]
# Dedup S1 and S2:  94%|█████████▍| 374/397 [05:22<00:18,  1.22it/s]
# Dedup S1 and S2:  94%|█████████▍| 375/397 [05:23<00:17,  1.23it/s]
# Dedup S1 and S2:  95%|█████████▍| 376/397 [05:24<00:19,  1.08it/s]
# Dedup S1 and S2:  95%|█████████▍| 377/397 [05:25<00:19,  1.00it/s]
# Dedup S1 and S2:  95%|█████████▌| 378/397 [05:26<00:19,  1.05s/it]
# Dedup S1 and S2:  95%|█████████▌| 379/397 [05:28<00:19,  1.10s/it]
# Dedup S1 and S2:  96%|█████████▌| 380/397 [05:29<00:19,  1.14s/it]
# Dedup S1 and S2:  96%|█████████▌| 381/397 [05:30<00:18,  1.15s/it]
# Dedup S1 and S2:  96%|█████████▌| 382/397 [05:31<00:17,  1.14s/it]
# Dedup S1 and S2:  96%|█████████▋| 383/397 [05:32<00:15,  1.14s/it]
# Dedup S1 and S2:  97%|█████████▋| 384/397 [05:33<00:13,  1.02s/it]
# Dedup S1 and S2:  97%|█████████▋| 385/397 [05:34<00:12,  1.05s/it]
# Dedup S1 and S2:  97%|█████████▋| 386/397 [05:35<00:10,  1.04it/s]
# Dedup S1 and S2:  97%|█████████▋| 387/397 [05:36<00:10,  1.01s/it]
# Dedup S1 and S2:  98%|█████████▊| 388/397 [05:37<00:08,  1.08it/s]
# Dedup S1 and S2:  98%|█████████▊| 389/397 [05:38<00:07,  1.02it/s]
# Dedup S1 and S2:  98%|█████████▊| 390/397 [05:39<00:06,  1.09it/s]
# Dedup S1 and S2:  98%|█████████▊| 391/397 [05:40<00:05,  1.01it/s]
# Dedup S1 and S2:  99%|█████████▊| 392/397 [05:41<00:04,  1.09it/s]
# Dedup S1 and S2:  99%|█████████▉| 393/397 [05:42<00:03,  1.02it/s]
# Dedup S1 and S2:  99%|█████████▉| 394/397 [05:42<00:02,  1.09it/s]
# Dedup S1 and S2:  99%|█████████▉| 395/397 [05:44<00:01,  1.02it/s]
# Dedup S1 and S2: 100%|█████████▉| 396/397 [05:45<00:01,  1.01s/it]
# Dedup S1 and S2: 100%|██████████| 397/397 [05:46<00:00,  1.15it/s]
#
# Gathering results: 100%|██████████| 2/2 [00:00<00:00, 16.48it/s]
#
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (806 / 810) | Bytes (2321280000 / 2286720000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_600_600/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_600_600/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:15<01:16, 15.27s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (749 / 810) | Bytes (2157120000 / 2286720000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_600_600/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_600_600/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:33<01:05, 16.27s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (701 / 810) | Bytes (2018880000 / 2286720000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_600_600/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_600_600/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:52<00:50, 16.83s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (0 / 810) | Bytes (0 / 2286720000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_600_600/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_600_600/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:11<00:34, 17.48s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (0 / 810) | Bytes (0 / 2286720000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_600_600/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_600_600/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:29<00:17, 17.92s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (0 / 810) | Bytes (0 / 2286720000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_600_600/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_600_600/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:48<00:00, 18.02s/it]
# None

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        700,
        700,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Dedup S1 and S2:  65%|██████▌   | 192/294 [02:58<01:49,  1.07s/it]
#
# Dedup S1 and S2:  66%|██████▌   | 193/294 [02:59<01:41,  1.00s/it]
#
# Dedup S1 and S2:  66%|██████▌   | 194/294 [03:00<01:35,  1.04it/s]
#
# Dedup S1 and S2:  66%|██████▋   | 195/294 [03:01<01:31,  1.08it/s]
#
# Dedup S1 and S2:  67%|██████▋   | 196/294 [03:02<01:28,  1.11it/s]
#
# Dedup S1 and S2:  67%|██████▋   | 197/294 [03:03<01:26,  1.12it/s]
#
# Dedup S1 and S2:  67%|██████▋   | 198/294 [03:04<01:38,  1.03s/it]
#
# Dedup S1 and S2:  68%|██████▊   | 199/294 [03:05<01:32,  1.03it/s]
#
# Dedup S1 and S2:  68%|██████▊   | 200/294 [03:06<01:27,  1.07it/s]
#
# Dedup S1 and S2:  68%|██████▊   | 201/294 [03:06<01:24,  1.11it/s]
#
# Dedup S1 and S2:  69%|██████▊   | 202/294 [03:07<01:20,  1.14it/s]
#
# Dedup S1 and S2:  69%|██████▉   | 203/294 [03:08<01:19,  1.15it/s]
#
# Dedup S1 and S2:  69%|██████▉   | 204/294 [03:09<01:30,  1.00s/it]
#
# Dedup S1 and S2:  70%|██████▉   | 205/294 [03:10<01:24,  1.05it/s]
#
# Dedup S1 and S2:  70%|███████   | 206/294 [03:11<01:21,  1.08it/s]
#
# Dedup S1 and S2:  70%|███████   | 207/294 [03:12<01:18,  1.11it/s]
#
# Dedup S1 and S2:  71%|███████   | 208/294 [03:13<01:15,  1.13it/s]
#
# Dedup S1 and S2:  71%|███████   | 209/294 [03:14<01:14,  1.14it/s]
#
# Dedup S1 and S2:  71%|███████▏  | 210/294 [03:15<01:23,  1.00it/s]
#
# Dedup S1 and S2:  72%|███████▏  | 211/294 [03:16<01:19,  1.05it/s]
#
# Dedup S1 and S2:  72%|███████▏  | 212/294 [03:17<01:15,  1.08it/s]
#
# Dedup S1 and S2:  72%|███████▏  | 213/294 [03:17<01:13,  1.10it/s]
#
# Dedup S1 and S2:  73%|███████▎  | 214/294 [03:18<01:11,  1.12it/s]
#
# Dedup S1 and S2:  73%|███████▎  | 215/294 [03:19<01:09,  1.14it/s]
#
# Dedup S1 and S2:  73%|███████▎  | 216/294 [03:21<01:19,  1.02s/it]
#
# Dedup S1 and S2:  74%|███████▍  | 217/294 [03:21<01:14,  1.04it/s]
#
# Dedup S1 and S2:  74%|███████▍  | 218/294 [03:22<01:11,  1.06it/s]
#
# Dedup S1 and S2:  74%|███████▍  | 219/294 [03:23<01:07,  1.10it/s]
#
# Dedup S1 and S2:  75%|███████▍  | 220/294 [03:24<01:06,  1.12it/s]
#
# Dedup S1 and S2:  75%|███████▌  | 221/294 [03:25<01:04,  1.13it/s]
#
# Dedup S1 and S2:  76%|███████▌  | 222/294 [03:26<01:12,  1.00s/it]
#
# Dedup S1 and S2:  76%|███████▌  | 223/294 [03:27<01:07,  1.05it/s]
#
# Dedup S1 and S2:  76%|███████▌  | 224/294 [03:28<01:04,  1.09it/s]
#
# Dedup S1 and S2:  77%|███████▋  | 225/294 [03:29<01:01,  1.12it/s]
#
# Dedup S1 and S2:  77%|███████▋  | 226/294 [03:29<00:59,  1.14it/s]
#
# Dedup S1 and S2:  77%|███████▋  | 227/294 [03:30<00:58,  1.15it/s]
#
# Dedup S1 and S2:  78%|███████▊  | 228/294 [03:32<01:05,  1.01it/s]
#
# Dedup S1 and S2:  78%|███████▊  | 229/294 [03:32<01:01,  1.06it/s]
#
# Dedup S1 and S2:  78%|███████▊  | 230/294 [03:33<00:59,  1.08it/s]
#
# Dedup S1 and S2:  79%|███████▊  | 231/294 [03:34<00:57,  1.09it/s]
#
# Dedup S1 and S2:  79%|███████▉  | 232/294 [03:35<00:55,  1.11it/s]
#
# Dedup S1 and S2:  79%|███████▉  | 233/294 [03:36<00:54,  1.12it/s]
#
# Dedup S1 and S2:  80%|███████▉  | 234/294 [03:37<01:00,  1.01s/it]
#
# Dedup S1 and S2:  80%|███████▉  | 235/294 [03:38<00:56,  1.04it/s]
#
# Dedup S1 and S2:  80%|████████  | 236/294 [03:39<00:54,  1.07it/s]
#
# Dedup S1 and S2:  81%|████████  | 237/294 [03:40<00:51,  1.10it/s]
#
# Dedup S1 and S2:  81%|████████  | 238/294 [03:41<00:49,  1.12it/s]
#
# Dedup S1 and S2:  81%|████████▏ | 239/294 [03:41<00:47,  1.15it/s]
#
# Dedup S1 and S2:  82%|████████▏ | 240/294 [03:43<00:53,  1.01it/s]
#
# Dedup S1 and S2:  82%|████████▏ | 241/294 [03:44<00:58,  1.10s/it]
#
# Dedup S1 and S2:  82%|████████▏ | 242/294 [03:45<00:59,  1.15s/it]
#
# Dedup S1 and S2:  83%|████████▎ | 243/294 [03:47<01:00,  1.19s/it]
#
# Dedup S1 and S2:  83%|████████▎ | 244/294 [03:48<01:01,  1.22s/it]
#
# Dedup S1 and S2:  83%|████████▎ | 245/294 [03:49<01:00,  1.24s/it]
#
# Dedup S1 and S2:  84%|████████▎ | 246/294 [03:51<01:00,  1.26s/it]
#
# Dedup S1 and S2:  84%|████████▍ | 247/294 [03:51<00:52,  1.12s/it]
#
# Dedup S1 and S2:  84%|████████▍ | 248/294 [03:52<00:47,  1.04s/it]
#
# Dedup S1 and S2:  85%|████████▍ | 249/294 [03:53<00:44,  1.02it/s]
#
# Dedup S1 and S2:  85%|████████▌ | 250/294 [03:54<00:41,  1.06it/s]
#
# Dedup S1 and S2:  85%|████████▌ | 251/294 [03:55<00:40,  1.07it/s]
#
# Dedup S1 and S2:  86%|████████▌ | 252/294 [03:56<00:44,  1.05s/it]
#
# Dedup S1 and S2:  86%|████████▌ | 253/294 [03:57<00:40,  1.01it/s]
#
# Dedup S1 and S2:  86%|████████▋ | 254/294 [03:58<00:37,  1.06it/s]
#
# Dedup S1 and S2:  87%|████████▋ | 255/294 [03:59<00:35,  1.10it/s]
#
# Dedup S1 and S2:  87%|████████▋ | 256/294 [03:59<00:33,  1.12it/s]
#
# Dedup S1 and S2:  87%|████████▋ | 257/294 [04:00<00:32,  1.14it/s]
#
# Dedup S1 and S2:  88%|████████▊ | 258/294 [04:02<00:35,  1.00it/s]
#
# Dedup S1 and S2:  88%|████████▊ | 259/294 [04:02<00:33,  1.05it/s]
#
# Dedup S1 and S2:  88%|████████▊ | 260/294 [04:03<00:31,  1.08it/s]
#
# Dedup S1 and S2:  89%|████████▉ | 261/294 [04:04<00:29,  1.11it/s]
#
# Dedup S1 and S2:  89%|████████▉ | 262/294 [04:05<00:28,  1.12it/s]
#
# Dedup S1 and S2:  89%|████████▉ | 263/294 [04:06<00:26,  1.15it/s]
#
# Dedup S1 and S2:  90%|████████▉ | 264/294 [04:07<00:29,  1.01it/s]
#
# Dedup S1 and S2:  90%|█████████ | 265/294 [04:08<00:27,  1.06it/s]
#
# Dedup S1 and S2:  90%|█████████ | 266/294 [04:09<00:25,  1.10it/s]
#
# Dedup S1 and S2:  91%|█████████ | 267/294 [04:10<00:23,  1.13it/s]
#
# Dedup S1 and S2:  91%|█████████ | 268/294 [04:10<00:22,  1.14it/s]
#
# Dedup S1 and S2:  91%|█████████▏| 269/294 [04:11<00:21,  1.16it/s]
#
# Dedup S1 and S2:  92%|█████████▏| 270/294 [04:13<00:23,  1.01it/s]
#
# Dedup S1 and S2:  92%|█████████▏| 271/294 [04:13<00:21,  1.08it/s]
#
# Dedup S1 and S2:  93%|█████████▎| 272/294 [04:14<00:19,  1.12it/s]
#
# Dedup S1 and S2:  93%|█████████▎| 273/294 [04:15<00:18,  1.15it/s]
#
# Dedup S1 and S2:  93%|█████████▎| 274/294 [04:16<00:16,  1.18it/s]
#
# Dedup S1 and S2:  94%|█████████▎| 275/294 [04:17<00:15,  1.19it/s]
#
# Dedup S1 and S2:  94%|█████████▍| 276/294 [04:18<00:17,  1.02it/s]
#
# Dedup S1 and S2:  94%|█████████▍| 277/294 [04:19<00:18,  1.07s/it]
#
# Dedup S1 and S2:  95%|█████████▍| 278/294 [04:20<00:18,  1.15s/it]
#
# Dedup S1 and S2:  95%|█████████▍| 279/294 [04:22<00:17,  1.19s/it]
#
# Dedup S1 and S2:  95%|█████████▌| 280/294 [04:23<00:16,  1.20s/it]
#
# Dedup S1 and S2:  96%|█████████▌| 281/294 [04:24<00:15,  1.23s/it]
#
# Dedup S1 and S2:  96%|█████████▌| 282/294 [04:26<00:15,  1.26s/it]
#
# Dedup S1 and S2:  96%|█████████▋| 283/294 [04:26<00:12,  1.12s/it]
#
# Dedup S1 and S2:  97%|█████████▋| 284/294 [04:28<00:11,  1.17s/it]
#
# Dedup S1 and S2:  97%|█████████▋| 285/294 [04:29<00:09,  1.06s/it]
#
# Dedup S1 and S2:  97%|█████████▋| 286/294 [04:30<00:08,  1.11s/it]
#
# Dedup S1 and S2:  98%|█████████▊| 287/294 [04:31<00:07,  1.02s/it]
#
# Dedup S1 and S2:  98%|█████████▊| 288/294 [04:32<00:06,  1.09s/it]
#
# Dedup S1 and S2:  98%|█████████▊| 289/294 [04:33<00:05,  1.02s/it]
#
# Dedup S1 and S2:  99%|█████████▊| 290/294 [04:34<00:04,  1.10s/it]
#
# Dedup S1 and S2:  99%|█████████▉| 291/294 [04:35<00:03,  1.02s/it]
#
# Dedup S1 and S2:  99%|█████████▉| 292/294 [04:36<00:02,  1.11s/it]
#
# Dedup S1 and S2: 100%|█████████▉| 293/294 [04:37<00:01,  1.17s/it]
#
# Dedup S1 and S2: 100%|██████████| 294/294 [04:39<00:00,  1.05it/s]
#
#
# Gathering results: 100%|██████████| 2/2 [00:00<00:00, 25.96it/s]
#
#
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (592 / 600) | Bytes (2320640000 / 2304960000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_700_700/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_700_700/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:17<01:25, 17.15s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (550 / 600) | Bytes (2156000000 / 2304960000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_700_700/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_700_700/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:34<01:08, 17.21s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (512 / 600) | Bytes (2007040000 / 2304960000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_700_700/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_700_700/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:51<00:51, 17.08s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (0 / 600) | Bytes (0 / 2304960000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_700_700/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_700_700/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:10<00:35, 17.70s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (0 / 600) | Bytes (0 / 2304960000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_700_700/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_700_700/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:29<00:18, 18.00s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (0 / 600) | Bytes (0 / 2304960000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_700_700/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_700_700/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:48<00:00, 18.32s/it]
# None

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        800,
        800,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Splitting model layers with size > 16 MB into blocks of size 800 X 800 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 56.83it/s]
#
#
#
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
#
#
# Splitting model into blocks:  81%|████████  | 21/26 [00:00<00:00, 198.74it/s]
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 60.24it/s]
#
#
#
# Dedup S1:   0%|          | 0/270 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1:   0%|          | 1/270 [00:01<05:52,  1.31s/it]
#
#
# Dedup S1:   1%|          | 2/270 [00:02<05:47,  1.30s/it]
#
#
# Dedup S1:   1%|          | 3/270 [00:04<07:07,  1.60s/it]
#
#
# Dedup S1:   1%|▏         | 4/270 [00:07<08:00,  1.81s/it]
#
#
# Dedup S1:   2%|▏         | 5/270 [00:09<08:47,  1.99s/it]
#
#
# Dedup S1:   2%|▏         | 6/270 [00:11<09:15,  2.11s/it]
#
#
# Dedup S1:   3%|▎         | 7/270 [00:13<08:09,  1.86s/it]
#
#
# Dedup S1:   3%|▎         | 8/270 [00:14<07:23,  1.69s/it]
#
#
# Dedup S1:   3%|▎         | 9/270 [00:16<08:09,  1.88s/it]
#
#
# Dedup S1:   4%|▎         | 10/270 [00:19<08:29,  1.96s/it]
#
#
# Dedup S1:   4%|▍         | 11/270 [00:21<08:35,  1.99s/it]
#
#
# Dedup S1:   4%|▍         | 12/270 [00:23<08:34,  1.99s/it]
#
#
# Dedup S1:   5%|▍         | 13/270 [00:24<07:24,  1.73s/it]
#
#
# Dedup S1:   5%|▌         | 14/270 [00:25<06:35,  1.54s/it]
#
#
# Dedup S1:   6%|▌         | 15/270 [00:27<07:15,  1.71s/it]
#
#
# Dedup S1:   6%|▌         | 16/270 [00:29<07:41,  1.82s/it]
#
#
# Dedup S1:   6%|▋         | 17/270 [00:31<07:52,  1.87s/it]
#
#
# Dedup S1:   7%|▋         | 18/270 [00:33<07:59,  1.90s/it]
#
#
# Dedup S1:   7%|▋         | 19/270 [00:34<06:53,  1.65s/it]
#
#
# Dedup S1:   7%|▋         | 20/270 [00:35<06:08,  1.47s/it]
#
#
# Dedup S1:   8%|▊         | 21/270 [00:37<06:46,  1.63s/it]
#
#
# Dedup S1:   8%|▊         | 22/270 [00:39<07:12,  1.75s/it]
#
#
# Dedup S1:   9%|▊         | 23/270 [00:41<07:29,  1.82s/it]
#
#
# Dedup S1:   9%|▉         | 24/270 [00:43<07:38,  1.87s/it]
#
#
# Dedup S1:   9%|▉         | 25/270 [00:44<06:33,  1.60s/it]
#
#
# Dedup S1:  10%|▉         | 26/270 [00:45<05:48,  1.43s/it]
#
#
# Dedup S1:  10%|█         | 27/270 [00:47<06:24,  1.58s/it]
#
#
# Dedup S1:  10%|█         | 28/270 [00:49<06:50,  1.69s/it]
#
#
# Dedup S1:  11%|█         | 29/270 [00:51<07:09,  1.78s/it]
#
#
# Dedup S1:  11%|█         | 30/270 [00:53<07:14,  1.81s/it]
#
#
# Dedup S1:  11%|█▏        | 31/270 [00:54<06:11,  1.55s/it]
#
#
# Dedup S1:  12%|█▏        | 32/270 [00:55<05:29,  1.39s/it]
#
#
# Dedup S1:  12%|█▏        | 33/270 [00:56<04:58,  1.26s/it]
#
#
# Dedup S1:  13%|█▎        | 34/270 [00:57<04:36,  1.17s/it]
#
#
# Dedup S1:  13%|█▎        | 35/270 [00:58<04:19,  1.11s/it]
#
#
# Dedup S1:  13%|█▎        | 36/270 [00:59<05:05,  1.31s/it]
#
#
# Dedup S1:  14%|█▎        | 37/270 [01:00<04:40,  1.20s/it]
#
#
# Dedup S1:  14%|█▍        | 38/270 [01:01<04:19,  1.12s/it]
#
#
# Dedup S1:  14%|█▍        | 39/270 [01:02<04:08,  1.08s/it]
#
#
# Dedup S1:  15%|█▍        | 40/270 [01:03<03:59,  1.04s/it]
#
#
# Dedup S1:  15%|█▌        | 41/270 [01:04<03:53,  1.02s/it]
#
#
# Dedup S1:  16%|█▌        | 42/270 [01:06<04:42,  1.24s/it]
#
#
# Dedup S1:  16%|█▌        | 43/270 [01:07<04:19,  1.14s/it]
#
#
# Dedup S1:  16%|█▋        | 44/270 [01:08<04:05,  1.08s/it]
#
#
# Dedup S1:  17%|█▋        | 45/270 [01:09<03:53,  1.04s/it]
#
#
# Dedup S1:  17%|█▋        | 46/270 [01:10<03:45,  1.01s/it]
#
#
# Dedup S1:  17%|█▋        | 47/270 [01:11<03:38,  1.02it/s]
#
#
# Dedup S1:  18%|█▊        | 48/270 [01:12<04:25,  1.20s/it]
#
#
# Dedup S1:  18%|█▊        | 49/270 [01:13<04:04,  1.11s/it]
#
#
# Dedup S1:  19%|█▊        | 50/270 [01:14<03:54,  1.07s/it]
#
#
# Dedup S1:  19%|█▉        | 51/270 [01:15<03:45,  1.03s/it]
#
#
# Dedup S1:  19%|█▉        | 52/270 [01:16<03:36,  1.01it/s]
#
#
# Dedup S1:  20%|█▉        | 53/270 [01:17<03:28,  1.04it/s]
#
#
# Dedup S1:  20%|██        | 54/270 [01:19<04:14,  1.18s/it]
#
#
# Dedup S1:  20%|██        | 55/270 [01:19<03:53,  1.09s/it]
#
#
# Dedup S1:  21%|██        | 56/270 [01:20<03:40,  1.03s/it]
#
#
# Dedup S1:  21%|██        | 57/270 [01:21<03:30,  1.01it/s]
#
#
# Dedup S1:  21%|██▏       | 58/270 [01:22<03:21,  1.05it/s]
#
#
# Dedup S1:  22%|██▏       | 59/270 [01:23<03:15,  1.08it/s]
#
#
# Dedup S1:  22%|██▏       | 60/270 [01:25<03:58,  1.13s/it]
#
#
# Dedup S1:  23%|██▎       | 61/270 [01:25<03:40,  1.05s/it]
#
#
# Dedup S1:  23%|██▎       | 62/270 [01:26<03:28,  1.00s/it]
#
#
# Dedup S1:  23%|██▎       | 63/270 [01:27<03:20,  1.03it/s]
#
#
# Dedup S1:  24%|██▎       | 64/270 [01:28<03:13,  1.07it/s]
#
#
# Dedup S1:  24%|██▍       | 65/270 [01:29<03:06,  1.10it/s]
#
#
# Dedup S1:  24%|██▍       | 66/270 [01:31<03:47,  1.12s/it]
#
#
# Dedup S1:  25%|██▍       | 67/270 [01:31<03:28,  1.03s/it]
#
#
# Dedup S1:  25%|██▌       | 68/270 [01:32<03:18,  1.02it/s]
#
#
# Dedup S1:  26%|██▌       | 69/270 [01:33<03:09,  1.06it/s]
#
#
# Dedup S1:  26%|██▌       | 70/270 [01:34<03:02,  1.09it/s]
#
#
# Dedup S1:  26%|██▋       | 71/270 [01:35<02:58,  1.11it/s]
#
#
# Dedup S1:  27%|██▋       | 72/270 [01:36<03:35,  1.09s/it]
#
#
# Dedup S1:  27%|██▋       | 73/270 [01:37<03:17,  1.00s/it]
#
#
# Dedup S1:  27%|██▋       | 74/270 [01:38<03:07,  1.04it/s]
#
#
# Dedup S1:  28%|██▊       | 75/270 [01:39<03:00,  1.08it/s]
#
#
# Dedup S1:  28%|██▊       | 76/270 [01:40<02:54,  1.11it/s]
#
#
# Dedup S1:  29%|██▊       | 77/270 [01:41<02:50,  1.13it/s]
#
#
# Dedup S1:  29%|██▉       | 78/270 [01:42<03:24,  1.06s/it]
#
#
# Dedup S1:  29%|██▉       | 79/270 [01:43<03:08,  1.02it/s]
#
#
# Dedup S1:  30%|██▉       | 80/270 [01:44<02:55,  1.08it/s]
#
#
# Dedup S1:  30%|███       | 81/270 [01:44<02:47,  1.13it/s]
#
#
# Dedup S1:  30%|███       | 82/270 [01:45<02:40,  1.17it/s]
#
#
# Dedup S1:  31%|███       | 83/270 [01:46<02:35,  1.20it/s]
#
#
# Dedup S1:  31%|███       | 84/270 [01:47<03:06,  1.00s/it]
#
#
# Dedup S1:  31%|███▏      | 85/270 [01:48<02:52,  1.07it/s]
#
#
# Dedup S1:  32%|███▏      | 86/270 [01:49<02:42,  1.13it/s]
#
#
# Dedup S1:  32%|███▏      | 87/270 [01:50<02:36,  1.17it/s]
#
#
# Dedup S1:  33%|███▎      | 88/270 [01:50<02:31,  1.20it/s]
#
#
# Dedup S1:  33%|███▎      | 89/270 [01:51<02:27,  1.23it/s]
#
#
# Dedup S1:  33%|███▎      | 90/270 [01:53<02:54,  1.03it/s]
#
#
# Dedup S1:  34%|███▎      | 91/270 [01:53<02:40,  1.12it/s]
#
#
# Dedup S1:  34%|███▍      | 92/270 [01:54<02:31,  1.17it/s]
#
#
# Dedup S1:  34%|███▍      | 93/270 [01:55<02:24,  1.23it/s]
#
#
# Dedup S1:  35%|███▍      | 94/270 [01:56<02:19,  1.27it/s]
#
#
# Dedup S1:  35%|███▌      | 95/270 [01:56<02:15,  1.30it/s]
#
#
# Dedup S1:  36%|███▌      | 96/270 [01:58<02:42,  1.07it/s]
#
#
# Dedup S1:  36%|███▌      | 97/270 [01:58<02:29,  1.16it/s]
#
#
# Dedup S1:  36%|███▋      | 98/270 [01:59<02:21,  1.22it/s]
#
#
# Dedup S1:  37%|███▋      | 99/270 [02:00<02:15,  1.26it/s]
#
#
# Dedup S1:  37%|███▋      | 100/270 [02:00<02:10,  1.30it/s]
#
#
# Dedup S1:  37%|███▋      | 101/270 [02:01<02:08,  1.32it/s]
#
#
# Dedup S1:  38%|███▊      | 102/270 [02:02<02:34,  1.09it/s]
#
#
# Dedup S1:  38%|███▊      | 103/270 [02:03<02:22,  1.17it/s]
#
#
# Dedup S1:  39%|███▊      | 104/270 [02:04<02:15,  1.23it/s]
#
#
# Dedup S1:  39%|███▉      | 105/270 [02:05<02:10,  1.27it/s]
#
#
# Dedup S1:  39%|███▉      | 106/270 [02:05<02:05,  1.31it/s]
#
#
# Dedup S1:  40%|███▉      | 107/270 [02:06<02:01,  1.34it/s]
#
#
# Dedup S1:  40%|████      | 108/270 [02:07<02:25,  1.11it/s]
#
#
# Dedup S1:  40%|████      | 109/270 [02:08<02:13,  1.20it/s]
#
#
# Dedup S1:  41%|████      | 110/270 [02:09<02:05,  1.28it/s]
#
#
# Dedup S1:  41%|████      | 111/270 [02:09<02:01,  1.31it/s]
#
#
# Dedup S1:  41%|████▏     | 112/270 [02:10<01:56,  1.35it/s]
#
#
# Dedup S1:  42%|████▏     | 113/270 [02:11<01:53,  1.39it/s]
#
#
# Dedup S1:  42%|████▏     | 114/270 [02:12<02:17,  1.14it/s]
#
#
# Dedup S1:  43%|████▎     | 115/270 [02:13<02:06,  1.22it/s]
#
#
# Dedup S1:  43%|████▎     | 116/270 [02:13<01:59,  1.29it/s]
#
#
# Dedup S1:  43%|████▎     | 117/270 [02:14<01:55,  1.33it/s]
#
#
# Dedup S1:  44%|████▎     | 118/270 [02:15<01:51,  1.36it/s]
#
#
# Dedup S1:  44%|████▍     | 119/270 [02:15<01:48,  1.40it/s]
#
#
# Dedup S1:  44%|████▍     | 120/270 [02:17<02:08,  1.17it/s]
#
#
# Dedup S1:  45%|████▍     | 121/270 [02:17<01:59,  1.25it/s]
#
#
# Dedup S1:  45%|████▌     | 122/270 [02:18<01:51,  1.33it/s]
#
#
# Dedup S1:  46%|████▌     | 123/270 [02:18<01:46,  1.38it/s]
#
#
# Dedup S1:  46%|████▌     | 124/270 [02:19<01:42,  1.42it/s]
#
#
# Dedup S1:  46%|████▋     | 125/270 [02:20<01:39,  1.46it/s]
#
#
# Dedup S1:  47%|████▋     | 126/270 [02:21<01:58,  1.22it/s]
#
#
# Dedup S1:  47%|████▋     | 127/270 [02:22<01:49,  1.30it/s]
#
#
# Dedup S1:  47%|████▋     | 128/270 [02:22<01:43,  1.37it/s]
#
#
# Dedup S1:  48%|████▊     | 129/270 [02:23<01:39,  1.42it/s]
#
#
# Dedup S1:  48%|████▊     | 130/270 [02:23<01:36,  1.46it/s]
#
#
# Dedup S1:  49%|████▊     | 131/270 [02:24<01:33,  1.49it/s]
#
#
# Dedup S1:  49%|████▉     | 132/270 [02:25<01:49,  1.26it/s]
#
#
# Dedup S1:  49%|████▉     | 133/270 [02:26<01:41,  1.35it/s]
#
#
# Dedup S1:  50%|████▉     | 134/270 [02:26<01:36,  1.42it/s]
#
#
# Dedup S1:  50%|█████     | 135/270 [02:27<01:32,  1.47it/s]
#
#
# Dedup S1:  50%|█████     | 136/270 [02:28<01:28,  1.52it/s]
#
#
# Dedup S1:  51%|█████     | 137/270 [02:28<01:25,  1.56it/s]
#
#
# Dedup S1:  51%|█████     | 138/270 [02:29<01:39,  1.33it/s]
#
#
# Dedup S1:  51%|█████▏    | 139/270 [02:30<01:31,  1.43it/s]
#
#
# Dedup S1:  52%|█████▏    | 140/270 [02:30<01:26,  1.51it/s]
#
#
# Dedup S1:  52%|█████▏    | 141/270 [02:31<01:22,  1.56it/s]
#
#
# Dedup S1:  53%|█████▎    | 142/270 [02:32<01:20,  1.60it/s]
#
#
# Dedup S1:  53%|█████▎    | 143/270 [02:32<01:18,  1.63it/s]
#
#
# Dedup S1:  53%|█████▎    | 144/270 [02:33<01:30,  1.40it/s]
#
#
# Dedup S1:  54%|█████▎    | 145/270 [02:34<01:23,  1.50it/s]
#
#
# Dedup S1:  54%|█████▍    | 146/270 [02:34<01:19,  1.57it/s]
#
#
# Dedup S1:  54%|█████▍    | 147/270 [02:35<01:16,  1.62it/s]
#
#
# Dedup S1:  55%|█████▍    | 148/270 [02:35<01:13,  1.66it/s]
#
#
# Dedup S1:  55%|█████▌    | 149/270 [02:36<01:11,  1.70it/s]
#
#
# Dedup S1:  56%|█████▌    | 150/270 [02:37<01:21,  1.46it/s]
#
#
# Dedup S1:  56%|█████▌    | 151/270 [02:37<01:15,  1.57it/s]
#
#
# Dedup S1:  56%|█████▋    | 152/270 [02:38<01:11,  1.65it/s]
#
#
# Dedup S1:  57%|█████▋    | 153/270 [02:39<01:09,  1.69it/s]
#
#
# Dedup S1:  57%|█████▋    | 154/270 [02:39<01:06,  1.73it/s]
#
#
# Dedup S1:  57%|█████▋    | 155/270 [02:40<01:04,  1.77it/s]
#
#
# Dedup S1:  58%|█████▊    | 156/270 [02:40<01:13,  1.54it/s]
#
#
# Dedup S1:  58%|█████▊    | 157/270 [02:41<01:08,  1.64it/s]
#
#
# Dedup S1:  59%|█████▊    | 158/270 [02:41<01:05,  1.71it/s]
#
#
# Dedup S1:  59%|█████▉    | 159/270 [02:42<01:03,  1.75it/s]
#
#
# Dedup S1:  59%|█████▉    | 160/270 [02:43<01:01,  1.80it/s]
#
#
# Dedup S1:  60%|█████▉    | 161/270 [02:43<00:59,  1.84it/s]
#
#
# Dedup S1:  60%|██████    | 162/270 [02:44<01:07,  1.59it/s]
#
#
# Dedup S1:  60%|██████    | 163/270 [02:44<01:03,  1.70it/s]
#
#
# Dedup S1:  61%|██████    | 164/270 [02:45<00:59,  1.78it/s]
#
#
# Dedup S1:  61%|██████    | 165/270 [02:45<00:57,  1.84it/s]
#
#
# Dedup S1:  61%|██████▏   | 166/270 [02:46<00:54,  1.89it/s]
#
#
# Dedup S1:  62%|██████▏   | 167/270 [02:46<00:53,  1.93it/s]
#
#
# Dedup S1:  62%|██████▏   | 168/270 [02:47<01:09,  1.48it/s]
#
#
# Dedup S1:  63%|██████▎   | 169/270 [02:48<01:02,  1.60it/s]
#
#
# Dedup S1:  63%|██████▎   | 170/270 [02:48<00:58,  1.71it/s]
#
#
# Dedup S1:  63%|██████▎   | 171/270 [02:49<00:55,  1.80it/s]
#
#
# Dedup S1:  64%|██████▎   | 172/270 [02:49<00:52,  1.88it/s]
#
#
# Dedup S1:  64%|██████▍   | 173/270 [02:50<00:49,  1.96it/s]
#
#
# Dedup S1:  64%|██████▍   | 174/270 [02:51<00:55,  1.72it/s]
#
#
# Dedup S1:  65%|██████▍   | 175/270 [02:51<00:51,  1.83it/s]
#
#
# Dedup S1:  65%|██████▌   | 176/270 [02:52<00:48,  1.93it/s]
#
#
# Dedup S1:  66%|██████▌   | 177/270 [02:52<00:46,  2.00it/s]
#
#
# Dedup S1:  66%|██████▌   | 178/270 [02:52<00:44,  2.06it/s]
#
#
# Dedup S1:  66%|██████▋   | 179/270 [02:53<00:43,  2.11it/s]
#
#
# Dedup S1:  67%|██████▋   | 180/270 [02:54<00:47,  1.88it/s]
#
#
# Dedup S1:  67%|██████▋   | 181/270 [02:54<00:44,  1.99it/s]
#
#
# Dedup S1:  67%|██████▋   | 182/270 [02:54<00:42,  2.06it/s]
#
#
# Dedup S1:  68%|██████▊   | 183/270 [02:55<00:41,  2.11it/s]
#
#
# Dedup S1:  68%|██████▊   | 184/270 [02:55<00:39,  2.18it/s]
#
#
# Dedup S1:  69%|██████▊   | 185/270 [02:56<00:38,  2.23it/s]
#
#
# Dedup S1:  69%|██████▉   | 186/270 [02:56<00:42,  1.97it/s]
#
#
# Dedup S1:  69%|██████▉   | 187/270 [02:57<00:39,  2.09it/s]
#
#
# Dedup S1:  70%|██████▉   | 188/270 [02:57<00:37,  2.17it/s]
#
#
# Dedup S1:  70%|███████   | 189/270 [02:58<00:36,  2.25it/s]
#
#
# Dedup S1:  70%|███████   | 190/270 [02:58<00:34,  2.32it/s]
#
#
# Dedup S1:  71%|███████   | 191/270 [02:58<00:33,  2.37it/s]
#
#
# Dedup S1:  71%|███████   | 192/270 [02:59<00:37,  2.10it/s]
#
#
# Dedup S1:  71%|███████▏  | 193/270 [02:59<00:34,  2.23it/s]
#
#
# Dedup S1:  72%|███████▏  | 194/270 [03:00<00:32,  2.31it/s]
#
#
# Dedup S1:  72%|███████▏  | 195/270 [03:00<00:31,  2.39it/s]
#
#
# Dedup S1:  73%|███████▎  | 196/270 [03:01<00:29,  2.47it/s]
#
#
# Dedup S1:  73%|███████▎  | 197/270 [03:01<00:29,  2.50it/s]
#
#
# Dedup S1:  73%|███████▎  | 198/270 [03:01<00:31,  2.27it/s]
#
#
# Dedup S1:  74%|███████▎  | 199/270 [03:02<00:30,  2.35it/s]
#
#
# Dedup S1:  74%|███████▍  | 200/270 [03:02<00:28,  2.43it/s]
#
#
# Dedup S1:  74%|███████▍  | 201/270 [03:03<00:27,  2.50it/s]
#
#
# Dedup S1:  75%|███████▍  | 202/270 [03:03<00:26,  2.55it/s]
#
#
# Dedup S1:  75%|███████▌  | 203/270 [03:03<00:25,  2.62it/s]
#
#
# Dedup S1:  76%|███████▌  | 204/270 [03:04<00:27,  2.38it/s]
#
#
# Dedup S1:  76%|███████▌  | 205/270 [03:04<00:26,  2.49it/s]
#
#
# Dedup S1:  76%|███████▋  | 206/270 [03:05<00:24,  2.59it/s]
#
#
# Dedup S1:  77%|███████▋  | 207/270 [03:05<00:23,  2.66it/s]
#
#
# Dedup S1:  77%|███████▋  | 208/270 [03:05<00:22,  2.72it/s]
#
#
# Dedup S1:  77%|███████▋  | 209/270 [03:06<00:21,  2.80it/s]
#
#
# Dedup S1:  78%|███████▊  | 210/270 [03:06<00:23,  2.56it/s]
#
#
# Dedup S1:  78%|███████▊  | 211/270 [03:06<00:21,  2.72it/s]
#
#
# Dedup S1:  79%|███████▊  | 212/270 [03:07<00:20,  2.79it/s]
#
#
# Dedup S1:  79%|███████▉  | 213/270 [03:07<00:19,  2.86it/s]
#
#
# Dedup S1:  79%|███████▉  | 214/270 [03:07<00:19,  2.92it/s]
#
#
# Dedup S1:  80%|███████▉  | 215/270 [03:08<00:18,  3.01it/s]
#
#
# Dedup S1:  80%|████████  | 216/270 [03:08<00:19,  2.81it/s]
#
#
# Dedup S1:  80%|████████  | 217/270 [03:08<00:19,  2.68it/s]
#
#
# Dedup S1:  81%|████████  | 218/270 [03:09<00:20,  2.60it/s]
#
#
# Dedup S1:  81%|████████  | 219/270 [03:09<00:20,  2.54it/s]
#
#
# Dedup S1:  81%|████████▏ | 220/270 [03:10<00:19,  2.56it/s]
#
#
# Dedup S1:  82%|████████▏ | 221/270 [03:10<00:19,  2.56it/s]
#
#
# Dedup S1:  82%|████████▏ | 222/270 [03:10<00:18,  2.61it/s]
#
#
# Dedup S1:  83%|████████▎ | 223/270 [03:11<00:16,  2.93it/s]
#
#
# Dedup S1:  83%|████████▎ | 224/270 [03:11<00:14,  3.18it/s]
#
#
# Dedup S1:  83%|████████▎ | 225/270 [03:11<00:13,  3.39it/s]
#
#
# Dedup S1:  84%|████████▎ | 226/270 [03:11<00:12,  3.58it/s]
#
#
# Dedup S1:  84%|████████▍ | 227/270 [03:12<00:11,  3.73it/s]
#
#
# Dedup S1:  84%|████████▍ | 228/270 [03:12<00:11,  3.53it/s]
#
#
# Dedup S1:  85%|████████▍ | 229/270 [03:12<00:10,  3.78it/s]
#
#
# Dedup S1:  85%|████████▌ | 230/270 [03:12<00:10,  3.98it/s]
#
#
# Dedup S1:  86%|████████▌ | 231/270 [03:13<00:09,  4.12it/s]
#
#
# Dedup S1:  86%|████████▌ | 232/270 [03:13<00:08,  4.23it/s]
#
#
# Dedup S1:  86%|████████▋ | 233/270 [03:13<00:08,  4.34it/s]
#
#
# Dedup S1:  87%|████████▋ | 234/270 [03:13<00:08,  4.15it/s]
#
#
# Dedup S1:  87%|████████▋ | 235/270 [03:14<00:08,  4.34it/s]
#
#
# Dedup S1:  87%|████████▋ | 236/270 [03:14<00:07,  4.50it/s]
#
#
# Dedup S1:  88%|████████▊ | 237/270 [03:14<00:07,  4.60it/s]
#
#
# Dedup S1:  88%|████████▊ | 238/270 [03:14<00:06,  4.76it/s]
#
#
# Dedup S1:  89%|████████▊ | 239/270 [03:14<00:06,  4.90it/s]
#
#
# Dedup S1:  89%|████████▉ | 240/270 [03:15<00:06,  4.87it/s]
#
#
# Dedup S1:  89%|████████▉ | 241/270 [03:15<00:05,  5.10it/s]
#
#
# Dedup S1:  90%|████████▉ | 242/270 [03:15<00:05,  5.28it/s]
#
#
# Dedup S1:  90%|█████████ | 243/270 [03:15<00:05,  5.33it/s]
#
#
# Dedup S1:  90%|█████████ | 244/270 [03:15<00:04,  5.48it/s]
#
#
# Dedup S1:  91%|█████████ | 245/270 [03:15<00:04,  5.62it/s]
#
#
# Dedup S1:  91%|█████████ | 246/270 [03:16<00:04,  5.67it/s]
#
#
# Dedup S1:  91%|█████████▏| 247/270 [03:16<00:03,  5.81it/s]
#
#
# Dedup S1:  92%|█████████▏| 248/270 [03:16<00:03,  5.92it/s]
#
#
# Dedup S1:  92%|█████████▏| 249/270 [03:16<00:03,  6.01it/s]
#
#
# Dedup S1:  93%|█████████▎| 250/270 [03:16<00:03,  6.15it/s]
#
#
# Dedup S1:  93%|█████████▎| 251/270 [03:16<00:03,  6.16it/s]
#
#
# Dedup S1:  93%|█████████▎| 252/270 [03:17<00:02,  6.31it/s]
#
#
# Dedup S1:  94%|█████████▎| 253/270 [03:17<00:02,  6.82it/s]
#
#
# Dedup S1:  94%|█████████▍| 254/270 [03:17<00:02,  7.32it/s]
#
#
# Dedup S1:  94%|█████████▍| 255/270 [03:17<00:01,  7.85it/s]
#
#
# Dedup S1:  95%|█████████▍| 256/270 [03:17<00:01,  8.07it/s]
#
#
# Dedup S1:  95%|█████████▌| 257/270 [03:17<00:01,  8.22it/s]
#
#
# Dedup S1:  96%|█████████▌| 259/270 [03:17<00:01,  9.04it/s]
#
#
# Dedup S1:  97%|█████████▋| 261/270 [03:17<00:00, 10.14it/s]
#
#
# Dedup S1:  97%|█████████▋| 263/270 [03:18<00:00, 11.59it/s]
#
#
# Dedup S1: 100%|██████████| 270/270 [03:18<00:00,  1.36it/s]
#
#
#
# Dedup S2:   0%|          | 0/282 [00:00<?, ?it/s]
#
#
# Dedup S2:   0%|          | 1/282 [00:01<06:26,  1.37s/it]
#
#
# Dedup S2:   1%|          | 2/282 [00:02<06:18,  1.35s/it]
#
#
# Dedup S2:   1%|          | 3/282 [00:04<07:35,  1.63s/it]
#
#
# Dedup S2:   1%|▏         | 4/282 [00:07<08:21,  1.81s/it]
#
#
# Dedup S2:   2%|▏         | 5/282 [00:09<08:53,  1.93s/it]
#
#
# Dedup S2:   2%|▏         | 6/282 [00:11<09:08,  1.99s/it]
#
#
# Dedup S2:   2%|▏         | 7/282 [00:12<08:02,  1.75s/it]
#
#
# Dedup S2:   3%|▎         | 8/282 [00:13<07:15,  1.59s/it]
#
#
# Dedup S2:   3%|▎         | 9/282 [00:16<08:03,  1.77s/it]
#
#
# Dedup S2:   4%|▎         | 10/282 [00:18<08:32,  1.88s/it]
#
#
# Dedup S2:   4%|▍         | 11/282 [00:20<08:53,  1.97s/it]
#
#
# Dedup S2:   4%|▍         | 12/282 [00:22<09:04,  2.02s/it]
#
#
# Dedup S2:   5%|▍         | 13/282 [00:23<07:54,  1.76s/it]
#
#
# Dedup S2:   5%|▍         | 14/282 [00:24<07:05,  1.59s/it]
#
#
# Dedup S2:   5%|▌         | 15/282 [00:27<07:50,  1.76s/it]
#
#
# Dedup S2:   6%|▌         | 16/282 [00:29<08:21,  1.88s/it]
#
#
# Dedup S2:   6%|▌         | 17/282 [00:31<08:51,  2.01s/it]
#
#
# Dedup S2:   6%|▋         | 18/282 [00:33<09:00,  2.05s/it]
#
#
# Dedup S2:   7%|▋         | 19/282 [00:34<07:45,  1.77s/it]
#
#
# Dedup S2:   7%|▋         | 20/282 [00:35<06:57,  1.60s/it]
#
#
# Dedup S2:   7%|▋         | 21/282 [00:38<07:35,  1.74s/it]
#
#
# Dedup S2:   8%|▊         | 22/282 [00:40<08:01,  1.85s/it]
#
#
# Dedup S2:   8%|▊         | 23/282 [00:42<08:17,  1.92s/it]
#
#
# Dedup S2:   9%|▊         | 24/282 [00:44<08:27,  1.97s/it]
#
#
# Dedup S2:   9%|▉         | 25/282 [00:45<07:22,  1.72s/it]
#
#
# Dedup S2:   9%|▉         | 26/282 [00:46<06:34,  1.54s/it]
#
#
# Dedup S2:  10%|▉         | 27/282 [00:48<07:16,  1.71s/it]
#
#
# Dedup S2:  10%|▉         | 28/282 [00:50<07:46,  1.83s/it]
#
#
# Dedup S2:  10%|█         | 29/282 [00:52<08:04,  1.92s/it]
#
#
# Dedup S2:  11%|█         | 30/282 [00:54<08:12,  1.95s/it]
#
#
# Dedup S2:  11%|█         | 31/282 [00:56<07:05,  1.69s/it]
#
#
# Dedup S2:  11%|█▏        | 32/282 [00:57<06:17,  1.51s/it]
#
#
# Dedup S2:  12%|█▏        | 33/282 [00:59<06:58,  1.68s/it]
#
#
# Dedup S2:  12%|█▏        | 34/282 [01:01<07:23,  1.79s/it]
#
#
# Dedup S2:  12%|█▏        | 35/282 [01:03<07:40,  1.86s/it]
#
#
# Dedup S2:  13%|█▎        | 36/282 [01:05<07:48,  1.90s/it]
#
#
# Dedup S2:  13%|█▎        | 37/282 [01:06<06:40,  1.64s/it]
#
#
# Dedup S2:  13%|█▎        | 38/282 [01:07<05:57,  1.46s/it]
#
#
# Dedup S2:  14%|█▍        | 39/282 [01:09<06:33,  1.62s/it]
#
#
# Dedup S2:  14%|█▍        | 40/282 [01:11<06:57,  1.72s/it]
#
#
# Dedup S2:  15%|█▍        | 41/282 [01:13<07:12,  1.80s/it]
#
#
# Dedup S2:  15%|█▍        | 42/282 [01:15<07:19,  1.83s/it]
#
#
# Dedup S2:  15%|█▌        | 43/282 [01:16<06:17,  1.58s/it]
#
#
# Dedup S2:  16%|█▌        | 44/282 [01:17<05:35,  1.41s/it]
#
#
# Dedup S2:  16%|█▌        | 45/282 [01:18<05:07,  1.30s/it]
#
#
# Dedup S2:  16%|█▋        | 46/282 [01:19<04:47,  1.22s/it]
#
#
# Dedup S2:  17%|█▋        | 47/282 [01:20<04:32,  1.16s/it]
#
#
# Dedup S2:  17%|█▋        | 48/282 [01:22<05:21,  1.37s/it]
#
#
# Dedup S2:  17%|█▋        | 49/282 [01:23<04:53,  1.26s/it]
#
#
# Dedup S2:  18%|█▊        | 50/282 [01:24<04:34,  1.18s/it]
#
#
# Dedup S2:  18%|█▊        | 51/282 [01:25<04:22,  1.14s/it]
#
#
# Dedup S2:  18%|█▊        | 52/282 [01:26<04:12,  1.10s/it]
#
#
# Dedup S2:  19%|█▉        | 53/282 [01:27<04:03,  1.06s/it]
#
#
# Dedup S2:  19%|█▉        | 54/282 [01:29<04:53,  1.29s/it]
#
#
# Dedup S2:  20%|█▉        | 55/282 [01:30<04:32,  1.20s/it]
#
#
# Dedup S2:  20%|█▉        | 56/282 [01:30<04:15,  1.13s/it]
#
#
# Dedup S2:  20%|██        | 57/282 [01:31<04:06,  1.09s/it]
#
#
# Dedup S2:  21%|██        | 58/282 [01:32<03:56,  1.06s/it]
#
#
# Dedup S2:  21%|██        | 59/282 [01:33<03:51,  1.04s/it]
#
#
# Dedup S2:  21%|██▏       | 60/282 [01:35<04:40,  1.26s/it]
#
#
# Dedup S2:  22%|██▏       | 61/282 [01:36<04:18,  1.17s/it]
#
#
# Dedup S2:  22%|██▏       | 62/282 [01:37<04:00,  1.09s/it]
#
#
# Dedup S2:  22%|██▏       | 63/282 [01:38<03:49,  1.05s/it]
#
#
# Dedup S2:  23%|██▎       | 64/282 [01:39<03:41,  1.01s/it]
#
#
# Dedup S2:  23%|██▎       | 65/282 [01:40<03:35,  1.01it/s]
#
#
# Dedup S2:  23%|██▎       | 66/282 [01:42<04:20,  1.20s/it]
#
#
# Dedup S2:  24%|██▍       | 67/282 [01:43<03:59,  1.12s/it]
#
#
# Dedup S2:  24%|██▍       | 68/282 [01:43<03:46,  1.06s/it]
#
#
# Dedup S2:  24%|██▍       | 69/282 [01:44<03:40,  1.04s/it]
#
#
# Dedup S2:  25%|██▍       | 70/282 [01:45<03:33,  1.01s/it]
#
#
# Dedup S2:  25%|██▌       | 71/282 [01:46<03:28,  1.01it/s]
#
#
# Dedup S2:  26%|██▌       | 72/282 [01:48<04:12,  1.20s/it]
#
#
# Dedup S2:  26%|██▌       | 73/282 [01:49<03:53,  1.12s/it]
#
#
# Dedup S2:  26%|██▌       | 74/282 [01:50<03:39,  1.05s/it]
#
#
# Dedup S2:  27%|██▋       | 75/282 [01:51<03:27,  1.00s/it]
#
#
# Dedup S2:  27%|██▋       | 76/282 [01:52<03:19,  1.03it/s]
#
#
# Dedup S2:  27%|██▋       | 77/282 [01:52<03:12,  1.07it/s]
#
#
# Dedup S2:  28%|██▊       | 78/282 [01:54<03:55,  1.15s/it]
#
#
# Dedup S2:  28%|██▊       | 79/282 [01:55<03:38,  1.08s/it]
#
#
# Dedup S2:  28%|██▊       | 80/282 [01:56<03:27,  1.03s/it]
#
#
# Dedup S2:  29%|██▊       | 81/282 [01:57<03:21,  1.00s/it]
#
#
# Dedup S2:  29%|██▉       | 82/282 [01:58<03:14,  1.03it/s]
#
#
# Dedup S2:  29%|██▉       | 83/282 [01:59<03:08,  1.05it/s]
#
#
# Dedup S2:  30%|██▉       | 84/282 [02:00<03:46,  1.14s/it]
#
#
# Dedup S2:  30%|███       | 85/282 [02:01<03:28,  1.06s/it]
#
#
# Dedup S2:  30%|███       | 86/282 [02:02<03:16,  1.00s/it]
#
#
# Dedup S2:  31%|███       | 87/282 [02:03<03:08,  1.04it/s]
#
#
# Dedup S2:  31%|███       | 88/282 [02:04<03:00,  1.08it/s]
#
#
# Dedup S2:  32%|███▏      | 89/282 [02:05<02:54,  1.10it/s]
#
#
# Dedup S2:  32%|███▏      | 90/282 [02:06<03:31,  1.10s/it]
#
#
# Dedup S2:  32%|███▏      | 91/282 [02:07<03:14,  1.02s/it]
#
#
# Dedup S2:  33%|███▎      | 92/282 [02:08<03:01,  1.04it/s]
#
#
# Dedup S2:  33%|███▎      | 93/282 [02:09<02:54,  1.09it/s]
#
#
# Dedup S2:  33%|███▎      | 94/282 [02:09<02:47,  1.12it/s]
#
#
# Dedup S2:  34%|███▎      | 95/282 [02:10<02:42,  1.15it/s]
#
#
# Dedup S2:  34%|███▍      | 96/282 [02:12<03:16,  1.06s/it]
#
#
# Dedup S2:  34%|███▍      | 97/282 [02:13<03:01,  1.02it/s]
#
#
# Dedup S2:  35%|███▍      | 98/282 [02:13<02:51,  1.07it/s]
#
#
# Dedup S2:  35%|███▌      | 99/282 [02:14<02:46,  1.10it/s]
#
#
# Dedup S2:  35%|███▌      | 100/282 [02:15<02:40,  1.13it/s]
#
#
# Dedup S2:  36%|███▌      | 101/282 [02:16<02:34,  1.17it/s]
#
#
# Dedup S2:  36%|███▌      | 102/282 [02:17<03:06,  1.03s/it]
#
#
# Dedup S2:  37%|███▋      | 103/282 [02:18<02:51,  1.04it/s]
#
#
# Dedup S2:  37%|███▋      | 104/282 [02:19<02:42,  1.10it/s]
#
#
# Dedup S2:  37%|███▋      | 105/282 [02:20<02:35,  1.14it/s]
#
#
# Dedup S2:  38%|███▊      | 106/282 [02:20<02:29,  1.17it/s]
#
#
# Dedup S2:  38%|███▊      | 107/282 [02:21<02:25,  1.20it/s]
#
#
# Dedup S2:  38%|███▊      | 108/282 [02:23<02:53,  1.00it/s]
#
#
# Dedup S2:  39%|███▊      | 109/282 [02:23<02:40,  1.08it/s]
#
#
# Dedup S2:  39%|███▉      | 110/282 [02:24<02:30,  1.14it/s]
#
#
# Dedup S2:  39%|███▉      | 111/282 [02:25<02:23,  1.19it/s]
#
#
# Dedup S2:  40%|███▉      | 112/282 [02:26<02:18,  1.23it/s]
#
#
# Dedup S2:  40%|████      | 113/282 [02:26<02:14,  1.26it/s]
#
#
# Dedup S2:  40%|████      | 114/282 [02:28<02:40,  1.05it/s]
#
#
# Dedup S2:  41%|████      | 115/282 [02:28<02:28,  1.13it/s]
#
#
# Dedup S2:  41%|████      | 116/282 [02:29<02:21,  1.17it/s]
#
#
# Dedup S2:  41%|████▏     | 117/282 [02:30<02:15,  1.22it/s]
#
#
# Dedup S2:  42%|████▏     | 118/282 [02:31<02:09,  1.26it/s]
#
#
# Dedup S2:  42%|████▏     | 119/282 [02:31<02:06,  1.29it/s]
#
#
# Dedup S2:  43%|████▎     | 120/282 [02:33<02:30,  1.08it/s]
#
#
# Dedup S2:  43%|████▎     | 121/282 [02:33<02:18,  1.16it/s]
#
#
# Dedup S2:  43%|████▎     | 122/282 [02:34<02:10,  1.22it/s]
#
#
# Dedup S2:  44%|████▎     | 123/282 [02:35<02:05,  1.26it/s]
#
#
# Dedup S2:  44%|████▍     | 124/282 [02:36<02:01,  1.30it/s]
#
#
# Dedup S2:  44%|████▍     | 125/282 [02:36<01:57,  1.33it/s]
#
#
# Dedup S2:  45%|████▍     | 126/282 [02:38<02:20,  1.11it/s]
#
#
# Dedup S2:  45%|████▌     | 127/282 [02:38<02:09,  1.19it/s]
#
#
# Dedup S2:  45%|████▌     | 128/282 [02:39<02:02,  1.25it/s]
#
#
# Dedup S2:  46%|████▌     | 129/282 [02:40<01:56,  1.31it/s]
#
#
# Dedup S2:  46%|████▌     | 130/282 [02:40<01:52,  1.36it/s]
#
#
# Dedup S2:  46%|████▋     | 131/282 [02:41<01:48,  1.40it/s]
#
#
# Dedup S2:  47%|████▋     | 132/282 [02:42<02:08,  1.17it/s]
#
#
# Dedup S2:  47%|████▋     | 133/282 [02:43<01:58,  1.26it/s]
#
#
# Dedup S2:  48%|████▊     | 134/282 [02:44<01:52,  1.32it/s]
#
#
# Dedup S2:  48%|████▊     | 135/282 [02:44<01:48,  1.35it/s]
#
#
# Dedup S2:  48%|████▊     | 136/282 [02:45<01:45,  1.39it/s]
#
#
# Dedup S2:  49%|████▊     | 137/282 [02:46<01:42,  1.41it/s]
#
#
# Dedup S2:  49%|████▉     | 138/282 [02:47<02:02,  1.18it/s]
#
#
# Dedup S2:  49%|████▉     | 139/282 [02:47<01:52,  1.27it/s]
#
#
# Dedup S2:  50%|████▉     | 140/282 [02:48<01:46,  1.33it/s]
#
#
# Dedup S2:  50%|█████     | 141/282 [02:49<01:42,  1.37it/s]
#
#
# Dedup S2:  50%|█████     | 142/282 [02:49<01:38,  1.42it/s]
#
#
# Dedup S2:  51%|█████     | 143/282 [02:50<01:34,  1.47it/s]
#
#
# Dedup S2:  51%|█████     | 144/282 [02:51<01:50,  1.25it/s]
#
#
# Dedup S2:  51%|█████▏    | 145/282 [02:52<01:42,  1.34it/s]
#
#
# Dedup S2:  52%|█████▏    | 146/282 [02:52<01:36,  1.41it/s]
#
#
# Dedup S2:  52%|█████▏    | 147/282 [02:53<01:32,  1.46it/s]
#
#
# Dedup S2:  52%|█████▏    | 148/282 [02:54<01:29,  1.50it/s]
#
#
# Dedup S2:  53%|█████▎    | 149/282 [02:54<01:27,  1.53it/s]
#
#
# Dedup S2:  53%|█████▎    | 150/282 [02:55<01:42,  1.29it/s]
#
#
# Dedup S2:  54%|█████▎    | 151/282 [02:56<01:35,  1.38it/s]
#
#
# Dedup S2:  54%|█████▍    | 152/282 [02:56<01:30,  1.43it/s]
#
#
# Dedup S2:  54%|█████▍    | 153/282 [02:57<01:26,  1.49it/s]
#
#
# Dedup S2:  55%|█████▍    | 154/282 [02:58<01:24,  1.52it/s]
#
#
# Dedup S2:  55%|█████▍    | 155/282 [02:58<01:21,  1.55it/s]
#
#
# Dedup S2:  55%|█████▌    | 156/282 [02:59<01:35,  1.32it/s]
#
#
# Dedup S2:  56%|█████▌    | 157/282 [03:00<01:27,  1.42it/s]
#
#
# Dedup S2:  56%|█████▌    | 158/282 [03:01<01:23,  1.48it/s]
#
#
# Dedup S2:  56%|█████▋    | 159/282 [03:01<01:20,  1.53it/s]
#
#
# Dedup S2:  57%|█████▋    | 160/282 [03:02<01:16,  1.59it/s]
#
#
# Dedup S2:  57%|█████▋    | 161/282 [03:02<01:14,  1.63it/s]
#
#
# Dedup S2:  57%|█████▋    | 162/282 [03:03<01:26,  1.39it/s]
#
#
# Dedup S2:  58%|█████▊    | 163/282 [03:04<01:19,  1.49it/s]
#
#
# Dedup S2:  58%|█████▊    | 164/282 [03:04<01:15,  1.57it/s]
#
#
# Dedup S2:  59%|█████▊    | 165/282 [03:05<01:11,  1.63it/s]
#
#
# Dedup S2:  59%|█████▉    | 166/282 [03:05<01:08,  1.69it/s]
#
#
# Dedup S2:  59%|█████▉    | 167/282 [03:06<01:05,  1.75it/s]
#
#
# Dedup S2:  60%|█████▉    | 168/282 [03:07<01:16,  1.50it/s]
#
#
# Dedup S2:  60%|█████▉    | 169/282 [03:07<01:10,  1.60it/s]
#
#
# Dedup S2:  60%|██████    | 170/282 [03:08<01:07,  1.67it/s]
#
#
# Dedup S2:  61%|██████    | 171/282 [03:08<01:04,  1.73it/s]
#
#
# Dedup S2:  61%|██████    | 172/282 [03:09<01:02,  1.77it/s]
#
#
# Dedup S2:  61%|██████▏   | 173/282 [03:10<01:00,  1.82it/s]
#
#
# Dedup S2:  62%|██████▏   | 174/282 [03:10<01:08,  1.58it/s]
#
#
# Dedup S2:  62%|██████▏   | 175/282 [03:11<01:03,  1.68it/s]
#
#
# Dedup S2:  62%|██████▏   | 176/282 [03:11<01:00,  1.77it/s]
#
#
# Dedup S2:  63%|██████▎   | 177/282 [03:12<00:57,  1.82it/s]
#
#
# Dedup S2:  63%|██████▎   | 178/282 [03:12<00:55,  1.88it/s]
#
#
# Dedup S2:  63%|██████▎   | 179/282 [03:13<00:53,  1.91it/s]
#
#
# Dedup S2:  64%|██████▍   | 180/282 [03:14<01:01,  1.66it/s]
#
#
# Dedup S2:  64%|██████▍   | 181/282 [03:14<00:57,  1.76it/s]
#
#
# Dedup S2:  65%|██████▍   | 182/282 [03:15<00:54,  1.83it/s]
#
#
# Dedup S2:  65%|██████▍   | 183/282 [03:15<00:52,  1.88it/s]
#
#
# Dedup S2:  65%|██████▌   | 184/282 [03:16<00:50,  1.94it/s]
#
#
# Dedup S2:  66%|██████▌   | 185/282 [03:16<00:49,  1.96it/s]
#
#
# Dedup S2:  66%|██████▌   | 186/282 [03:17<00:56,  1.71it/s]
#
#
# Dedup S2:  66%|██████▋   | 187/282 [03:17<00:51,  1.83it/s]
#
#
# Dedup S2:  67%|██████▋   | 188/282 [03:18<00:49,  1.91it/s]
#
#
# Dedup S2:  67%|██████▋   | 189/282 [03:18<00:47,  1.96it/s]
#
#
# Dedup S2:  67%|██████▋   | 190/282 [03:19<00:45,  2.02it/s]
#
#
# Dedup S2:  68%|██████▊   | 191/282 [03:19<00:43,  2.07it/s]
#
#
# Dedup S2:  68%|██████▊   | 192/282 [03:20<00:49,  1.83it/s]
#
#
# Dedup S2:  68%|██████▊   | 193/282 [03:20<00:45,  1.95it/s]
#
#
# Dedup S2:  69%|██████▉   | 194/282 [03:21<00:43,  2.04it/s]
#
#
# Dedup S2:  69%|██████▉   | 195/282 [03:21<00:41,  2.10it/s]
#
#
# Dedup S2:  70%|██████▉   | 196/282 [03:22<00:39,  2.15it/s]
#
#
# Dedup S2:  70%|██████▉   | 197/282 [03:22<00:38,  2.20it/s]
#
#
# Dedup S2:  70%|███████   | 198/282 [03:23<00:43,  1.94it/s]
#
#
# Dedup S2:  71%|███████   | 199/282 [03:23<00:40,  2.05it/s]
#
#
# Dedup S2:  71%|███████   | 200/282 [03:24<00:38,  2.12it/s]
#
#
# Dedup S2:  71%|███████▏  | 201/282 [03:24<00:37,  2.18it/s]
#
#
# Dedup S2:  72%|███████▏  | 202/282 [03:24<00:35,  2.24it/s]
#
#
# Dedup S2:  72%|███████▏  | 203/282 [03:25<00:34,  2.31it/s]
#
#
# Dedup S2:  72%|███████▏  | 204/282 [03:25<00:37,  2.06it/s]
#
#
# Dedup S2:  73%|███████▎  | 205/282 [03:26<00:35,  2.19it/s]
#
#
# Dedup S2:  73%|███████▎  | 206/282 [03:26<00:33,  2.27it/s]
#
#
# Dedup S2:  73%|███████▎  | 207/282 [03:27<00:32,  2.34it/s]
#
#
# Dedup S2:  74%|███████▍  | 208/282 [03:27<00:30,  2.43it/s]
#
#
# Dedup S2:  74%|███████▍  | 209/282 [03:27<00:29,  2.49it/s]
#
#
# Dedup S2:  74%|███████▍  | 210/282 [03:28<00:32,  2.24it/s]
#
#
# Dedup S2:  75%|███████▍  | 211/282 [03:28<00:30,  2.34it/s]
#
#
# Dedup S2:  75%|███████▌  | 212/282 [03:29<00:28,  2.42it/s]
#
#
# Dedup S2:  76%|███████▌  | 213/282 [03:29<00:27,  2.47it/s]
#
#
# Dedup S2:  76%|███████▌  | 214/282 [03:29<00:27,  2.50it/s]
#
#
# Dedup S2:  76%|███████▌  | 215/282 [03:30<00:26,  2.56it/s]
#
#
# Dedup S2:  77%|███████▋  | 216/282 [03:30<00:28,  2.30it/s]
#
#
# Dedup S2:  77%|███████▋  | 217/282 [03:31<00:26,  2.43it/s]
#
#
# Dedup S2:  77%|███████▋  | 218/282 [03:31<00:25,  2.53it/s]
#
#
# Dedup S2:  78%|███████▊  | 219/282 [03:31<00:24,  2.60it/s]
#
#
# Dedup S2:  78%|███████▊  | 220/282 [03:32<00:23,  2.69it/s]
#
#
# Dedup S2:  78%|███████▊  | 221/282 [03:32<00:22,  2.74it/s]
#
#
# Dedup S2:  79%|███████▊  | 222/282 [03:33<00:23,  2.56it/s]
#
#
# Dedup S2:  79%|███████▉  | 223/282 [03:33<00:21,  2.69it/s]
#
#
# Dedup S2:  79%|███████▉  | 224/282 [03:33<00:21,  2.75it/s]
#
#
# Dedup S2:  80%|███████▉  | 225/282 [03:34<00:20,  2.80it/s]
#
#
# Dedup S2:  80%|████████  | 226/282 [03:34<00:19,  2.88it/s]
#
#
# Dedup S2:  80%|████████  | 227/282 [03:34<00:18,  2.94it/s]
#
#
# Dedup S2:  81%|████████  | 228/282 [03:35<00:19,  2.75it/s]
#
#
# Dedup S2:  81%|████████  | 229/282 [03:35<00:20,  2.64it/s]
#
#
# Dedup S2:  82%|████████▏ | 230/282 [03:36<00:21,  2.47it/s]
#
#
# Dedup S2:  82%|████████▏ | 231/282 [03:36<00:21,  2.33it/s]
#
#
# Dedup S2:  82%|████████▏ | 232/282 [03:37<00:23,  2.14it/s]
#
#
# Dedup S2:  83%|████████▎ | 233/282 [03:37<00:21,  2.26it/s]
#
#
# Dedup S2:  83%|████████▎ | 234/282 [03:37<00:20,  2.36it/s]
#
#
# Dedup S2:  83%|████████▎ | 235/282 [03:38<00:17,  2.69it/s]
#
#
# Dedup S2:  84%|████████▎ | 236/282 [03:38<00:15,  2.96it/s]
#
#
# Dedup S2:  84%|████████▍ | 237/282 [03:38<00:14,  3.21it/s]
#
#
# Dedup S2:  84%|████████▍ | 238/282 [03:38<00:13,  3.37it/s]
#
#
# Dedup S2:  85%|████████▍ | 239/282 [03:39<00:12,  3.56it/s]
#
#
# Dedup S2:  85%|████████▌ | 240/282 [03:39<00:12,  3.39it/s]
#
#
# Dedup S2:  85%|████████▌ | 241/282 [03:39<00:11,  3.65it/s]
#
#
# Dedup S2:  86%|████████▌ | 242/282 [03:39<00:10,  3.82it/s]
#
#
# Dedup S2:  86%|████████▌ | 243/282 [03:40<00:09,  3.94it/s]
#
#
# Dedup S2:  87%|████████▋ | 244/282 [03:40<00:09,  4.02it/s]
#
#
# Dedup S2:  87%|████████▋ | 245/282 [03:40<00:08,  4.15it/s]
#
#
# Dedup S2:  87%|████████▋ | 246/282 [03:40<00:08,  4.00it/s]
#
#
# Dedup S2:  88%|████████▊ | 247/282 [03:41<00:08,  4.19it/s]
#
#
# Dedup S2:  88%|████████▊ | 248/282 [03:41<00:07,  4.38it/s]
#
#
# Dedup S2:  88%|████████▊ | 249/282 [03:41<00:07,  4.50it/s]
#
#
# Dedup S2:  89%|████████▊ | 250/282 [03:41<00:06,  4.66it/s]
#
#
# Dedup S2:  89%|████████▉ | 251/282 [03:41<00:06,  4.76it/s]
#
#
# Dedup S2:  89%|████████▉ | 252/282 [03:42<00:06,  4.71it/s]
#
#
# Dedup S2:  90%|████████▉ | 253/282 [03:42<00:05,  4.92it/s]
#
#
# Dedup S2:  90%|█████████ | 254/282 [03:42<00:05,  5.12it/s]
#
#
# Dedup S2:  90%|█████████ | 255/282 [03:42<00:05,  5.18it/s]
#
#
# Dedup S2:  91%|█████████ | 256/282 [03:42<00:04,  5.34it/s]
#
#
# Dedup S2:  91%|█████████ | 257/282 [03:43<00:04,  5.40it/s]
#
#
# Dedup S2:  91%|█████████▏| 258/282 [03:43<00:04,  5.46it/s]
#
#
# Dedup S2:  92%|█████████▏| 259/282 [03:43<00:04,  5.67it/s]
#
#
# Dedup S2:  92%|█████████▏| 260/282 [03:43<00:03,  5.77it/s]
#
#
# Dedup S2:  93%|█████████▎| 261/282 [03:43<00:03,  5.84it/s]
#
#
# Dedup S2:  93%|█████████▎| 262/282 [03:43<00:03,  5.93it/s]
#
#
# Dedup S2:  93%|█████████▎| 263/282 [03:44<00:03,  6.06it/s]
#
#
# Dedup S2:  94%|█████████▎| 264/282 [03:44<00:02,  6.42it/s]
#
#
# Dedup S2:  94%|█████████▍| 265/282 [03:44<00:02,  6.71it/s]
#
#
# Dedup S2:  94%|█████████▍| 266/282 [03:44<00:02,  7.22it/s]
#
#
# Dedup S2:  95%|█████████▍| 267/282 [03:44<00:01,  7.56it/s]
#
#
# Dedup S2:  95%|█████████▌| 268/282 [03:44<00:01,  7.79it/s]
#
#
# Dedup S2:  95%|█████████▌| 269/282 [03:44<00:01,  7.96it/s]
#
#
# Dedup S2:  96%|█████████▌| 271/282 [03:44<00:01,  8.76it/s]
#
#
# Dedup S2:  97%|█████████▋| 273/282 [03:45<00:00,  9.81it/s]
#
#
# Dedup S2:  98%|█████████▊| 275/282 [03:45<00:00, 11.10it/s]
#
#
# Dedup S2: 100%|██████████| 282/282 [03:45<00:00,  1.25it/s]
#
#
#
# Dedup S1 and S2:   0%|          | 0/270 [00:00<?, ?it/s]
#
#
# Dedup S1 and S2:   0%|          | 1/270 [00:01<05:54,  1.32s/it]
#
#
# Dedup S1 and S2:   1%|          | 2/270 [00:02<05:53,  1.32s/it]
#
#
# Dedup S1 and S2:   1%|          | 3/270 [00:05<07:17,  1.64s/it]
#
#
# Dedup S1 and S2:   1%|▏         | 4/270 [00:07<08:04,  1.82s/it]
#
#
# Dedup S1 and S2:   2%|▏         | 5/270 [00:09<08:39,  1.96s/it]
#
#
# Dedup S1 and S2:   2%|▏         | 6/270 [00:11<09:02,  2.06s/it]
#
#
# Dedup S1 and S2:   3%|▎         | 7/270 [00:13<07:58,  1.82s/it]
#
#
# Dedup S1 and S2:   3%|▎         | 8/270 [00:14<07:16,  1.66s/it]
#
#
# Dedup S1 and S2:   3%|▎         | 9/270 [00:16<08:06,  1.86s/it]
#
#
# Dedup S1 and S2:   4%|▎         | 10/270 [00:18<08:32,  1.97s/it]
#
#
# Dedup S1 and S2:   4%|▍         | 11/270 [00:21<08:49,  2.04s/it]
#
#
# Dedup S1 and S2:   4%|▍         | 12/270 [00:23<09:00,  2.10s/it]
#
#
# Dedup S1 and S2:   5%|▍         | 13/270 [00:24<07:54,  1.85s/it]
#
#
# Dedup S1 and S2:   5%|▌         | 14/270 [00:25<07:09,  1.68s/it]
#
#
# Dedup S1 and S2:   6%|▌         | 15/270 [00:28<07:52,  1.85s/it]
#
#
# Dedup S1 and S2:   6%|▌         | 16/270 [00:30<08:19,  1.97s/it]
#
#
# Dedup S1 and S2:   6%|▋         | 17/270 [00:32<08:36,  2.04s/it]
#
#
# Dedup S1 and S2:   7%|▋         | 18/270 [00:34<08:49,  2.10s/it]
#
#
# Dedup S1 and S2:   7%|▋         | 19/270 [00:36<07:42,  1.84s/it]
#
#
# Dedup S1 and S2:   7%|▋         | 20/270 [00:37<07:04,  1.70s/it]
#
#
# Dedup S1 and S2:   8%|▊         | 21/270 [00:39<07:48,  1.88s/it]
#
#
# Dedup S1 and S2:   8%|▊         | 22/270 [00:42<08:16,  2.00s/it]
#
#
# Dedup S1 and S2:   9%|▊         | 23/270 [00:44<08:35,  2.09s/it]
#
#
# Dedup S1 and S2:   9%|▉         | 24/270 [00:46<08:48,  2.15s/it]
#
#
# Dedup S1 and S2:   9%|▉         | 25/270 [00:47<07:43,  1.89s/it]
#
#
# Dedup S1 and S2:  10%|▉         | 26/270 [00:49<06:58,  1.71s/it]
#
#
# Dedup S1 and S2:  10%|█         | 27/270 [00:51<07:39,  1.89s/it]
#
#
# Dedup S1 and S2:  10%|█         | 28/270 [00:53<08:07,  2.02s/it]
#
#
# Dedup S1 and S2:  11%|█         | 29/270 [00:56<08:22,  2.09s/it]
#
#
# Dedup S1 and S2:  11%|█         | 30/270 [00:58<08:31,  2.13s/it]
#
#
# Dedup S1 and S2:  11%|█▏        | 31/270 [00:59<07:29,  1.88s/it]
#
#
# Dedup S1 and S2:  12%|█▏        | 32/270 [01:00<06:46,  1.71s/it]
#
#
# Dedup S1 and S2:  12%|█▏        | 33/270 [01:02<06:17,  1.59s/it]
#
#
# Dedup S1 and S2:  13%|█▎        | 34/270 [01:03<05:55,  1.51s/it]
#
#
# Dedup S1 and S2:  13%|█▎        | 35/270 [01:04<05:39,  1.45s/it]
#
#
# Dedup S1 and S2:  13%|█▎        | 36/270 [01:07<06:31,  1.67s/it]
#
#
# Dedup S1 and S2:  14%|█▎        | 37/270 [01:08<06:02,  1.55s/it]
#
#
# Dedup S1 and S2:  14%|█▍        | 38/270 [01:09<05:45,  1.49s/it]
#
#
# Dedup S1 and S2:  14%|█▍        | 39/270 [01:11<05:31,  1.44s/it]
#
#
# Dedup S1 and S2:  15%|█▍        | 40/270 [01:12<05:22,  1.40s/it]
#
#
# Dedup S1 and S2:  15%|█▌        | 41/270 [01:13<05:14,  1.37s/it]
#
#
# Dedup S1 and S2:  16%|█▌        | 42/270 [01:15<06:13,  1.64s/it]
#
#
# Dedup S1 and S2:  16%|█▌        | 43/270 [01:17<05:48,  1.54s/it]
#
#
# Dedup S1 and S2:  16%|█▋        | 44/270 [01:18<05:35,  1.48s/it]
#
#
# Dedup S1 and S2:  17%|█▋        | 45/270 [01:19<05:23,  1.44s/it]
#
#
# Dedup S1 and S2:  17%|█▋        | 46/270 [01:21<05:16,  1.41s/it]
#
#
# Dedup S1 and S2:  17%|█▋        | 47/270 [01:22<05:08,  1.38s/it]
#
#
# Dedup S1 and S2:  18%|█▊        | 48/270 [01:24<06:04,  1.64s/it]
#
#
# Dedup S1 and S2:  18%|█▊        | 49/270 [01:26<05:41,  1.54s/it]
#
#
# Dedup S1 and S2:  19%|█▊        | 50/270 [01:27<05:25,  1.48s/it]
#
#
# Dedup S1 and S2:  19%|█▉        | 51/270 [01:28<05:15,  1.44s/it]
#
#
# Dedup S1 and S2:  19%|█▉        | 52/270 [01:30<05:06,  1.41s/it]
#
#
# Dedup S1 and S2:  20%|█▉        | 53/270 [01:31<05:00,  1.39s/it]
#
#
# Dedup S1 and S2:  20%|██        | 54/270 [01:33<05:55,  1.64s/it]
#
#
# Dedup S1 and S2:  20%|██        | 55/270 [01:35<05:31,  1.54s/it]
#
#
# Dedup S1 and S2:  21%|██        | 56/270 [01:36<05:18,  1.49s/it]
#
#
# Dedup S1 and S2:  21%|██        | 57/270 [01:37<05:07,  1.45s/it]
#
#
# Dedup S1 and S2:  21%|██▏       | 58/270 [01:39<04:59,  1.41s/it]
#
#
# Dedup S1 and S2:  22%|██▏       | 59/270 [01:40<04:50,  1.38s/it]
#
#
# Dedup S1 and S2:  22%|██▏       | 60/270 [01:42<05:43,  1.64s/it]
#
#
# Dedup S1 and S2:  23%|██▎       | 61/270 [01:43<05:22,  1.54s/it]
#
#
# Dedup S1 and S2:  23%|██▎       | 62/270 [01:45<05:07,  1.48s/it]
#
#
# Dedup S1 and S2:  23%|██▎       | 63/270 [01:46<04:58,  1.44s/it]
#
#
# Dedup S1 and S2:  24%|██▎       | 64/270 [01:47<04:48,  1.40s/it]
#
#
# Dedup S1 and S2:  24%|██▍       | 65/270 [01:49<04:43,  1.38s/it]
#
#
# Dedup S1 and S2:  24%|██▍       | 66/270 [01:51<05:33,  1.63s/it]
#
#
# Dedup S1 and S2:  25%|██▍       | 67/270 [01:52<05:10,  1.53s/it]
#
#
# Dedup S1 and S2:  25%|██▌       | 68/270 [01:54<04:56,  1.47s/it]
#
#
# Dedup S1 and S2:  26%|██▌       | 69/270 [01:55<04:46,  1.42s/it]
#
#
# Dedup S1 and S2:  26%|██▌       | 70/270 [01:56<04:37,  1.39s/it]
#
#
# Dedup S1 and S2:  26%|██▋       | 71/270 [01:57<04:30,  1.36s/it]
#
#
# Dedup S1 and S2:  27%|██▋       | 72/270 [02:00<05:22,  1.63s/it]
#
#
# Dedup S1 and S2:  27%|██▋       | 73/270 [02:01<05:01,  1.53s/it]
#
#
# Dedup S1 and S2:  27%|██▋       | 74/270 [02:02<04:48,  1.47s/it]
#
#
# Dedup S1 and S2:  28%|██▊       | 75/270 [02:04<04:39,  1.43s/it]
#
#
# Dedup S1 and S2:  28%|██▊       | 76/270 [02:05<04:31,  1.40s/it]
#
#
# Dedup S1 and S2:  29%|██▊       | 77/270 [02:06<04:25,  1.38s/it]
#
#
# Dedup S1 and S2:  29%|██▉       | 78/270 [02:09<05:12,  1.63s/it]
#
#
# Dedup S1 and S2:  29%|██▉       | 79/270 [02:10<04:52,  1.53s/it]
#
#
# Dedup S1 and S2:  30%|██▉       | 80/270 [02:11<04:38,  1.47s/it]
#
#
# Dedup S1 and S2:  30%|███       | 81/270 [02:13<04:30,  1.43s/it]
#
#
# Dedup S1 and S2:  30%|███       | 82/270 [02:14<04:23,  1.40s/it]
#
#
# Dedup S1 and S2:  31%|███       | 83/270 [02:15<04:19,  1.39s/it]
#
#
# Dedup S1 and S2:  31%|███       | 84/270 [02:17<05:05,  1.64s/it]
#
#
# Dedup S1 and S2:  31%|███▏      | 85/270 [02:19<04:44,  1.54s/it]
#
#
# Dedup S1 and S2:  32%|███▏      | 86/270 [02:20<04:30,  1.47s/it]
#
#
# Dedup S1 and S2:  32%|███▏      | 87/270 [02:21<04:22,  1.43s/it]
#
#
# Dedup S1 and S2:  33%|███▎      | 88/270 [02:23<04:14,  1.40s/it]
#
#
# Dedup S1 and S2:  33%|███▎      | 89/270 [02:24<04:08,  1.37s/it]
#
#
# Dedup S1 and S2:  33%|███▎      | 90/270 [02:26<04:52,  1.62s/it]
#
#
# Dedup S1 and S2:  34%|███▎      | 91/270 [02:28<04:32,  1.52s/it]
#
#
# Dedup S1 and S2:  34%|███▍      | 92/270 [02:29<04:20,  1.46s/it]
#
#
# Dedup S1 and S2:  34%|███▍      | 93/270 [02:30<04:10,  1.42s/it]
#
#
# Dedup S1 and S2:  35%|███▍      | 94/270 [02:32<04:05,  1.39s/it]
#
#
# Dedup S1 and S2:  35%|███▌      | 95/270 [02:33<03:59,  1.37s/it]
#
#
# Dedup S1 and S2:  36%|███▌      | 96/270 [02:35<04:42,  1.63s/it]
#
#
# Dedup S1 and S2:  36%|███▌      | 97/270 [02:36<04:23,  1.52s/it]
#
#
# Dedup S1 and S2:  36%|███▋      | 98/270 [02:38<04:10,  1.45s/it]
#
#
# Dedup S1 and S2:  37%|███▋      | 99/270 [02:39<04:02,  1.42s/it]
#
#
# Dedup S1 and S2:  37%|███▋      | 100/270 [02:40<03:55,  1.39s/it]
#
#
# Dedup S1 and S2:  37%|███▋      | 101/270 [02:42<03:51,  1.37s/it]
#
#
# Dedup S1 and S2:  38%|███▊      | 102/270 [02:44<04:36,  1.65s/it]
#
#
# Dedup S1 and S2:  38%|███▊      | 103/270 [02:45<04:19,  1.55s/it]
#
#
# Dedup S1 and S2:  39%|███▊      | 104/270 [02:47<04:08,  1.50s/it]
#
#
# Dedup S1 and S2:  39%|███▉      | 105/270 [02:48<04:00,  1.46s/it]
#
#
# Dedup S1 and S2:  39%|███▉      | 106/270 [02:49<03:51,  1.41s/it]
#
#
# Dedup S1 and S2:  40%|███▉      | 107/270 [02:51<03:45,  1.38s/it]
#
#
# Dedup S1 and S2:  40%|████      | 108/270 [02:53<04:26,  1.65s/it]
#
#
# Dedup S1 and S2:  40%|████      | 109/270 [02:54<04:08,  1.54s/it]
#
#
# Dedup S1 and S2:  41%|████      | 110/270 [02:55<03:55,  1.47s/it]
#
#
# Dedup S1 and S2:  41%|████      | 111/270 [02:57<03:49,  1.44s/it]
#
#
# Dedup S1 and S2:  41%|████▏     | 112/270 [02:58<03:40,  1.40s/it]
#
#
# Dedup S1 and S2:  42%|████▏     | 113/270 [02:59<03:34,  1.37s/it]
#
#
# Dedup S1 and S2:  42%|████▏     | 114/270 [03:02<04:13,  1.63s/it]
#
#
# Dedup S1 and S2:  43%|████▎     | 115/270 [03:03<03:56,  1.53s/it]
#
#
# Dedup S1 and S2:  43%|████▎     | 116/270 [03:04<03:46,  1.47s/it]
#
#
# Dedup S1 and S2:  43%|████▎     | 117/270 [03:06<03:37,  1.42s/it]
#
#
# Dedup S1 and S2:  44%|████▎     | 118/270 [03:07<03:31,  1.39s/it]
#
#
# Dedup S1 and S2:  44%|████▍     | 119/270 [03:08<03:24,  1.35s/it]
#
#
# Dedup S1 and S2:  44%|████▍     | 120/270 [03:10<04:00,  1.60s/it]
#
#
# Dedup S1 and S2:  45%|████▍     | 121/270 [03:12<03:44,  1.50s/it]
#
#
# Dedup S1 and S2:  45%|████▌     | 122/270 [03:13<03:34,  1.45s/it]
#
#
# Dedup S1 and S2:  46%|████▌     | 123/270 [03:14<03:27,  1.41s/it]
#
#
# Dedup S1 and S2:  46%|████▌     | 124/270 [03:16<03:21,  1.38s/it]
#
#
# Dedup S1 and S2:  46%|████▋     | 125/270 [03:17<03:17,  1.36s/it]
#
#
# Dedup S1 and S2:  47%|████▋     | 126/270 [03:19<03:54,  1.63s/it]
#
#
# Dedup S1 and S2:  47%|████▋     | 127/270 [03:20<03:39,  1.54s/it]
#
#
# Dedup S1 and S2:  47%|████▋     | 128/270 [03:22<03:31,  1.49s/it]
#
#
# Dedup S1 and S2:  48%|████▊     | 129/270 [03:23<03:24,  1.45s/it]
#
#
# Dedup S1 and S2:  48%|████▊     | 130/270 [03:25<03:18,  1.41s/it]
#
#
# Dedup S1 and S2:  49%|████▊     | 131/270 [03:26<03:12,  1.38s/it]
#
#
# Dedup S1 and S2:  49%|████▉     | 132/270 [03:28<03:44,  1.62s/it]
#
#
# Dedup S1 and S2:  49%|████▉     | 133/270 [03:29<03:30,  1.53s/it]
#
#
# Dedup S1 and S2:  50%|████▉     | 134/270 [03:31<03:19,  1.46s/it]
#
#
# Dedup S1 and S2:  50%|█████     | 135/270 [03:32<03:13,  1.43s/it]
#
#
# Dedup S1 and S2:  50%|█████     | 136/270 [03:33<03:08,  1.41s/it]
#
#
# Dedup S1 and S2:  51%|█████     | 137/270 [03:35<03:04,  1.39s/it]
#
#
# Dedup S1 and S2:  51%|█████     | 138/270 [03:37<03:35,  1.63s/it]
#
#
# Dedup S1 and S2:  51%|█████▏    | 139/270 [03:38<03:20,  1.53s/it]
#
#
# Dedup S1 and S2:  52%|█████▏    | 140/270 [03:40<03:11,  1.47s/it]
#
#
# Dedup S1 and S2:  52%|█████▏    | 141/270 [03:41<03:03,  1.42s/it]
#
#
# Dedup S1 and S2:  53%|█████▎    | 142/270 [03:42<02:57,  1.39s/it]
#
#
# Dedup S1 and S2:  53%|█████▎    | 143/270 [03:43<02:53,  1.36s/it]
#
#
# Dedup S1 and S2:  53%|█████▎    | 144/270 [03:46<03:25,  1.63s/it]
#
#
# Dedup S1 and S2:  54%|█████▎    | 145/270 [03:47<03:13,  1.55s/it]
#
#
# Dedup S1 and S2:  54%|█████▍    | 146/270 [03:48<03:03,  1.48s/it]
#
#
# Dedup S1 and S2:  54%|█████▍    | 147/270 [03:50<02:56,  1.43s/it]
#
#
# Dedup S1 and S2:  55%|█████▍    | 148/270 [03:51<02:49,  1.39s/it]
#
#
# Dedup S1 and S2:  55%|█████▌    | 149/270 [03:52<02:43,  1.35s/it]
#
#
# Dedup S1 and S2:  56%|█████▌    | 150/270 [03:54<03:13,  1.61s/it]
#
#
# Dedup S1 and S2:  56%|█████▌    | 151/270 [03:56<03:01,  1.53s/it]
#
#
# Dedup S1 and S2:  56%|█████▋    | 152/270 [03:57<02:52,  1.46s/it]
#
#
# Dedup S1 and S2:  57%|█████▋    | 153/270 [03:59<02:48,  1.44s/it]
#
#
# Dedup S1 and S2:  57%|█████▋    | 154/270 [04:00<02:43,  1.41s/it]
#
#
# Dedup S1 and S2:  57%|█████▋    | 155/270 [04:01<02:39,  1.39s/it]
#
#
# Dedup S1 and S2:  58%|█████▊    | 156/270 [04:04<03:12,  1.69s/it]
#
#
# Dedup S1 and S2:  58%|█████▊    | 157/270 [04:05<02:57,  1.57s/it]
#
#
# Dedup S1 and S2:  59%|█████▊    | 158/270 [04:06<02:48,  1.50s/it]
#
#
# Dedup S1 and S2:  59%|█████▉    | 159/270 [04:08<02:41,  1.46s/it]
#
#
# Dedup S1 and S2:  59%|█████▉    | 160/270 [04:09<02:36,  1.42s/it]
#
#
# Dedup S1 and S2:  60%|█████▉    | 161/270 [04:10<02:32,  1.40s/it]
#
#
# Dedup S1 and S2:  60%|██████    | 162/270 [04:12<02:58,  1.65s/it]
#
#
# Dedup S1 and S2:  60%|██████    | 163/270 [04:14<02:46,  1.56s/it]
#
#
# Dedup S1 and S2:  61%|██████    | 164/270 [04:15<02:39,  1.51s/it]
#
#
# Dedup S1 and S2:  61%|██████    | 165/270 [04:17<02:32,  1.45s/it]
#
#
# Dedup S1 and S2:  61%|██████▏   | 166/270 [04:18<02:27,  1.42s/it]
#
#
# Dedup S1 and S2:  62%|██████▏   | 167/270 [04:19<02:22,  1.39s/it]
#
#
# Dedup S1 and S2:  62%|██████▏   | 168/270 [04:21<02:46,  1.64s/it]
#
#
# Dedup S1 and S2:  63%|██████▎   | 169/270 [04:23<02:34,  1.53s/it]
#
#
# Dedup S1 and S2:  63%|██████▎   | 170/270 [04:24<02:26,  1.47s/it]
#
#
# Dedup S1 and S2:  63%|██████▎   | 171/270 [04:25<02:21,  1.43s/it]
#
#
# Dedup S1 and S2:  64%|██████▎   | 172/270 [04:27<02:15,  1.38s/it]
#
#
# Dedup S1 and S2:  64%|██████▍   | 173/270 [04:28<02:11,  1.36s/it]
#
#
# Dedup S1 and S2:  64%|██████▍   | 174/270 [04:30<02:35,  1.62s/it]
#
#
# Dedup S1 and S2:  65%|██████▍   | 175/270 [04:31<02:25,  1.53s/it]
#
#
# Dedup S1 and S2:  65%|██████▌   | 176/270 [04:33<02:17,  1.46s/it]
#
#
# Dedup S1 and S2:  66%|██████▌   | 177/270 [04:34<02:11,  1.41s/it]
#
#
# Dedup S1 and S2:  66%|██████▌   | 178/270 [04:35<02:07,  1.39s/it]
#
#
# Dedup S1 and S2:  66%|██████▋   | 179/270 [04:37<02:04,  1.36s/it]
#
#
# Dedup S1 and S2:  67%|██████▋   | 180/270 [04:39<02:25,  1.62s/it]
#
#
# Dedup S1 and S2:  67%|██████▋   | 181/270 [04:40<02:15,  1.53s/it]
#
#
# Dedup S1 and S2:  67%|██████▋   | 182/270 [04:42<02:09,  1.47s/it]
#
#
# Dedup S1 and S2:  68%|██████▊   | 183/270 [04:43<02:05,  1.44s/it]
#
#
# Dedup S1 and S2:  68%|██████▊   | 184/270 [04:44<02:02,  1.42s/it]
#
#
# Dedup S1 and S2:  69%|██████▊   | 185/270 [04:46<01:58,  1.40s/it]
#
#
# Dedup S1 and S2:  69%|██████▉   | 186/270 [04:48<02:19,  1.66s/it]
#
#
# Dedup S1 and S2:  69%|██████▉   | 187/270 [04:49<02:09,  1.56s/it]
#
#
# Dedup S1 and S2:  70%|██████▉   | 188/270 [04:51<02:02,  1.49s/it]
#
#
# Dedup S1 and S2:  70%|███████   | 189/270 [04:52<01:58,  1.46s/it]
#
#
# Dedup S1 and S2:  70%|███████   | 190/270 [04:53<01:53,  1.42s/it]
#
#
# Dedup S1 and S2:  71%|███████   | 191/270 [04:55<01:49,  1.38s/it]
#
#
# Dedup S1 and S2:  71%|███████   | 192/270 [04:57<02:08,  1.65s/it]
#
#
# Dedup S1 and S2:  71%|███████▏  | 193/270 [04:58<01:58,  1.54s/it]
#
#
# Dedup S1 and S2:  72%|███████▏  | 194/270 [05:00<01:52,  1.48s/it]
#
#
# Dedup S1 and S2:  72%|███████▏  | 195/270 [05:01<01:48,  1.44s/it]
#
#
# Dedup S1 and S2:  73%|███████▎  | 196/270 [05:02<01:44,  1.41s/it]
#
#
# Dedup S1 and S2:  73%|███████▎  | 197/270 [05:04<01:41,  1.39s/it]
#
#
# Dedup S1 and S2:  73%|███████▎  | 198/270 [05:06<01:58,  1.65s/it]
#
#
# Dedup S1 and S2:  74%|███████▎  | 199/270 [05:07<01:50,  1.55s/it]
#
#
# Dedup S1 and S2:  74%|███████▍  | 200/270 [05:08<01:43,  1.48s/it]
#
#
# Dedup S1 and S2:  74%|███████▍  | 201/270 [05:10<01:39,  1.45s/it]
#
#
# Dedup S1 and S2:  75%|███████▍  | 202/270 [05:11<01:36,  1.42s/it]
#
#
# Dedup S1 and S2:  75%|███████▌  | 203/270 [05:12<01:32,  1.38s/it]
#
#
# Dedup S1 and S2:  76%|███████▌  | 204/270 [05:15<01:48,  1.65s/it]
#
#
# Dedup S1 and S2:  76%|███████▌  | 205/270 [05:16<01:41,  1.55s/it]
#
#
# Dedup S1 and S2:  76%|███████▋  | 206/270 [05:17<01:36,  1.50s/it]
#
#
# Dedup S1 and S2:  77%|███████▋  | 207/270 [05:19<01:31,  1.46s/it]
#
#
# Dedup S1 and S2:  77%|███████▋  | 208/270 [05:20<01:28,  1.43s/it]
#
#
# Dedup S1 and S2:  77%|███████▋  | 209/270 [05:21<01:25,  1.40s/it]
#
#
# Dedup S1 and S2:  78%|███████▊  | 210/270 [05:24<01:39,  1.65s/it]
#
#
# Dedup S1 and S2:  78%|███████▊  | 211/270 [05:25<01:31,  1.55s/it]
#
#
# Dedup S1 and S2:  79%|███████▊  | 212/270 [05:26<01:26,  1.49s/it]
#
#
# Dedup S1 and S2:  79%|███████▉  | 213/270 [05:28<01:22,  1.44s/it]
#
#
# Dedup S1 and S2:  79%|███████▉  | 214/270 [05:29<01:18,  1.41s/it]
#
#
# Dedup S1 and S2:  80%|███████▉  | 215/270 [05:30<01:16,  1.38s/it]
#
#
# Dedup S1 and S2:  80%|████████  | 216/270 [05:33<01:28,  1.64s/it]
#
#
# Dedup S1 and S2:  80%|████████  | 217/270 [05:35<01:37,  1.84s/it]
#
#
# Dedup S1 and S2:  81%|████████  | 218/270 [05:37<01:42,  1.97s/it]
#
#
# Dedup S1 and S2:  81%|████████  | 219/270 [05:39<01:44,  2.06s/it]
#
#
# Dedup S1 and S2:  81%|████████▏ | 220/270 [05:42<01:45,  2.11s/it]
#
#
# Dedup S1 and S2:  82%|████████▏ | 221/270 [05:44<01:46,  2.17s/it]
#
#
# Dedup S1 and S2:  82%|████████▏ | 222/270 [05:46<01:45,  2.19s/it]
#
#
# Dedup S1 and S2:  83%|████████▎ | 223/270 [05:48<01:30,  1.92s/it]
#
#
# Dedup S1 and S2:  83%|████████▎ | 224/270 [05:49<01:20,  1.75s/it]
#
#
# Dedup S1 and S2:  83%|████████▎ | 225/270 [05:50<01:13,  1.63s/it]
#
#
# Dedup S1 and S2:  84%|████████▎ | 226/270 [05:52<01:07,  1.53s/it]
#
#
# Dedup S1 and S2:  84%|████████▍ | 227/270 [05:53<01:02,  1.46s/it]
#
#
# Dedup S1 and S2:  84%|████████▍ | 228/270 [05:55<01:11,  1.69s/it]
#
#
# Dedup S1 and S2:  85%|████████▍ | 229/270 [05:56<01:04,  1.57s/it]
#
#
# Dedup S1 and S2:  85%|████████▌ | 230/270 [05:58<00:59,  1.48s/it]
#
#
# Dedup S1 and S2:  86%|████████▌ | 231/270 [05:59<00:56,  1.44s/it]
#
#
# Dedup S1 and S2:  86%|████████▌ | 232/270 [06:00<00:53,  1.41s/it]
#
#
# Dedup S1 and S2:  86%|████████▋ | 233/270 [06:02<00:51,  1.38s/it]
#
#
# Dedup S1 and S2:  87%|████████▋ | 234/270 [06:04<00:59,  1.65s/it]
#
#
# Dedup S1 and S2:  87%|████████▋ | 235/270 [06:05<00:54,  1.55s/it]
#
#
# Dedup S1 and S2:  87%|████████▋ | 236/270 [06:07<00:50,  1.48s/it]
#
#
# Dedup S1 and S2:  88%|████████▊ | 237/270 [06:08<00:47,  1.43s/it]
#
#
# Dedup S1 and S2:  88%|████████▊ | 238/270 [06:09<00:44,  1.41s/it]
#
#
# Dedup S1 and S2:  89%|████████▊ | 239/270 [06:11<00:43,  1.39s/it]
#
#
# Dedup S1 and S2:  89%|████████▉ | 240/270 [06:13<00:49,  1.64s/it]
#
#
# Dedup S1 and S2:  89%|████████▉ | 241/270 [06:14<00:45,  1.55s/it]
#
#
# Dedup S1 and S2:  90%|████████▉ | 242/270 [06:15<00:41,  1.49s/it]
#
#
# Dedup S1 and S2:  90%|█████████ | 243/270 [06:17<00:38,  1.44s/it]
#
#
# Dedup S1 and S2:  90%|█████████ | 244/270 [06:18<00:36,  1.41s/it]
#
#
# Dedup S1 and S2:  91%|█████████ | 245/270 [06:19<00:34,  1.38s/it]
#
#
# Dedup S1 and S2:  91%|█████████ | 246/270 [06:22<00:39,  1.64s/it]
#
#
# Dedup S1 and S2:  91%|█████████▏| 247/270 [06:23<00:35,  1.53s/it]
#
#
# Dedup S1 and S2:  92%|█████████▏| 248/270 [06:24<00:32,  1.46s/it]
#
#
# Dedup S1 and S2:  92%|█████████▏| 249/270 [06:26<00:29,  1.42s/it]
#
#
# Dedup S1 and S2:  93%|█████████▎| 250/270 [06:27<00:27,  1.39s/it]
#
#
# Dedup S1 and S2:  93%|█████████▎| 251/270 [06:28<00:25,  1.35s/it]
#
#
# Dedup S1 and S2:  93%|█████████▎| 252/270 [06:30<00:28,  1.61s/it]
#
#
# Dedup S1 and S2:  94%|█████████▎| 253/270 [06:33<00:30,  1.79s/it]
#
#
# Dedup S1 and S2:  94%|█████████▍| 254/270 [06:35<00:30,  1.93s/it]
#
#
# Dedup S1 and S2:  94%|█████████▍| 255/270 [06:37<00:30,  2.02s/it]
#
#
# Dedup S1 and S2:  95%|█████████▍| 256/270 [06:39<00:29,  2.07s/it]
#
#
# Dedup S1 and S2:  95%|█████████▌| 257/270 [06:41<00:27,  2.11s/it]
#
#
# Dedup S1 and S2:  96%|█████████▌| 258/270 [06:44<00:25,  2.15s/it]
#
#
# Dedup S1 and S2:  96%|█████████▌| 259/270 [06:45<00:20,  1.89s/it]
#
#
# Dedup S1 and S2:  96%|█████████▋| 260/270 [06:47<00:19,  1.99s/it]
#
#
# Dedup S1 and S2:  97%|█████████▋| 261/270 [06:49<00:16,  1.78s/it]
#
#
# Dedup S1 and S2:  97%|█████████▋| 262/270 [06:51<00:15,  1.90s/it]
#
#
# Dedup S1 and S2:  97%|█████████▋| 263/270 [06:52<00:12,  1.72s/it]
#
#
# Dedup S1 and S2:  98%|█████████▊| 264/270 [06:54<00:11,  1.86s/it]
#
#
# Dedup S1 and S2:  98%|█████████▊| 265/270 [06:55<00:08,  1.68s/it]
#
#
# Dedup S1 and S2:  99%|█████████▊| 266/270 [06:58<00:07,  1.84s/it]
#
#
# Dedup S1 and S2:  99%|█████████▉| 267/270 [06:59<00:05,  1.68s/it]
#
#
# Dedup S1 and S2:  99%|█████████▉| 268/270 [07:01<00:03,  1.84s/it]
#
#
# Dedup S1 and S2: 100%|█████████▉| 269/270 [07:03<00:01,  1.95s/it]
#
#
# Dedup S1 and S2: 100%|██████████| 270/270 [07:06<00:00,  1.58s/it]
#
#
#
# Gathering results: 100%|██████████| 2/2 [00:00<00:00, 24.49it/s]
#
#
#
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (548 / 552) | Bytes (2805760000 / 2764800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_800_800/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_800_800/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:14<01:11, 14.32s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (524 / 552) | Bytes (2682880000 / 2764800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_800_800/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_800_800/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:34<01:04, 16.08s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (498 / 552) | Bytes (2549760000 / 2764800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_800_800/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_800_800/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:52<00:50, 16.71s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (120 / 552) | Bytes (614400000 / 2764800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_800_800/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_800_800/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:11<00:34, 17.24s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (89 / 552) | Bytes (455680000 / 2764800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_800_800/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_800_800/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:32<00:18, 18.52s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (80 / 552) | Bytes (409600000 / 2764800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_800_800/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_800_800/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:54<00:00, 19.48s/it]
# None

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        900,
        900,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
#
#
#
# Splitting model into blocks:  78%|███████▊  | 18/23 [00:00<00:00, 171.71it/s]
# Splitting model layers with size > 16 MB into blocks of size 900 X 900 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 39.09it/s]
#
#
#
#
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
#
#
#
# Splitting model into blocks:  77%|███████▋  | 20/26 [00:00<00:00, 188.06it/s]
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Reshaped matrix from 3,786432 -> 1152,2048
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 49.91it/s]
#
#
#
#
# Dedup S1:   0%|          | 0/205 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1:   0%|          | 1/205 [00:01<04:16,  1.26s/it]
#
#
#
# Dedup S1:   1%|          | 2/205 [00:02<04:16,  1.27s/it]
#
#
#
# Dedup S1:   1%|▏         | 3/205 [00:04<04:45,  1.41s/it]
#
#
#
# Dedup S1:   2%|▏         | 4/205 [00:06<05:04,  1.52s/it]
#
#
#
# Dedup S1:   2%|▏         | 5/205 [00:07<05:10,  1.55s/it]
#
#
#
# Dedup S1:   3%|▎         | 6/205 [00:09<05:14,  1.58s/it]
#
#
#
# Dedup S1:   3%|▎         | 7/205 [00:10<04:50,  1.47s/it]
#
#
#
# Dedup S1:   4%|▍         | 8/205 [00:11<04:31,  1.38s/it]
#
#
#
# Dedup S1:   4%|▍         | 9/205 [00:13<04:43,  1.45s/it]
#
#
#
# Dedup S1:   5%|▍         | 10/205 [00:15<04:56,  1.52s/it]
#
#
#
# Dedup S1:   5%|▌         | 11/205 [00:16<05:09,  1.59s/it]
#
#
#
# Dedup S1:   6%|▌         | 12/205 [00:18<05:05,  1.58s/it]
#
#
#
# Dedup S1:   6%|▋         | 13/205 [00:19<04:31,  1.41s/it]
#
#
#
# Dedup S1:   7%|▋         | 14/205 [00:20<04:07,  1.29s/it]
#
#
#
# Dedup S1:   7%|▋         | 15/205 [00:21<04:20,  1.37s/it]
#
#
#
# Dedup S1:   8%|▊         | 16/205 [00:23<04:25,  1.41s/it]
#
#
#
# Dedup S1:   8%|▊         | 17/205 [00:24<04:28,  1.43s/it]
#
#
#
# Dedup S1:   9%|▉         | 18/205 [00:26<04:30,  1.45s/it]
#
#
#
# Dedup S1:   9%|▉         | 19/205 [00:27<04:02,  1.31s/it]
#
#
#
# Dedup S1:  10%|▉         | 20/205 [00:28<03:42,  1.20s/it]
#
#
#
# Dedup S1:  10%|█         | 21/205 [00:29<03:57,  1.29s/it]
#
#
#
# Dedup S1:  11%|█         | 22/205 [00:31<04:02,  1.32s/it]
#
#
#
# Dedup S1:  11%|█         | 23/205 [00:32<04:06,  1.35s/it]
#
#
#
# Dedup S1:  12%|█▏        | 24/205 [00:34<04:05,  1.36s/it]
#
#
#
# Dedup S1:  12%|█▏        | 25/205 [00:34<03:40,  1.22s/it]
#
#
#
# Dedup S1:  13%|█▎        | 26/205 [00:35<03:23,  1.14s/it]
#
#
#
# Dedup S1:  13%|█▎        | 27/205 [00:37<03:36,  1.22s/it]
#
#
#
# Dedup S1:  14%|█▎        | 28/205 [00:38<03:42,  1.26s/it]
#
#
#
# Dedup S1:  14%|█▍        | 29/205 [00:39<03:47,  1.29s/it]
#
#
#
# Dedup S1:  15%|█▍        | 30/205 [00:41<03:50,  1.32s/it]
#
#
#
# Dedup S1:  15%|█▌        | 31/205 [00:42<03:26,  1.19s/it]
#
#
#
# Dedup S1:  16%|█▌        | 32/205 [00:43<03:09,  1.10s/it]
#
#
#
# Dedup S1:  16%|█▌        | 33/205 [00:43<02:56,  1.03s/it]
#
#
#
# Dedup S1:  17%|█▋        | 34/205 [00:44<02:47,  1.02it/s]
#
#
#
# Dedup S1:  17%|█▋        | 35/205 [00:46<03:03,  1.08s/it]
#
#
#
# Dedup S1:  18%|█▊        | 36/205 [00:46<02:49,  1.00s/it]
#
#
#
# Dedup S1:  18%|█▊        | 37/205 [00:47<02:40,  1.05it/s]
#
#
#
# Dedup S1:  19%|█▊        | 38/205 [00:48<02:33,  1.09it/s]
#
#
#
# Dedup S1:  19%|█▉        | 39/205 [00:49<02:28,  1.12it/s]
#
#
#
# Dedup S1:  20%|█▉        | 40/205 [00:50<02:44,  1.01it/s]
#
#
#
# Dedup S1:  20%|██        | 41/205 [00:51<02:33,  1.07it/s]
#
#
#
# Dedup S1:  20%|██        | 42/205 [00:52<02:25,  1.12it/s]
#
#
#
# Dedup S1:  21%|██        | 43/205 [00:53<02:22,  1.14it/s]
#
#
#
# Dedup S1:  21%|██▏       | 44/205 [00:53<02:17,  1.17it/s]
#
#
#
# Dedup S1:  22%|██▏       | 45/205 [00:55<02:31,  1.06it/s]
#
#
#
# Dedup S1:  22%|██▏       | 46/205 [00:55<02:23,  1.11it/s]
#
#
#
# Dedup S1:  23%|██▎       | 47/205 [00:56<02:18,  1.14it/s]
#
#
#
# Dedup S1:  23%|██▎       | 48/205 [00:57<02:13,  1.18it/s]
#
#
#
# Dedup S1:  24%|██▍       | 49/205 [00:58<02:09,  1.20it/s]
#
#
#
# Dedup S1:  24%|██▍       | 50/205 [00:59<02:24,  1.07it/s]
#
#
#
# Dedup S1:  25%|██▍       | 51/205 [01:00<02:16,  1.13it/s]
#
#
#
# Dedup S1:  25%|██▌       | 52/205 [01:01<02:10,  1.17it/s]
#
#
#
# Dedup S1:  26%|██▌       | 53/205 [01:01<02:06,  1.20it/s]
#
#
#
# Dedup S1:  26%|██▋       | 54/205 [01:02<02:02,  1.23it/s]
#
#
#
# Dedup S1:  27%|██▋       | 55/205 [01:03<02:15,  1.11it/s]
#
#
#
# Dedup S1:  27%|██▋       | 56/205 [01:04<02:05,  1.19it/s]
#
#
#
# Dedup S1:  28%|██▊       | 57/205 [01:05<02:00,  1.23it/s]
#
#
#
# Dedup S1:  28%|██▊       | 58/205 [01:05<01:56,  1.26it/s]
#
#
#
# Dedup S1:  29%|██▉       | 59/205 [01:06<01:53,  1.29it/s]
#
#
#
# Dedup S1:  29%|██▉       | 60/205 [01:07<02:05,  1.16it/s]
#
#
#
# Dedup S1:  30%|██▉       | 61/205 [01:08<01:57,  1.22it/s]
#
#
#
# Dedup S1:  30%|███       | 62/205 [01:09<01:53,  1.26it/s]
#
#
#
# Dedup S1:  31%|███       | 63/205 [01:09<01:50,  1.29it/s]
#
#
#
# Dedup S1:  31%|███       | 64/205 [01:10<01:48,  1.30it/s]
#
#
#
# Dedup S1:  32%|███▏      | 65/205 [01:11<02:00,  1.16it/s]
#
#
#
# Dedup S1:  32%|███▏      | 66/205 [01:12<01:53,  1.23it/s]
#
#
#
# Dedup S1:  33%|███▎      | 67/205 [01:13<01:48,  1.28it/s]
#
#
#
# Dedup S1:  33%|███▎      | 68/205 [01:13<01:43,  1.32it/s]
#
#
#
# Dedup S1:  34%|███▎      | 69/205 [01:14<01:40,  1.36it/s]
#
#
#
# Dedup S1:  34%|███▍      | 70/205 [01:15<01:50,  1.22it/s]
#
#
#
# Dedup S1:  35%|███▍      | 71/205 [01:16<01:44,  1.28it/s]
#
#
#
# Dedup S1:  35%|███▌      | 72/205 [01:16<01:40,  1.33it/s]
#
#
#
# Dedup S1:  36%|███▌      | 73/205 [01:17<01:36,  1.37it/s]
#
#
#
# Dedup S1:  36%|███▌      | 74/205 [01:18<01:33,  1.40it/s]
#
#
#
# Dedup S1:  37%|███▋      | 75/205 [01:19<01:42,  1.27it/s]
#
#
#
# Dedup S1:  37%|███▋      | 76/205 [01:19<01:35,  1.35it/s]
#
#
#
# Dedup S1:  38%|███▊      | 77/205 [01:20<01:32,  1.39it/s]
#
#
#
# Dedup S1:  38%|███▊      | 78/205 [01:21<01:29,  1.41it/s]
#
#
#
# Dedup S1:  39%|███▊      | 79/205 [01:21<01:26,  1.46it/s]
#
#
#
# Dedup S1:  39%|███▉      | 80/205 [01:22<01:32,  1.35it/s]
#
#
#
# Dedup S1:  40%|███▉      | 81/205 [01:23<01:27,  1.42it/s]
#
#
#
# Dedup S1:  40%|████      | 82/205 [01:23<01:23,  1.47it/s]
#
#
#
# Dedup S1:  40%|████      | 83/205 [01:24<01:20,  1.52it/s]
#
#
#
# Dedup S1:  41%|████      | 84/205 [01:25<01:18,  1.53it/s]
#
#
#
# Dedup S1:  41%|████▏     | 85/205 [01:26<01:27,  1.38it/s]
#
#
#
# Dedup S1:  42%|████▏     | 86/205 [01:26<01:21,  1.46it/s]
#
#
#
# Dedup S1:  42%|████▏     | 87/205 [01:27<01:17,  1.51it/s]
#
#
#
# Dedup S1:  43%|████▎     | 88/205 [01:27<01:15,  1.56it/s]
#
#
#
# Dedup S1:  43%|████▎     | 89/205 [01:28<01:12,  1.60it/s]
#
#
#
# Dedup S1:  44%|████▍     | 90/205 [01:29<01:20,  1.43it/s]
#
#
#
# Dedup S1:  44%|████▍     | 91/205 [01:29<01:15,  1.52it/s]
#
#
#
# Dedup S1:  45%|████▍     | 92/205 [01:30<01:12,  1.55it/s]
#
#
#
# Dedup S1:  45%|████▌     | 93/205 [01:31<01:10,  1.59it/s]
#
#
#
# Dedup S1:  46%|████▌     | 94/205 [01:31<01:08,  1.63it/s]
#
#
#
# Dedup S1:  46%|████▋     | 95/205 [01:32<01:14,  1.47it/s]
#
#
#
# Dedup S1:  47%|████▋     | 96/205 [01:33<01:10,  1.54it/s]
#
#
#
# Dedup S1:  47%|████▋     | 97/205 [01:33<01:07,  1.59it/s]
#
#
#
# Dedup S1:  48%|████▊     | 98/205 [01:34<01:04,  1.65it/s]
#
#
#
# Dedup S1:  48%|████▊     | 99/205 [01:34<01:02,  1.70it/s]
#
#
#
# Dedup S1:  49%|████▉     | 100/205 [01:35<01:05,  1.59it/s]
#
#
#
# Dedup S1:  49%|████▉     | 101/205 [01:36<01:02,  1.68it/s]
#
#
#
# Dedup S1:  50%|████▉     | 102/205 [01:36<00:59,  1.74it/s]
#
#
#
# Dedup S1:  50%|█████     | 103/205 [01:37<00:57,  1.79it/s]
#
#
#
# Dedup S1:  51%|█████     | 104/205 [01:37<00:55,  1.82it/s]
#
#
#
# Dedup S1:  51%|█████     | 105/205 [01:38<00:59,  1.68it/s]
#
#
#
# Dedup S1:  52%|█████▏    | 106/205 [01:38<00:56,  1.77it/s]
#
#
#
# Dedup S1:  52%|█████▏    | 107/205 [01:39<00:54,  1.81it/s]
#
#
#
# Dedup S1:  53%|█████▎    | 108/205 [01:39<00:51,  1.88it/s]
#
#
#
# Dedup S1:  53%|█████▎    | 109/205 [01:40<00:50,  1.91it/s]
#
#
#
# Dedup S1:  54%|█████▎    | 110/205 [01:41<00:55,  1.71it/s]
#
#
#
# Dedup S1:  54%|█████▍    | 111/205 [01:41<00:52,  1.79it/s]
#
#
#
# Dedup S1:  55%|█████▍    | 112/205 [01:42<00:50,  1.85it/s]
#
#
#
# Dedup S1:  55%|█████▌    | 113/205 [01:42<00:48,  1.91it/s]
#
#
#
# Dedup S1:  56%|█████▌    | 114/205 [01:43<00:46,  1.97it/s]
#
#
#
# Dedup S1:  56%|█████▌    | 115/205 [01:43<00:51,  1.76it/s]
#
#
#
# Dedup S1:  57%|█████▋    | 116/205 [01:44<00:47,  1.87it/s]
#
#
#
# Dedup S1:  57%|█████▋    | 117/205 [01:44<00:45,  1.95it/s]
#
#
#
# Dedup S1:  58%|█████▊    | 118/205 [01:45<00:43,  2.02it/s]
#
#
#
# Dedup S1:  58%|█████▊    | 119/205 [01:45<00:41,  2.06it/s]
#
#
#
# Dedup S1:  59%|█████▊    | 120/205 [01:46<00:45,  1.87it/s]
#
#
#
# Dedup S1:  59%|█████▉    | 121/205 [01:46<00:42,  2.00it/s]
#
#
#
# Dedup S1:  60%|█████▉    | 122/205 [01:47<00:39,  2.08it/s]
#
#
#
# Dedup S1:  60%|██████    | 123/205 [01:47<00:37,  2.16it/s]
#
#
#
# Dedup S1:  60%|██████    | 124/205 [01:47<00:36,  2.20it/s]
#
#
#
# Dedup S1:  61%|██████    | 125/205 [01:48<00:39,  2.03it/s]
#
#
#
# Dedup S1:  61%|██████▏   | 126/205 [01:48<00:36,  2.16it/s]
#
#
#
# Dedup S1:  62%|██████▏   | 127/205 [01:49<00:35,  2.23it/s]
#
#
#
# Dedup S1:  62%|██████▏   | 128/205 [01:49<00:33,  2.28it/s]
#
#
#
# Dedup S1:  63%|██████▎   | 129/205 [01:50<00:32,  2.34it/s]
#
#
#
# Dedup S1:  63%|██████▎   | 130/205 [01:50<00:35,  2.14it/s]
#
#
#
# Dedup S1:  64%|██████▍   | 131/205 [01:51<00:32,  2.25it/s]
#
#
#
# Dedup S1:  64%|██████▍   | 132/205 [01:51<00:31,  2.33it/s]
#
#
#
# Dedup S1:  65%|██████▍   | 133/205 [01:51<00:30,  2.39it/s]
#
#
#
# Dedup S1:  65%|██████▌   | 134/205 [01:52<00:28,  2.46it/s]
#
#
#
# Dedup S1:  66%|██████▌   | 135/205 [01:52<00:31,  2.25it/s]
#
#
#
# Dedup S1:  66%|██████▋   | 136/205 [01:53<00:28,  2.40it/s]
#
#
#
# Dedup S1:  67%|██████▋   | 137/205 [01:53<00:27,  2.51it/s]
#
#
#
# Dedup S1:  67%|██████▋   | 138/205 [01:53<00:26,  2.56it/s]
#
#
#
# Dedup S1:  68%|██████▊   | 139/205 [01:54<00:25,  2.63it/s]
#
#
#
# Dedup S1:  68%|██████▊   | 140/205 [01:54<00:26,  2.47it/s]
#
#
#
# Dedup S1:  69%|██████▉   | 141/205 [01:54<00:24,  2.60it/s]
#
#
#
# Dedup S1:  69%|██████▉   | 142/205 [01:55<00:23,  2.69it/s]
#
#
#
# Dedup S1:  70%|██████▉   | 143/205 [01:55<00:22,  2.77it/s]
#
#
#
# Dedup S1:  70%|███████   | 144/205 [01:56<00:21,  2.79it/s]
#
#
#
# Dedup S1:  71%|███████   | 145/205 [01:56<00:23,  2.55it/s]
#
#
#
# Dedup S1:  71%|███████   | 146/205 [01:56<00:21,  2.70it/s]
#
#
#
# Dedup S1:  72%|███████▏  | 147/205 [01:57<00:20,  2.81it/s]
#
#
#
# Dedup S1:  72%|███████▏  | 148/205 [01:57<00:19,  2.92it/s]
#
#
#
# Dedup S1:  73%|███████▎  | 149/205 [01:57<00:18,  2.99it/s]
#
#
#
# Dedup S1:  73%|███████▎  | 150/205 [01:58<00:19,  2.80it/s]
#
#
#
# Dedup S1:  74%|███████▎  | 151/205 [01:58<00:18,  2.92it/s]
#
#
#
# Dedup S1:  74%|███████▍  | 152/205 [01:58<00:17,  3.03it/s]
#
#
#
# Dedup S1:  75%|███████▍  | 153/205 [01:59<00:16,  3.13it/s]
#
#
#
# Dedup S1:  75%|███████▌  | 154/205 [01:59<00:15,  3.20it/s]
#
#
#
# Dedup S1:  76%|███████▌  | 155/205 [01:59<00:16,  3.01it/s]
#
#
#
# Dedup S1:  76%|███████▌  | 156/205 [02:00<00:15,  3.16it/s]
#
#
#
# Dedup S1:  77%|███████▋  | 157/205 [02:00<00:14,  3.29it/s]
#
#
#
# Dedup S1:  77%|███████▋  | 158/205 [02:00<00:13,  3.38it/s]
#
#
#
# Dedup S1:  78%|███████▊  | 159/205 [02:00<00:13,  3.45it/s]
#
#
#
# Dedup S1:  78%|███████▊  | 160/205 [02:01<00:14,  3.21it/s]
#
#
#
# Dedup S1:  79%|███████▊  | 161/205 [02:01<00:13,  3.37it/s]
#
#
#
# Dedup S1:  79%|███████▉  | 162/205 [02:01<00:12,  3.49it/s]
#
#
#
# Dedup S1:  80%|███████▉  | 163/205 [02:02<00:11,  3.56it/s]
#
#
#
# Dedup S1:  80%|████████  | 164/205 [02:02<00:11,  3.68it/s]
#
#
#
# Dedup S1:  80%|████████  | 165/205 [02:02<00:11,  3.52it/s]
#
#
#
# Dedup S1:  81%|████████  | 166/205 [02:02<00:11,  3.50it/s]
#
#
#
# Dedup S1:  81%|████████▏ | 167/205 [02:03<00:10,  3.54it/s]
#
#
#
# Dedup S1:  82%|████████▏ | 168/205 [02:03<00:10,  3.54it/s]
#
#
#
# Dedup S1:  82%|████████▏ | 169/205 [02:03<00:10,  3.56it/s]
#
#
#
# Dedup S1:  83%|████████▎ | 170/205 [02:03<00:09,  3.66it/s]
#
#
#
# Dedup S1:  83%|████████▎ | 171/205 [02:04<00:08,  3.99it/s]
#
#
#
# Dedup S1:  84%|████████▍ | 172/205 [02:04<00:07,  4.27it/s]
#
#
#
# Dedup S1:  84%|████████▍ | 173/205 [02:04<00:07,  4.52it/s]
#
#
#
# Dedup S1:  85%|████████▍ | 174/205 [02:04<00:06,  4.74it/s]
#
#
#
# Dedup S1:  85%|████████▌ | 175/205 [02:04<00:06,  4.72it/s]
#
#
#
# Dedup S1:  86%|████████▌ | 176/205 [02:05<00:05,  5.04it/s]
#
#
#
# Dedup S1:  86%|████████▋ | 177/205 [02:05<00:05,  5.25it/s]
#
#
#
# Dedup S1:  87%|████████▋ | 178/205 [02:05<00:04,  5.43it/s]
#
#
#
# Dedup S1:  87%|████████▋ | 179/205 [02:05<00:04,  5.54it/s]
#
#
#
# Dedup S1:  88%|████████▊ | 180/205 [02:05<00:04,  5.30it/s]
#
#
#
# Dedup S1:  88%|████████▊ | 181/205 [02:05<00:04,  5.59it/s]
#
#
#
# Dedup S1:  89%|████████▉ | 182/205 [02:06<00:03,  5.87it/s]
#
#
#
# Dedup S1:  89%|████████▉ | 183/205 [02:06<00:03,  6.10it/s]
#
#
#
# Dedup S1:  90%|████████▉ | 184/205 [02:06<00:03,  6.32it/s]
#
#
#
# Dedup S1:  90%|█████████ | 185/205 [02:06<00:03,  6.22it/s]
#
#
#
# Dedup S1:  91%|█████████ | 186/205 [02:06<00:02,  6.52it/s]
#
#
#
# Dedup S1:  91%|█████████ | 187/205 [02:06<00:02,  6.85it/s]
#
#
#
# Dedup S1:  92%|█████████▏| 188/205 [02:06<00:02,  7.21it/s]
#
#
#
# Dedup S1:  92%|█████████▏| 189/205 [02:07<00:02,  7.52it/s]
#
#
#
# Dedup S1:  93%|█████████▎| 190/205 [02:07<00:01,  7.91it/s]
#
#
#
# Dedup S1:  93%|█████████▎| 191/205 [02:07<00:01,  8.17it/s]
#
#
#
# Dedup S1:  94%|█████████▎| 192/205 [02:07<00:01,  8.36it/s]
#
#
#
# Dedup S1:  94%|█████████▍| 193/205 [02:07<00:01,  8.77it/s]
#
#
#
# Dedup S1:  95%|█████████▌| 195/205 [02:07<00:01,  9.50it/s]
#
#
#
# Dedup S1:  96%|█████████▌| 197/205 [02:07<00:00, 10.83it/s]
#
#
#
# Dedup S1:  97%|█████████▋| 199/205 [02:07<00:00, 12.55it/s]
#
#
#
# Dedup S1: 100%|██████████| 205/205 [02:08<00:00,  1.60it/s]
#
#
#
#
# Dedup S2:   0%|          | 0/217 [00:00<?, ?it/s]
#
#
#
# Dedup S2:   0%|          | 1/217 [00:01<03:55,  1.09s/it]
#
#
#
# Dedup S2:   1%|          | 2/217 [00:02<03:56,  1.10s/it]
#
#
#
# Dedup S2:   1%|▏         | 3/217 [00:03<04:31,  1.27s/it]
#
#
#
# Dedup S2:   2%|▏         | 4/217 [00:05<04:52,  1.37s/it]
#
#
#
# Dedup S2:   2%|▏         | 5/217 [00:07<05:03,  1.43s/it]
#
#
#
# Dedup S2:   3%|▎         | 6/217 [00:08<05:11,  1.48s/it]
#
#
#
# Dedup S2:   3%|▎         | 7/217 [00:09<04:44,  1.36s/it]
#
#
#
# Dedup S2:   4%|▎         | 8/217 [00:11<04:40,  1.34s/it]
#
#
#
# Dedup S2:   4%|▍         | 9/217 [00:12<04:51,  1.40s/it]
#
#
#
# Dedup S2:   5%|▍         | 10/217 [00:14<04:59,  1.45s/it]
#
#
#
# Dedup S2:   5%|▌         | 11/217 [00:15<05:03,  1.47s/it]
#
#
#
# Dedup S2:   6%|▌         | 12/217 [00:17<05:03,  1.48s/it]
#
#
#
# Dedup S2:   6%|▌         | 13/217 [00:18<04:35,  1.35s/it]
#
#
#
# Dedup S2:   6%|▋         | 14/217 [00:19<04:17,  1.27s/it]
#
#
#
# Dedup S2:   7%|▋         | 15/217 [00:20<04:28,  1.33s/it]
#
#
#
# Dedup S2:   7%|▋         | 16/217 [00:22<04:34,  1.37s/it]
#
#
#
# Dedup S2:   8%|▊         | 17/217 [00:23<04:37,  1.39s/it]
#
#
#
# Dedup S2:   8%|▊         | 18/217 [00:25<04:42,  1.42s/it]
#
#
#
# Dedup S2:   9%|▉         | 19/217 [00:26<04:15,  1.29s/it]
#
#
#
# Dedup S2:   9%|▉         | 20/217 [00:27<03:58,  1.21s/it]
#
#
#
# Dedup S2:  10%|▉         | 21/217 [00:28<04:13,  1.29s/it]
#
#
#
# Dedup S2:  10%|█         | 22/217 [00:30<04:20,  1.33s/it]
#
#
#
# Dedup S2:  11%|█         | 23/217 [00:31<04:22,  1.35s/it]
#
#
#
# Dedup S2:  11%|█         | 24/217 [00:32<04:24,  1.37s/it]
#
#
#
# Dedup S2:  12%|█▏        | 25/217 [00:33<04:02,  1.26s/it]
#
#
#
# Dedup S2:  12%|█▏        | 26/217 [00:34<03:44,  1.18s/it]
#
#
#
# Dedup S2:  12%|█▏        | 27/217 [00:36<04:00,  1.26s/it]
#
#
#
# Dedup S2:  13%|█▎        | 28/217 [00:37<04:08,  1.31s/it]
#
#
#
# Dedup S2:  13%|█▎        | 29/217 [00:39<04:12,  1.35s/it]
#
#
#
# Dedup S2:  14%|█▍        | 30/217 [00:40<04:14,  1.36s/it]
#
#
#
# Dedup S2:  14%|█▍        | 31/217 [00:41<03:49,  1.23s/it]
#
#
#
# Dedup S2:  15%|█▍        | 32/217 [00:42<03:31,  1.14s/it]
#
#
#
# Dedup S2:  15%|█▌        | 33/217 [00:43<03:43,  1.21s/it]
#
#
#
# Dedup S2:  16%|█▌        | 34/217 [00:45<03:49,  1.25s/it]
#
#
#
# Dedup S2:  16%|█▌        | 35/217 [00:46<03:53,  1.28s/it]
#
#
#
# Dedup S2:  17%|█▋        | 36/217 [00:47<03:55,  1.30s/it]
#
#
#
# Dedup S2:  17%|█▋        | 37/217 [00:48<03:31,  1.17s/it]
#
#
#
# Dedup S2:  18%|█▊        | 38/217 [00:49<03:15,  1.09s/it]
#
#
#
# Dedup S2:  18%|█▊        | 39/217 [00:50<03:25,  1.16s/it]
#
#
#
# Dedup S2:  18%|█▊        | 40/217 [00:52<03:31,  1.20s/it]
#
#
#
# Dedup S2:  19%|█▉        | 41/217 [00:53<03:37,  1.24s/it]
#
#
#
# Dedup S2:  19%|█▉        | 42/217 [00:54<03:41,  1.27s/it]
#
#
#
# Dedup S2:  20%|█▉        | 43/217 [00:55<03:18,  1.14s/it]
#
#
#
# Dedup S2:  20%|██        | 44/217 [00:56<03:03,  1.06s/it]
#
#
#
# Dedup S2:  21%|██        | 45/217 [00:57<02:51,  1.00it/s]
#
#
#
# Dedup S2:  21%|██        | 46/217 [00:58<02:43,  1.05it/s]
#
#
#
# Dedup S2:  22%|██▏       | 47/217 [00:59<02:59,  1.05s/it]
#
#
#
# Dedup S2:  22%|██▏       | 48/217 [01:00<02:45,  1.02it/s]
#
#
#
# Dedup S2:  23%|██▎       | 49/217 [01:01<02:36,  1.07it/s]
#
#
#
# Dedup S2:  23%|██▎       | 50/217 [01:02<02:30,  1.11it/s]
#
#
#
# Dedup S2:  24%|██▎       | 51/217 [01:02<02:27,  1.13it/s]
#
#
#
# Dedup S2:  24%|██▍       | 52/217 [01:04<02:42,  1.01it/s]
#
#
#
# Dedup S2:  24%|██▍       | 53/217 [01:04<02:34,  1.06it/s]
#
#
#
# Dedup S2:  25%|██▍       | 54/217 [01:05<02:28,  1.10it/s]
#
#
#
# Dedup S2:  25%|██▌       | 55/217 [01:06<02:24,  1.12it/s]
#
#
#
# Dedup S2:  26%|██▌       | 56/217 [01:07<02:20,  1.14it/s]
#
#
#
# Dedup S2:  26%|██▋       | 57/217 [01:08<02:37,  1.01it/s]
#
#
#
# Dedup S2:  27%|██▋       | 58/217 [01:09<02:28,  1.07it/s]
#
#
#
# Dedup S2:  27%|██▋       | 59/217 [01:10<02:21,  1.11it/s]
#
#
#
# Dedup S2:  28%|██▊       | 60/217 [01:11<02:16,  1.15it/s]
#
#
#
# Dedup S2:  28%|██▊       | 61/217 [01:11<02:12,  1.18it/s]
#
#
#
# Dedup S2:  29%|██▊       | 62/217 [01:13<02:26,  1.06it/s]
#
#
#
# Dedup S2:  29%|██▉       | 63/217 [01:13<02:16,  1.13it/s]
#
#
#
# Dedup S2:  29%|██▉       | 64/217 [01:14<02:10,  1.17it/s]
#
#
#
# Dedup S2:  30%|██▉       | 65/217 [01:15<02:06,  1.21it/s]
#
#
#
# Dedup S2:  30%|███       | 66/217 [01:16<02:01,  1.24it/s]
#
#
#
# Dedup S2:  31%|███       | 67/217 [01:17<02:15,  1.11it/s]
#
#
#
# Dedup S2:  31%|███▏      | 68/217 [01:18<02:08,  1.16it/s]
#
#
#
# Dedup S2:  32%|███▏      | 69/217 [01:18<02:03,  1.20it/s]
#
#
#
# Dedup S2:  32%|███▏      | 70/217 [01:19<01:58,  1.24it/s]
#
#
#
# Dedup S2:  33%|███▎      | 71/217 [01:20<01:54,  1.27it/s]
#
#
#
# Dedup S2:  33%|███▎      | 72/217 [01:21<02:07,  1.14it/s]
#
#
#
# Dedup S2:  34%|███▎      | 73/217 [01:22<01:59,  1.20it/s]
#
#
#
# Dedup S2:  34%|███▍      | 74/217 [01:22<01:53,  1.26it/s]
#
#
#
# Dedup S2:  35%|███▍      | 75/217 [01:23<01:49,  1.30it/s]
#
#
#
# Dedup S2:  35%|███▌      | 76/217 [01:24<01:47,  1.32it/s]
#
#
#
# Dedup S2:  35%|███▌      | 77/217 [01:25<01:58,  1.18it/s]
#
#
#
# Dedup S2:  36%|███▌      | 78/217 [01:26<01:50,  1.25it/s]
#
#
#
# Dedup S2:  36%|███▋      | 79/217 [01:26<01:45,  1.31it/s]
#
#
#
# Dedup S2:  37%|███▋      | 80/217 [01:27<01:41,  1.35it/s]
#
#
#
# Dedup S2:  37%|███▋      | 81/217 [01:28<01:38,  1.38it/s]
#
#
#
# Dedup S2:  38%|███▊      | 82/217 [01:29<01:49,  1.24it/s]
#
#
#
# Dedup S2:  38%|███▊      | 83/217 [01:29<01:42,  1.30it/s]
#
#
#
# Dedup S2:  39%|███▊      | 84/217 [01:30<01:37,  1.36it/s]
#
#
#
# Dedup S2:  39%|███▉      | 85/217 [01:31<01:33,  1.42it/s]
#
#
#
# Dedup S2:  40%|███▉      | 86/217 [01:31<01:30,  1.45it/s]
#
#
#
# Dedup S2:  40%|████      | 87/217 [01:32<01:39,  1.31it/s]
#
#
#
# Dedup S2:  41%|████      | 88/217 [01:33<01:34,  1.36it/s]
#
#
#
# Dedup S2:  41%|████      | 89/217 [01:34<01:31,  1.41it/s]
#
#
#
# Dedup S2:  41%|████▏     | 90/217 [01:34<01:28,  1.44it/s]
#
#
#
# Dedup S2:  42%|████▏     | 91/217 [01:35<01:26,  1.46it/s]
#
#
#
# Dedup S2:  42%|████▏     | 92/217 [01:36<01:35,  1.31it/s]
#
#
#
# Dedup S2:  43%|████▎     | 93/217 [01:36<01:30,  1.38it/s]
#
#
#
# Dedup S2:  43%|████▎     | 94/217 [01:37<01:26,  1.43it/s]
#
#
#
# Dedup S2:  44%|████▍     | 95/217 [01:38<01:22,  1.47it/s]
#
#
#
# Dedup S2:  44%|████▍     | 96/217 [01:38<01:19,  1.52it/s]
#
#
#
# Dedup S2:  45%|████▍     | 97/217 [01:39<01:27,  1.37it/s]
#
#
#
# Dedup S2:  45%|████▌     | 98/217 [01:40<01:21,  1.45it/s]
#
#
#
# Dedup S2:  46%|████▌     | 99/217 [01:40<01:17,  1.51it/s]
#
#
#
# Dedup S2:  46%|████▌     | 100/217 [01:41<01:14,  1.57it/s]
#
#
#
# Dedup S2:  47%|████▋     | 101/217 [01:42<01:11,  1.62it/s]
#
#
#
# Dedup S2:  47%|████▋     | 102/217 [01:42<01:18,  1.46it/s]
#
#
#
# Dedup S2:  47%|████▋     | 103/217 [01:43<01:13,  1.55it/s]
#
#
#
# Dedup S2:  48%|████▊     | 104/217 [01:43<01:10,  1.60it/s]
#
#
#
# Dedup S2:  48%|████▊     | 105/217 [01:44<01:08,  1.64it/s]
#
#
#
# Dedup S2:  49%|████▉     | 106/217 [01:45<01:06,  1.68it/s]
#
#
#
# Dedup S2:  49%|████▉     | 107/217 [01:45<01:11,  1.54it/s]
#
#
#
# Dedup S2:  50%|████▉     | 108/217 [01:46<01:07,  1.62it/s]
#
#
#
# Dedup S2:  50%|█████     | 109/217 [01:47<01:04,  1.67it/s]
#
#
#
# Dedup S2:  51%|█████     | 110/217 [01:47<01:02,  1.71it/s]
#
#
#
# Dedup S2:  51%|█████     | 111/217 [01:48<01:01,  1.72it/s]
#
#
#
# Dedup S2:  52%|█████▏    | 112/217 [01:48<01:07,  1.55it/s]
#
#
#
# Dedup S2:  52%|█████▏    | 113/217 [01:49<01:03,  1.64it/s]
#
#
#
# Dedup S2:  53%|█████▎    | 114/217 [01:49<01:00,  1.70it/s]
#
#
#
# Dedup S2:  53%|█████▎    | 115/217 [01:50<00:58,  1.75it/s]
#
#
#
# Dedup S2:  53%|█████▎    | 116/217 [01:51<00:56,  1.79it/s]
#
#
#
# Dedup S2:  54%|█████▍    | 117/217 [01:51<01:00,  1.64it/s]
#
#
#
# Dedup S2:  54%|█████▍    | 118/217 [01:52<00:56,  1.74it/s]
#
#
#
# Dedup S2:  55%|█████▍    | 119/217 [01:52<00:54,  1.79it/s]
#
#
#
# Dedup S2:  55%|█████▌    | 120/217 [01:53<00:52,  1.83it/s]
#
#
#
# Dedup S2:  56%|█████▌    | 121/217 [01:53<00:51,  1.86it/s]
#
#
#
# Dedup S2:  56%|█████▌    | 122/217 [01:54<00:55,  1.71it/s]
#
#
#
# Dedup S2:  57%|█████▋    | 123/217 [01:54<00:51,  1.82it/s]
#
#
#
# Dedup S2:  57%|█████▋    | 124/217 [01:55<00:49,  1.88it/s]
#
#
#
# Dedup S2:  58%|█████▊    | 125/217 [01:55<00:47,  1.94it/s]
#
#
#
# Dedup S2:  58%|█████▊    | 126/217 [01:56<00:46,  1.97it/s]
#
#
#
# Dedup S2:  59%|█████▊    | 127/217 [01:57<00:49,  1.82it/s]
#
#
#
# Dedup S2:  59%|█████▉    | 128/217 [01:57<00:46,  1.90it/s]
#
#
#
# Dedup S2:  59%|█████▉    | 129/217 [01:58<00:45,  1.95it/s]
#
#
#
# Dedup S2:  60%|█████▉    | 130/217 [01:58<00:43,  1.99it/s]
#
#
#
# Dedup S2:  60%|██████    | 131/217 [01:58<00:42,  2.03it/s]
#
#
#
# Dedup S2:  61%|██████    | 132/217 [01:59<00:45,  1.85it/s]
#
#
#
# Dedup S2:  61%|██████▏   | 133/217 [02:00<00:42,  1.97it/s]
#
#
#
# Dedup S2:  62%|██████▏   | 134/217 [02:00<00:40,  2.06it/s]
#
#
#
# Dedup S2:  62%|██████▏   | 135/217 [02:00<00:38,  2.12it/s]
#
#
#
# Dedup S2:  63%|██████▎   | 136/217 [02:01<00:37,  2.17it/s]
#
#
#
# Dedup S2:  63%|██████▎   | 137/217 [02:01<00:39,  2.03it/s]
#
#
#
# Dedup S2:  64%|██████▎   | 138/217 [02:02<00:37,  2.11it/s]
#
#
#
# Dedup S2:  64%|██████▍   | 139/217 [02:02<00:36,  2.16it/s]
#
#
#
# Dedup S2:  65%|██████▍   | 140/217 [02:03<00:34,  2.21it/s]
#
#
#
# Dedup S2:  65%|██████▍   | 141/217 [02:03<00:33,  2.26it/s]
#
#
#
# Dedup S2:  65%|██████▌   | 142/217 [02:04<00:35,  2.10it/s]
#
#
#
# Dedup S2:  66%|██████▌   | 143/217 [02:04<00:33,  2.21it/s]
#
#
#
# Dedup S2:  66%|██████▋   | 144/217 [02:05<00:32,  2.25it/s]
#
#
#
# Dedup S2:  67%|██████▋   | 145/217 [02:05<00:30,  2.32it/s]
#
#
#
# Dedup S2:  67%|██████▋   | 146/217 [02:05<00:30,  2.35it/s]
#
#
#
# Dedup S2:  68%|██████▊   | 147/217 [02:06<00:31,  2.20it/s]
#
#
#
# Dedup S2:  68%|██████▊   | 148/217 [02:06<00:29,  2.31it/s]
#
#
#
# Dedup S2:  69%|██████▊   | 149/217 [02:07<00:28,  2.41it/s]
#
#
#
# Dedup S2:  69%|██████▉   | 150/217 [02:07<00:27,  2.46it/s]
#
#
#
# Dedup S2:  70%|██████▉   | 151/217 [02:07<00:26,  2.51it/s]
#
#
#
# Dedup S2:  70%|███████   | 152/217 [02:08<00:27,  2.34it/s]
#
#
#
# Dedup S2:  71%|███████   | 153/217 [02:08<00:26,  2.45it/s]
#
#
#
# Dedup S2:  71%|███████   | 154/217 [02:09<00:25,  2.52it/s]
#
#
#
# Dedup S2:  71%|███████▏  | 155/217 [02:09<00:23,  2.58it/s]
#
#
#
# Dedup S2:  72%|███████▏  | 156/217 [02:09<00:22,  2.66it/s]
#
#
#
# Dedup S2:  72%|███████▏  | 157/217 [02:10<00:24,  2.48it/s]
#
#
#
# Dedup S2:  73%|███████▎  | 158/217 [02:10<00:22,  2.63it/s]
#
#
#
# Dedup S2:  73%|███████▎  | 159/217 [02:10<00:21,  2.72it/s]
#
#
#
# Dedup S2:  74%|███████▎  | 160/217 [02:11<00:20,  2.82it/s]
#
#
#
# Dedup S2:  74%|███████▍  | 161/217 [02:11<00:19,  2.89it/s]
#
#
#
# Dedup S2:  75%|███████▍  | 162/217 [02:12<00:20,  2.71it/s]
#
#
#
# Dedup S2:  75%|███████▌  | 163/217 [02:12<00:18,  2.87it/s]
#
#
#
# Dedup S2:  76%|███████▌  | 164/217 [02:12<00:17,  2.97it/s]
#
#
#
# Dedup S2:  76%|███████▌  | 165/217 [02:12<00:17,  3.04it/s]
#
#
#
# Dedup S2:  76%|███████▋  | 166/217 [02:13<00:16,  3.18it/s]
#
#
#
# Dedup S2:  77%|███████▋  | 167/217 [02:13<00:16,  3.02it/s]
#
#
#
# Dedup S2:  77%|███████▋  | 168/217 [02:13<00:15,  3.13it/s]
#
#
#
# Dedup S2:  78%|███████▊  | 169/217 [02:14<00:14,  3.24it/s]
#
#
#
# Dedup S2:  78%|███████▊  | 170/217 [02:14<00:14,  3.33it/s]
#
#
#
# Dedup S2:  79%|███████▉  | 171/217 [02:14<00:13,  3.45it/s]
#
#
#
# Dedup S2:  79%|███████▉  | 172/217 [02:15<00:13,  3.27it/s]
#
#
#
# Dedup S2:  80%|███████▉  | 173/217 [02:15<00:12,  3.44it/s]
#
#
#
# Dedup S2:  80%|████████  | 174/217 [02:15<00:12,  3.50it/s]
#
#
#
# Dedup S2:  81%|████████  | 175/217 [02:15<00:11,  3.66it/s]
#
#
#
# Dedup S2:  81%|████████  | 176/217 [02:16<00:11,  3.65it/s]
#
#
#
# Dedup S2:  82%|████████▏ | 177/217 [02:16<00:11,  3.61it/s]
#
#
#
# Dedup S2:  82%|████████▏ | 178/217 [02:16<00:10,  3.63it/s]
#
#
#
# Dedup S2:  82%|████████▏ | 179/217 [02:16<00:10,  3.63it/s]
#
#
#
# Dedup S2:  83%|████████▎ | 180/217 [02:17<00:10,  3.65it/s]
#
#
#
# Dedup S2:  83%|████████▎ | 181/217 [02:17<00:09,  3.66it/s]
#
#
#
# Dedup S2:  84%|████████▍ | 182/217 [02:17<00:09,  3.70it/s]
#
#
#
# Dedup S2:  84%|████████▍ | 183/217 [02:17<00:08,  3.96it/s]
#
#
#
# Dedup S2:  85%|████████▍ | 184/217 [02:18<00:07,  4.18it/s]
#
#
#
# Dedup S2:  85%|████████▌ | 185/217 [02:18<00:07,  4.44it/s]
#
#
#
# Dedup S2:  86%|████████▌ | 186/217 [02:18<00:06,  4.61it/s]
#
#
#
# Dedup S2:  86%|████████▌ | 187/217 [02:18<00:06,  4.54it/s]
#
#
#
# Dedup S2:  87%|████████▋ | 188/217 [02:18<00:06,  4.74it/s]
#
#
#
# Dedup S2:  87%|████████▋ | 189/217 [02:19<00:05,  4.98it/s]
#
#
#
# Dedup S2:  88%|████████▊ | 190/217 [02:19<00:05,  5.29it/s]
#
#
#
# Dedup S2:  88%|████████▊ | 191/217 [02:19<00:04,  5.45it/s]
#
#
#
# Dedup S2:  88%|████████▊ | 192/217 [02:19<00:04,  5.37it/s]
#
#
#
# Dedup S2:  89%|████████▉ | 193/217 [02:19<00:04,  5.65it/s]
#
#
#
# Dedup S2:  89%|████████▉ | 194/217 [02:20<00:03,  5.83it/s]
#
#
#
# Dedup S2:  90%|████████▉ | 195/217 [02:20<00:03,  6.11it/s]
#
#
#
# Dedup S2:  90%|█████████ | 196/217 [02:20<00:03,  6.28it/s]
#
#
#
# Dedup S2:  91%|█████████ | 197/217 [02:20<00:03,  6.33it/s]
#
#
#
# Dedup S2:  91%|█████████ | 198/217 [02:20<00:02,  6.67it/s]
#
#
#
# Dedup S2:  92%|█████████▏| 199/217 [02:20<00:02,  6.81it/s]
#
#
#
# Dedup S2:  92%|█████████▏| 200/217 [02:20<00:02,  7.02it/s]
#
#
#
# Dedup S2:  93%|█████████▎| 201/217 [02:20<00:02,  7.15it/s]
#
#
#
# Dedup S2:  93%|█████████▎| 202/217 [02:21<00:02,  7.47it/s]
#
#
#
# Dedup S2:  94%|█████████▎| 203/217 [02:21<00:01,  7.87it/s]
#
#
#
# Dedup S2:  94%|█████████▍| 204/217 [02:21<00:01,  8.31it/s]
#
#
#
# Dedup S2:  95%|█████████▍| 206/217 [02:21<00:01,  9.00it/s]
#
#
#
# Dedup S2:  96%|█████████▌| 208/217 [02:21<00:00, 10.01it/s]
#
#
#
# Dedup S2:  97%|█████████▋| 210/217 [02:21<00:00, 11.47it/s]
#
#
#
# Dedup S2: 100%|██████████| 217/217 [02:21<00:00,  1.53it/s]
#
#
#
#
# Dedup S1 and S2:   0%|          | 0/205 [00:00<?, ?it/s]
#
#
#
# Dedup S1 and S2:   0%|          | 1/205 [00:01<03:41,  1.09s/it]
#
#
#
# Dedup S1 and S2:   1%|          | 2/205 [00:02<03:41,  1.09s/it]
#
#
#
# Dedup S1 and S2:   1%|▏         | 3/205 [00:03<04:10,  1.24s/it]
#
#
#
# Dedup S1 and S2:   2%|▏         | 4/205 [00:05<04:30,  1.35s/it]
#
#
#
# Dedup S1 and S2:   2%|▏         | 5/205 [00:06<04:44,  1.42s/it]
#
#
#
# Dedup S1 and S2:   3%|▎         | 6/205 [00:08<04:47,  1.45s/it]
#
#
#
# Dedup S1 and S2:   3%|▎         | 7/205 [00:09<04:23,  1.33s/it]
#
#
#
# Dedup S1 and S2:   4%|▍         | 8/205 [00:10<04:09,  1.26s/it]
#
#
#
# Dedup S1 and S2:   4%|▍         | 9/205 [00:12<04:29,  1.37s/it]
#
#
#
# Dedup S1 and S2:   5%|▍         | 10/205 [00:13<04:42,  1.45s/it]
#
#
#
# Dedup S1 and S2:   5%|▌         | 11/205 [00:15<04:49,  1.49s/it]
#
#
#
# Dedup S1 and S2:   6%|▌         | 12/205 [00:17<04:53,  1.52s/it]
#
#
#
# Dedup S1 and S2:   6%|▋         | 13/205 [00:18<04:27,  1.39s/it]
#
#
#
# Dedup S1 and S2:   7%|▋         | 14/205 [00:19<04:09,  1.31s/it]
#
#
#
# Dedup S1 and S2:   7%|▋         | 15/205 [00:20<04:21,  1.37s/it]
#
#
#
# Dedup S1 and S2:   8%|▊         | 16/205 [00:22<04:30,  1.43s/it]
#
#
#
# Dedup S1 and S2:   8%|▊         | 17/205 [00:23<04:35,  1.46s/it]
#
#
#
# Dedup S1 and S2:   9%|▉         | 18/205 [00:25<04:37,  1.49s/it]
#
#
#
# Dedup S1 and S2:   9%|▉         | 19/205 [00:26<04:16,  1.38s/it]
#
#
#
# Dedup S1 and S2:  10%|▉         | 20/205 [00:27<04:02,  1.31s/it]
#
#
#
# Dedup S1 and S2:  10%|█         | 21/205 [00:29<04:16,  1.39s/it]
#
#
#
# Dedup S1 and S2:  11%|█         | 22/205 [00:30<04:28,  1.47s/it]
#
#
#
# Dedup S1 and S2:  11%|█         | 23/205 [00:32<04:35,  1.51s/it]
#
#
#
# Dedup S1 and S2:  12%|█▏        | 24/205 [00:34<04:36,  1.53s/it]
#
#
#
# Dedup S1 and S2:  12%|█▏        | 25/205 [00:35<04:11,  1.40s/it]
#
#
#
# Dedup S1 and S2:  13%|█▎        | 26/205 [00:36<03:58,  1.33s/it]
#
#
#
# Dedup S1 and S2:  13%|█▎        | 27/205 [00:38<04:17,  1.45s/it]
#
#
#
# Dedup S1 and S2:  14%|█▎        | 28/205 [00:39<04:24,  1.49s/it]
#
#
#
# Dedup S1 and S2:  14%|█▍        | 29/205 [00:41<04:31,  1.54s/it]
#
#
#
# Dedup S1 and S2:  15%|█▍        | 30/205 [00:43<04:36,  1.58s/it]
#
#
#
# Dedup S1 and S2:  15%|█▌        | 31/205 [00:44<04:12,  1.45s/it]
#
#
#
# Dedup S1 and S2:  16%|█▌        | 32/205 [00:45<03:55,  1.36s/it]
#
#
#
# Dedup S1 and S2:  16%|█▌        | 33/205 [00:46<03:44,  1.30s/it]
#
#
#
# Dedup S1 and S2:  17%|█▋        | 34/205 [00:47<03:37,  1.27s/it]
#
#
#
# Dedup S1 and S2:  17%|█▋        | 35/205 [00:49<03:55,  1.38s/it]
#
#
#
# Dedup S1 and S2:  18%|█▊        | 36/205 [00:50<03:41,  1.31s/it]
#
#
#
# Dedup S1 and S2:  18%|█▊        | 37/205 [00:51<03:33,  1.27s/it]
#
#
#
# Dedup S1 and S2:  19%|█▊        | 38/205 [00:52<03:25,  1.23s/it]
#
#
#
# Dedup S1 and S2:  19%|█▉        | 39/205 [00:53<03:20,  1.21s/it]
#
#
#
# Dedup S1 and S2:  20%|█▉        | 40/205 [00:55<03:40,  1.34s/it]
#
#
#
# Dedup S1 and S2:  20%|██        | 41/205 [00:56<03:29,  1.28s/it]
#
#
#
# Dedup S1 and S2:  20%|██        | 42/205 [00:57<03:22,  1.24s/it]
#
#
#
# Dedup S1 and S2:  21%|██        | 43/205 [00:59<03:18,  1.22s/it]
#
#
#
# Dedup S1 and S2:  21%|██▏       | 44/205 [01:00<03:13,  1.20s/it]
#
#
#
# Dedup S1 and S2:  22%|██▏       | 45/205 [01:01<03:35,  1.34s/it]
#
#
#
# Dedup S1 and S2:  22%|██▏       | 46/205 [01:03<03:25,  1.29s/it]
#
#
#
# Dedup S1 and S2:  23%|██▎       | 47/205 [01:04<03:19,  1.26s/it]
#
#
#
# Dedup S1 and S2:  23%|██▎       | 48/205 [01:05<03:11,  1.22s/it]
#
#
#
# Dedup S1 and S2:  24%|██▍       | 49/205 [01:06<03:07,  1.20s/it]
#
#
#
# Dedup S1 and S2:  24%|██▍       | 50/205 [01:08<03:26,  1.33s/it]
#
#
#
# Dedup S1 and S2:  25%|██▍       | 51/205 [01:09<03:14,  1.26s/it]
#
#
#
# Dedup S1 and S2:  25%|██▌       | 52/205 [01:10<03:06,  1.22s/it]
#
#
#
# Dedup S1 and S2:  26%|██▌       | 53/205 [01:11<03:03,  1.21s/it]
#
#
#
# Dedup S1 and S2:  26%|██▋       | 54/205 [01:12<02:59,  1.19s/it]
#
#
#
# Dedup S1 and S2:  27%|██▋       | 55/205 [01:14<03:17,  1.32s/it]
#
#
#
# Dedup S1 and S2:  27%|██▋       | 56/205 [01:15<03:07,  1.26s/it]
#
#
#
# Dedup S1 and S2:  28%|██▊       | 57/205 [01:16<03:00,  1.22s/it]
#
#
#
# Dedup S1 and S2:  28%|██▊       | 58/205 [01:17<02:56,  1.20s/it]
#
#
#
# Dedup S1 and S2:  29%|██▉       | 59/205 [01:18<02:52,  1.18s/it]
#
#
#
# Dedup S1 and S2:  29%|██▉       | 60/205 [01:20<03:06,  1.29s/it]
#
#
#
# Dedup S1 and S2:  30%|██▉       | 61/205 [01:21<02:58,  1.24s/it]
#
#
#
# Dedup S1 and S2:  30%|███       | 62/205 [01:22<02:52,  1.20s/it]
#
#
#
# Dedup S1 and S2:  31%|███       | 63/205 [01:23<02:47,  1.18s/it]
#
#
#
# Dedup S1 and S2:  31%|███       | 64/205 [01:24<02:43,  1.16s/it]
#
#
#
# Dedup S1 and S2:  32%|███▏      | 65/205 [01:26<03:00,  1.29s/it]
#
#
#
# Dedup S1 and S2:  32%|███▏      | 66/205 [01:27<02:52,  1.24s/it]
#
#
#
# Dedup S1 and S2:  33%|███▎      | 67/205 [01:28<02:47,  1.21s/it]
#
#
#
# Dedup S1 and S2:  33%|███▎      | 68/205 [01:29<02:43,  1.20s/it]
#
#
#
# Dedup S1 and S2:  34%|███▎      | 69/205 [01:31<02:41,  1.19s/it]
#
#
#
# Dedup S1 and S2:  34%|███▍      | 70/205 [01:32<02:57,  1.31s/it]
#
#
#
# Dedup S1 and S2:  35%|███▍      | 71/205 [01:33<02:47,  1.25s/it]
#
#
#
# Dedup S1 and S2:  35%|███▌      | 72/205 [01:34<02:41,  1.21s/it]
#
#
#
# Dedup S1 and S2:  36%|███▌      | 73/205 [01:36<02:37,  1.19s/it]
#
#
#
# Dedup S1 and S2:  36%|███▌      | 74/205 [01:37<02:36,  1.19s/it]
#
#
#
# Dedup S1 and S2:  37%|███▋      | 75/205 [01:38<02:53,  1.33s/it]
#
#
#
# Dedup S1 and S2:  37%|███▋      | 76/205 [01:40<02:43,  1.27s/it]
#
#
#
# Dedup S1 and S2:  38%|███▊      | 77/205 [01:41<02:38,  1.24s/it]
#
#
#
# Dedup S1 and S2:  38%|███▊      | 78/205 [01:42<02:33,  1.21s/it]
#
#
#
# Dedup S1 and S2:  39%|███▊      | 79/205 [01:43<02:30,  1.19s/it]
#
#
#
# Dedup S1 and S2:  39%|███▉      | 80/205 [01:45<02:43,  1.31s/it]
#
#
#
# Dedup S1 and S2:  40%|███▉      | 81/205 [01:46<02:35,  1.26s/it]
#
#
#
# Dedup S1 and S2:  40%|████      | 82/205 [01:47<02:33,  1.25s/it]
#
#
#
# Dedup S1 and S2:  40%|████      | 83/205 [01:48<02:30,  1.23s/it]
#
#
#
# Dedup S1 and S2:  41%|████      | 84/205 [01:49<02:28,  1.23s/it]
#
#
#
# Dedup S1 and S2:  41%|████▏     | 85/205 [01:51<02:44,  1.37s/it]
#
#
#
# Dedup S1 and S2:  42%|████▏     | 86/205 [01:52<02:34,  1.30s/it]
#
#
#
# Dedup S1 and S2:  42%|████▏     | 87/205 [01:53<02:29,  1.27s/it]
#
#
#
# Dedup S1 and S2:  43%|████▎     | 88/205 [01:55<02:23,  1.23s/it]
#
#
#
# Dedup S1 and S2:  43%|████▎     | 89/205 [01:56<02:20,  1.21s/it]
#
#
#
# Dedup S1 and S2:  44%|████▍     | 90/205 [01:57<02:34,  1.34s/it]
#
#
#
# Dedup S1 and S2:  44%|████▍     | 91/205 [01:59<02:26,  1.28s/it]
#
#
#
# Dedup S1 and S2:  45%|████▍     | 92/205 [02:00<02:20,  1.24s/it]
#
#
#
# Dedup S1 and S2:  45%|████▌     | 93/205 [02:01<02:15,  1.21s/it]
#
#
#
# Dedup S1 and S2:  46%|████▌     | 94/205 [02:02<02:12,  1.20s/it]
#
#
#
# Dedup S1 and S2:  46%|████▋     | 95/205 [02:04<02:25,  1.32s/it]
#
#
#
# Dedup S1 and S2:  47%|████▋     | 96/205 [02:05<02:17,  1.26s/it]
#
#
#
# Dedup S1 and S2:  47%|████▋     | 97/205 [02:06<02:12,  1.23s/it]
#
#
#
# Dedup S1 and S2:  48%|████▊     | 98/205 [02:07<02:09,  1.21s/it]
#
#
#
# Dedup S1 and S2:  48%|████▊     | 99/205 [02:08<02:06,  1.20s/it]
#
#
#
# Dedup S1 and S2:  49%|████▉     | 100/205 [02:10<02:18,  1.32s/it]
#
#
#
# Dedup S1 and S2:  49%|████▉     | 101/205 [02:11<02:14,  1.29s/it]
#
#
#
# Dedup S1 and S2:  50%|████▉     | 102/205 [02:12<02:09,  1.26s/it]
#
#
#
# Dedup S1 and S2:  50%|█████     | 103/205 [02:13<02:06,  1.24s/it]
#
#
#
# Dedup S1 and S2:  51%|█████     | 104/205 [02:15<02:03,  1.23s/it]
#
#
#
# Dedup S1 and S2:  51%|█████     | 105/205 [02:16<02:13,  1.34s/it]
#
#
#
# Dedup S1 and S2:  52%|█████▏    | 106/205 [02:17<02:06,  1.28s/it]
#
#
#
# Dedup S1 and S2:  52%|█████▏    | 107/205 [02:19<02:01,  1.24s/it]
#
#
#
# Dedup S1 and S2:  53%|█████▎    | 108/205 [02:20<01:58,  1.22s/it]
#
#
#
# Dedup S1 and S2:  53%|█████▎    | 109/205 [02:21<01:54,  1.20s/it]
#
#
#
# Dedup S1 and S2:  54%|█████▎    | 110/205 [02:22<02:04,  1.31s/it]
#
#
#
# Dedup S1 and S2:  54%|█████▍    | 111/205 [02:23<01:57,  1.25s/it]
#
#
#
# Dedup S1 and S2:  55%|█████▍    | 112/205 [02:25<01:52,  1.20s/it]
#
#
#
# Dedup S1 and S2:  55%|█████▌    | 113/205 [02:26<01:48,  1.18s/it]
#
#
#
# Dedup S1 and S2:  56%|█████▌    | 114/205 [02:27<01:46,  1.17s/it]
#
#
#
# Dedup S1 and S2:  56%|█████▌    | 115/205 [02:28<01:56,  1.29s/it]
#
#
#
# Dedup S1 and S2:  57%|█████▋    | 116/205 [02:30<01:50,  1.24s/it]
#
#
#
# Dedup S1 and S2:  57%|█████▋    | 117/205 [02:31<01:46,  1.21s/it]
#
#
#
# Dedup S1 and S2:  58%|█████▊    | 118/205 [02:32<01:43,  1.19s/it]
#
#
#
# Dedup S1 and S2:  58%|█████▊    | 119/205 [02:33<01:40,  1.17s/it]
#
#
#
# Dedup S1 and S2:  59%|█████▊    | 120/205 [02:34<01:48,  1.27s/it]
#
#
#
# Dedup S1 and S2:  59%|█████▉    | 121/205 [02:36<01:42,  1.22s/it]
#
#
#
# Dedup S1 and S2:  60%|█████▉    | 122/205 [02:37<01:38,  1.19s/it]
#
#
#
# Dedup S1 and S2:  60%|██████    | 123/205 [02:38<01:36,  1.17s/it]
#
#
#
# Dedup S1 and S2:  60%|██████    | 124/205 [02:39<01:33,  1.15s/it]
#
#
#
# Dedup S1 and S2:  61%|██████    | 125/205 [02:41<01:42,  1.29s/it]
#
#
#
# Dedup S1 and S2:  61%|██████▏   | 126/205 [02:42<01:38,  1.24s/it]
#
#
#
# Dedup S1 and S2:  62%|██████▏   | 127/205 [02:43<01:34,  1.21s/it]
#
#
#
# Dedup S1 and S2:  62%|██████▏   | 128/205 [02:44<01:31,  1.19s/it]
#
#
#
# Dedup S1 and S2:  63%|██████▎   | 129/205 [02:45<01:29,  1.17s/it]
#
#
#
# Dedup S1 and S2:  63%|██████▎   | 130/205 [02:47<01:38,  1.31s/it]
#
#
#
# Dedup S1 and S2:  64%|██████▍   | 131/205 [02:48<01:32,  1.25s/it]
#
#
#
# Dedup S1 and S2:  64%|██████▍   | 132/205 [02:49<01:27,  1.20s/it]
#
#
#
# Dedup S1 and S2:  65%|██████▍   | 133/205 [02:50<01:24,  1.18s/it]
#
#
#
# Dedup S1 and S2:  65%|██████▌   | 134/205 [02:51<01:21,  1.15s/it]
#
#
#
# Dedup S1 and S2:  66%|██████▌   | 135/205 [02:53<01:28,  1.26s/it]
#
#
#
# Dedup S1 and S2:  66%|██████▋   | 136/205 [02:54<01:22,  1.20s/it]
#
#
#
# Dedup S1 and S2:  67%|██████▋   | 137/205 [02:55<01:19,  1.16s/it]
#
#
#
# Dedup S1 and S2:  67%|██████▋   | 138/205 [02:56<01:17,  1.15s/it]
#
#
#
# Dedup S1 and S2:  68%|██████▊   | 139/205 [02:57<01:15,  1.14s/it]
#
#
#
# Dedup S1 and S2:  68%|██████▊   | 140/205 [02:59<01:23,  1.28s/it]
#
#
#
# Dedup S1 and S2:  69%|██████▉   | 141/205 [03:00<01:18,  1.22s/it]
#
#
#
# Dedup S1 and S2:  69%|██████▉   | 142/205 [03:01<01:15,  1.20s/it]
#
#
#
# Dedup S1 and S2:  70%|██████▉   | 143/205 [03:02<01:12,  1.17s/it]
#
#
#
# Dedup S1 and S2:  70%|███████   | 144/205 [03:03<01:10,  1.16s/it]
#
#
#
# Dedup S1 and S2:  71%|███████   | 145/205 [03:05<01:16,  1.27s/it]
#
#
#
# Dedup S1 and S2:  71%|███████   | 146/205 [03:06<01:11,  1.21s/it]
#
#
#
# Dedup S1 and S2:  72%|███████▏  | 147/205 [03:07<01:07,  1.16s/it]
#
#
#
# Dedup S1 and S2:  72%|███████▏  | 148/205 [03:08<01:05,  1.14s/it]
#
#
#
# Dedup S1 and S2:  73%|███████▎  | 149/205 [03:09<01:03,  1.13s/it]
#
#
#
# Dedup S1 and S2:  73%|███████▎  | 150/205 [03:10<01:09,  1.27s/it]
#
#
#
# Dedup S1 and S2:  74%|███████▎  | 151/205 [03:12<01:06,  1.22s/it]
#
#
#
# Dedup S1 and S2:  74%|███████▍  | 152/205 [03:13<01:03,  1.20s/it]
#
#
#
# Dedup S1 and S2:  75%|███████▍  | 153/205 [03:14<01:01,  1.18s/it]
#
#
#
# Dedup S1 and S2:  75%|███████▌  | 154/205 [03:15<00:59,  1.17s/it]
#
#
#
# Dedup S1 and S2:  76%|███████▌  | 155/205 [03:17<01:04,  1.29s/it]
#
#
#
# Dedup S1 and S2:  76%|███████▌  | 156/205 [03:18<01:00,  1.24s/it]
#
#
#
# Dedup S1 and S2:  77%|███████▋  | 157/205 [03:19<00:57,  1.20s/it]
#
#
#
# Dedup S1 and S2:  77%|███████▋  | 158/205 [03:20<00:55,  1.19s/it]
#
#
#
# Dedup S1 and S2:  78%|███████▊  | 159/205 [03:21<00:53,  1.17s/it]
#
#
#
# Dedup S1 and S2:  78%|███████▊  | 160/205 [03:23<00:57,  1.27s/it]
#
#
#
# Dedup S1 and S2:  79%|███████▊  | 161/205 [03:24<00:53,  1.22s/it]
#
#
#
# Dedup S1 and S2:  79%|███████▉  | 162/205 [03:25<00:50,  1.18s/it]
#
#
#
# Dedup S1 and S2:  80%|███████▉  | 163/205 [03:26<00:49,  1.18s/it]
#
#
#
# Dedup S1 and S2:  80%|████████  | 164/205 [03:27<00:47,  1.17s/it]
#
#
#
# Dedup S1 and S2:  80%|████████  | 165/205 [03:29<00:51,  1.29s/it]
#
#
#
# Dedup S1 and S2:  81%|████████  | 166/205 [03:30<00:53,  1.38s/it]
#
#
#
# Dedup S1 and S2:  81%|████████▏ | 167/205 [03:32<00:54,  1.45s/it]
#
#
#
# Dedup S1 and S2:  82%|████████▏ | 168/205 [03:34<00:55,  1.51s/it]
#
#
#
# Dedup S1 and S2:  82%|████████▏ | 169/205 [03:35<00:55,  1.54s/it]
#
#
#
# Dedup S1 and S2:  83%|████████▎ | 170/205 [03:37<00:54,  1.56s/it]
#
#
#
# Dedup S1 and S2:  83%|████████▎ | 171/205 [03:38<00:48,  1.43s/it]
#
#
#
# Dedup S1 and S2:  84%|████████▍ | 172/205 [03:39<00:44,  1.33s/it]
#
#
#
# Dedup S1 and S2:  84%|████████▍ | 173/205 [03:40<00:40,  1.28s/it]
#
#
#
# Dedup S1 and S2:  85%|████████▍ | 174/205 [03:41<00:38,  1.25s/it]
#
#
#
# Dedup S1 and S2:  85%|████████▌ | 175/205 [03:43<00:40,  1.34s/it]
#
#
#
# Dedup S1 and S2:  86%|████████▌ | 176/205 [03:44<00:37,  1.28s/it]
#
#
#
# Dedup S1 and S2:  86%|████████▋ | 177/205 [03:45<00:34,  1.24s/it]
#
#
#
# Dedup S1 and S2:  87%|████████▋ | 178/205 [03:46<00:32,  1.22s/it]
#
#
#
# Dedup S1 and S2:  87%|████████▋ | 179/205 [03:47<00:31,  1.20s/it]
#
#
#
# Dedup S1 and S2:  88%|████████▊ | 180/205 [03:49<00:33,  1.33s/it]
#
#
#
# Dedup S1 and S2:  88%|████████▊ | 181/205 [03:50<00:30,  1.28s/it]
#
#
#
# Dedup S1 and S2:  89%|████████▉ | 182/205 [03:51<00:28,  1.25s/it]
#
#
#
# Dedup S1 and S2:  89%|████████▉ | 183/205 [03:53<00:26,  1.21s/it]
#
#
#
# Dedup S1 and S2:  90%|████████▉ | 184/205 [03:54<00:24,  1.19s/it]
#
#
#
# Dedup S1 and S2:  90%|█████████ | 185/205 [03:55<00:25,  1.30s/it]
#
#
#
# Dedup S1 and S2:  91%|█████████ | 186/205 [03:56<00:23,  1.26s/it]
#
#
#
# Dedup S1 and S2:  91%|█████████ | 187/205 [03:58<00:22,  1.23s/it]
#
#
#
# Dedup S1 and S2:  92%|█████████▏| 188/205 [03:59<00:20,  1.21s/it]
#
#
#
# Dedup S1 and S2:  92%|█████████▏| 189/205 [04:00<00:19,  1.20s/it]
#
#
#
# Dedup S1 and S2:  93%|█████████▎| 190/205 [04:02<00:20,  1.35s/it]
#
#
#
# Dedup S1 and S2:  93%|█████████▎| 191/205 [04:03<00:20,  1.44s/it]
#
#
#
# Dedup S1 and S2:  94%|█████████▎| 192/205 [04:05<00:19,  1.50s/it]
#
#
#
# Dedup S1 and S2:  94%|█████████▍| 193/205 [04:07<00:18,  1.55s/it]
#
#
#
# Dedup S1 and S2:  95%|█████████▍| 194/205 [04:08<00:17,  1.58s/it]
#
#
#
# Dedup S1 and S2:  95%|█████████▌| 195/205 [04:10<00:15,  1.60s/it]
#
#
#
# Dedup S1 and S2:  96%|█████████▌| 196/205 [04:11<00:13,  1.46s/it]
#
#
#
# Dedup S1 and S2:  96%|█████████▌| 197/205 [04:13<00:12,  1.51s/it]
#
#
#
# Dedup S1 and S2:  97%|█████████▋| 198/205 [04:14<00:09,  1.39s/it]
#
#
#
# Dedup S1 and S2:  97%|█████████▋| 199/205 [04:15<00:08,  1.49s/it]
#
#
#
# Dedup S1 and S2:  98%|█████████▊| 200/205 [04:17<00:06,  1.38s/it]
#
#
#
# Dedup S1 and S2:  98%|█████████▊| 201/205 [04:18<00:05,  1.47s/it]
#
#
#
# Dedup S1 and S2:  99%|█████████▊| 202/205 [04:19<00:04,  1.36s/it]
#
#
#
# Dedup S1 and S2:  99%|█████████▉| 203/205 [04:21<00:02,  1.45s/it]
#
#
#
# Dedup S1 and S2: 100%|█████████▉| 204/205 [04:23<00:01,  1.51s/it]
#
#
#
# Dedup S1 and S2: 100%|██████████| 205/205 [04:24<00:00,  1.29s/it]
#
#
#
#
# Gathering results: 100%|██████████| 2/2 [00:00<00:00, 39.22it/s]
#
#
#
#
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (419 / 422) | Bytes (2715120000 / 2656800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_900_900/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_900_900/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:15<01:16, 15.29s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (398 / 422) | Bytes (2579040000 / 2656800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_900_900/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_900_900/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:35<01:06, 16.68s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (385 / 422) | Bytes (2494800000 / 2656800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_900_900/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_900_900/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:55<00:53, 17.73s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (57 / 422) | Bytes (369360000 / 2656800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_900_900/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_900_900/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:14<00:36, 18.11s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (21 / 422) | Bytes (136080000 / 2656800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_900_900/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_900_900/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:36<00:19, 19.41s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (17 / 422) | Bytes (110160000 / 2656800000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_900_900/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_900_900/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:57<00:00, 19.85s/it]
# None

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        400,
        400,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model layers with size > 16 MB into blocks of size 400 X 400 and computing similarity across blocks
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 86.13it/s]
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 61.13it/s]
# Dedup S1:   0%|          | 0/957 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1: 100%|██████████| 957/957 [04:39<00:00,  3.42it/s]
# Dedup S2: 100%|██████████| 1001/1001 [04:57<00:00,  3.37it/s]
# Dedup S1 and S2: 100%|██████████| 957/957 [09:16<00:00,  1.72it/s]
# Gathering results: 100%|██████████| 2/2 [00:00<00:00,  3.60it/s]
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (1947 / 1958) | Bytes (2492160000 / 2449920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_400_400/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_400_400/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:19<01:39, 19.94s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (1854 / 1958) | Bytes (2373120000 / 2449920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_400_400/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_400_400/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:37<01:17, 19.36s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (1739 / 1958) | Bytes (2225920000 / 2449920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_400_400/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_400_400/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:56<00:57, 19.03s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (196 / 1958) | Bytes (250880000 / 2449920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_400_400/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_400_400/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:14<00:37, 18.78s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (159 / 1958) | Bytes (203520000 / 2449920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_400_400/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_400_400/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:33<00:18, 18.80s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (13 / 1958) | Bytes (16640000 / 2449920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_400_400/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_400_400/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:54<00:00, 19.67s/it]
# None

# %%
print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        300,
        300,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Splitting model layers with size > 16 MB into blocks of size 300 X 300 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 83.80it/s]
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Reshaped matrix from 3,786432 -> 576,4096
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 68.38it/s]
# Dedup S1:   0%|          | 0/1568 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1: 100%|██████████| 1568/1568 [07:15<00:00,  3.60it/s]
# Dedup S2: 100%|██████████| 1624/1624 [07:36<00:00,  3.56it/s]
# Dedup S1 and S2: 100%|██████████| 1568/1568 [14:27<00:00,  1.81it/s]
# Gathering results: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (3161 / 3192) | Bytes (2275920000 / 2257920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_300_300/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_300_300/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:23<01:55, 23.10s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (2933 / 3192) | Bytes (2111760000 / 2257920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_300_300/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_300_300/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:45<01:31, 22.80s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (2787 / 3192) | Bytes (2006640000 / 2257920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_300_300/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_300_300/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [01:04<01:04, 21.64s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (14 / 3192) | Bytes (10080000 / 2257920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_300_300/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_300_300/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:22<00:41, 20.62s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (1 / 3192) | Bytes (720000 / 2257920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_300_300/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_300_300/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:42<00:20, 20.61s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (0 / 3192) | Bytes (0 / 2257920000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_300_300/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_300_300/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [02:06<00:00, 21.44s/it]
# None

# %%
import gc
tf.keras.backend.clear_session()
gc.collect()

print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        200,
        200,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Splitting model layers with size > 16 MB into blocks of size 200 X 200 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 86.15it/s]
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Reshaped matrix from 3,786432 -> 288,8192
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 61.93it/s]
# Dedup S1:   0%|          | 0/3602 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1: 100%|██████████| 3602/3602 [13:12<00:00,  4.54it/s]
# Dedup S2: 100%|██████████| 3766/3766 [15:02<00:00,  4.17it/s]
# Dedup S1 and S2: 100%|██████████| 3602/3602 [27:23<00:00,  2.19it/s]
# Gathering results: 100%|██████████| 2/2 [00:12<00:00,  6.08s/it]
# Dumping deduplicated model pairs:   0%|          | 0/6 [00:00<?, ?it/s]
# Floating point threshold: 0.01, Block similarity threshold: 0.7 -> Blocks (7321 / 7368) | Bytes (2342720000 / 2305280000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.7_16_200_200/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.7_16_200_200/assets
# Dumping deduplicated model pairs:  17%|█▋        | 1/6 [00:13<01:08, 13.74s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.8 -> Blocks (6879 / 7368) | Bytes (2201280000 / 2305280000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.8_16_200_200/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.8_16_200_200/assets
# Dumping deduplicated model pairs:  33%|███▎      | 2/6 [00:32<01:00, 15.14s/it]
# Floating point threshold: 0.01, Block similarity threshold: 0.9 -> Blocks (6473 / 7368) | Bytes (2071360000 / 2305280000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.01_0.9_16_200_200/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.01_0.9_16_200_200/assets
# Dumping deduplicated model pairs:  50%|█████     | 3/6 [00:49<00:47, 15.88s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.7 -> Blocks (4 / 7368) | Bytes (1280000 / 2305280000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.7_16_200_200/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.7_16_200_200/assets
# Dumping deduplicated model pairs:  67%|██████▋   | 4/6 [01:07<00:32, 16.48s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.8 -> Blocks (3 / 7368) | Bytes (960000 / 2305280000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.8_16_200_200/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.8_16_200_200/assets
# Dumping deduplicated model pairs:  83%|████████▎ | 5/6 [01:27<00:17, 17.39s/it]
# Floating point threshold: 0.001, Block similarity threshold: 0.9 -> Blocks (0 / 7368) | Bytes (0 / 2305280000)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg16_0.001_0.9_16_200_200/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/models/vgg19_0.001_0.9_16_200_200/assets
# Dumping deduplicated model pairs: 100%|██████████| 6/6 [01:52<00:00, 19.88s/it]
# None

# %%
import gc
tf.keras.backend.clear_session()
gc.collect()

print(
    analyse_models_v2_and_dedup(
        vgg16,
        vgg19,
        {
            'fp': [0.01, 0.001],  # for different floating point thresholds
            'sim': [.7, .8, .9],  # for naive diff similarity percentage
            # 'diff': [.1, .2, .3], # for lsh difference
        },
        100,
        100,
        "/content/drive/MyDrive/Colab Notebooks",
        16,
        # , 256,
        build_dedup=True
    ))
# Out:
# Splitting model into blocks:   0%|          | 0/23 [00:00<?, ?it/s]
# Splitting model layers with size > 16 MB into blocks of size 100 X 100 and computing similarity across blocks
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Splitting model into blocks: 100%|██████████| 23/23 [00:00<00:00, 72.55it/s]
# Splitting model into blocks:   0%|          | 0/26 [00:00<?, ?it/s]
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Reshaped matrix from 3,786432 -> 144,16384
# Splitting model into blocks: 100%|██████████| 26/26 [00:00<00:00, 64.62it/s]
# Dedup S1:   0%|          | 0/14022 [00:00<?, ?it/s]
# Comparing block sets...
# Dedup S1:  19%|█▉        | 2667/14022 [20:56<1:20:00,  2.37it/s]

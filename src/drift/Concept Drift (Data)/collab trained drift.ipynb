# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

from tensorflow.keras.datasets import mnist
import keras

BASE_PATH = "/content/drive/MyDrive/Colab Notebooks/"

# %%
# Generate the train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)
 
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))
 
# Generate some noisy data
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
 
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 6s 1us/step

# %%
# sudden noisy dataset
x_train_sudden = np.vstack((x_train[:30000], x_train[:30000] + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train[:30000].shape)))
x_test_sudden = np.vstack((x_test[:30000], x_test[:30000] + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test[:30000].shape)))

x_train_sudden = np.clip(x_train_sudden, 0., 1.)
x_test_sudden = np.clip(x_test_sudden, 0., 1.)

# %%
# # incremental noisy dataset

act_res = []
po = np.linspace(0, 1, x_train.shape[0])
for i in range(x_train.shape[0]):
    act_res.append(np.random.choice(2, 1, p=[1-po[i], po[i]])[0])

noise = noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
for i in range(x_train.shape[0]):
    noise[i] *= act_res[i]

x_train_inc = x_train + noise
x_train_inc = np.clip(x_train_inc, 0., 1.)

act_res = []
po = np.linspace(0, 1, x_test.shape[0])
for i in range(x_test.shape[0]):
    act_res.append(np.random.choice(2, 1, p=[1-po[i], po[i]])[0])

noise = noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
for i in range(x_test.shape[0]):
    noise[i] *= act_res[i]

x_test_inc = x_test + noise
x_test_inc = np.clip(x_test_inc, 0., 1.)

# %%
# # gradual noisy dataset

x = np.linspace(-2*np.pi, 2*np.pi, int(x_train.shape[0] / 2))
arr = np.exp2(x)
start = 0
end = 1
width = end - start
res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
res[res>0.5] = 0.5
act_res = np.ones(x_train.shape[0])
act_res[:int(x_train.shape[0] / 2)] = res
act_res[int(x_train.shape[0] / 2):] = 0.5

noise = noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
for i in range(x_train.shape[0]):
    noise[i] *= act_res[i]

x_train_grad = x_train + noise
x_train_grad = np.clip(x_train_grad, 0., 1.)

x = np.linspace(-2*np.pi, 2*np.pi, int(x_test.shape[0] / 2))
arr = np.exp2(x)
start = 0
end = 1
width = end - start
res = (arr - arr.min())/(arr.max() - arr.min()) * width + start
res[res>0.5] = 0.5
act_res = np.ones(x_test.shape[0])
act_res[:int(x_test.shape[0] / 2)] = res
act_res[int(x_test.shape[0] / 2):] = 0.5

noise = noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
for i in range(x_test.shape[0]):
    noise[i] *= act_res[i]


x_test_grad = x_test + noise
x_test_grad = np.clip(x_test_grad, 0., 1.)

# %%
def make_model():
    model = Sequential()

    model.add(Conv2D(32,kernel_size=3,activation='relu',input_shape=(28,28,1)))
    model.add(BatchNormalization())
    model.add(Conv2D(32,kernel_size=3,activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(32,kernel_size=5,strides=2,padding='same',activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(64,kernel_size=3,activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64,kernel_size=3,activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64,kernel_size=5,strides=2,padding='same',activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

    return model

def train_model(model, x_train, y_train, name):
    filepath = BASE_PATH + name + "-{epoch:02d}"
    checkpoint = ModelCheckpoint(filepath, verbose=1, save_best_only=False, mode='auto', save_freq='epoch')
    epochs = 45
    annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** (x+epochs))
    model.fit(x_train, y_train, batch_size=64, epochs = epochs, steps_per_epoch = x_train.shape[0]//64, callbacks=[annealer, checkpoint])

# %%
model = make_model()
model.save(BASE_PATH + 'base_model')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/base_model/assets

# %% [markdown]
# Experiment 1 - full mnist model

# %%
m1 = tf.keras.models.load_model(BASE_PATH + 'base_model')
train_model(m1, x_train, y_train, 'based_model')
results = m1.evaluate(x_test, y_test)
results = m1.evaluate(x_test_noisy, y_test)
# Out:
# Epoch 1/45
# 937/937 [==============================] - 8s 7ms/step - loss: 0.8133 - accuracy: 0.7470
#
# Epoch 00001: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-01
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-01/assets
# Epoch 2/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.1874 - accuracy: 0.9426
#
# Epoch 00002: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-02
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-02/assets
# Epoch 3/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.1197 - accuracy: 0.9634
#
# Epoch 00003: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-03
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-03/assets
# Epoch 4/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0889 - accuracy: 0.9732
#
# Epoch 00004: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-04
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-04/assets
# Epoch 5/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0706 - accuracy: 0.9785
#
# Epoch 00005: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-05
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-05/assets
# Epoch 6/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0601 - accuracy: 0.9815
#
# Epoch 00006: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-06
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-06/assets
# Epoch 7/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0534 - accuracy: 0.9838
#
# Epoch 00007: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-07
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-07/assets
# Epoch 8/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0485 - accuracy: 0.9851
#
# Epoch 00008: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-08
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-08/assets
# Epoch 9/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0409 - accuracy: 0.9879
#
# Epoch 00009: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-09
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-09/assets
# Epoch 10/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0388 - accuracy: 0.9884
#
# Epoch 00010: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-10
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-10/assets
# Epoch 11/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0353 - accuracy: 0.9895
#
# Epoch 00011: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-11
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-11/assets
# Epoch 12/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0314 - accuracy: 0.9904
#
# Epoch 00012: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-12
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-12/assets
# Epoch 13/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0293 - accuracy: 0.9910
#
# Epoch 00013: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-13
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-13/assets
# Epoch 14/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0291 - accuracy: 0.9910
#
# Epoch 00014: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-14
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-14/assets
# Epoch 15/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0269 - accuracy: 0.9916
#
# Epoch 00015: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-15
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-15/assets
# Epoch 16/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0250 - accuracy: 0.9921
#
# Epoch 00016: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-16
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-16/assets
# Epoch 17/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0234 - accuracy: 0.9928
#
# Epoch 00017: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-17
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-17/assets
# Epoch 18/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0235 - accuracy: 0.9928
#
# Epoch 00018: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-18
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-18/assets
# Epoch 19/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0197 - accuracy: 0.9939
#
# Epoch 00019: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-19
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-19/assets
# Epoch 20/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0198 - accuracy: 0.9937
#
# Epoch 00020: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-20
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-20/assets
# Epoch 21/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0202 - accuracy: 0.9938
#
# Epoch 00021: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-21
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-21/assets
# Epoch 22/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0186 - accuracy: 0.9943
#
# Epoch 00022: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-22
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-22/assets
# Epoch 23/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0173 - accuracy: 0.9945
#
# Epoch 00023: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-23
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-23/assets
# Epoch 24/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0176 - accuracy: 0.9944
#
# Epoch 00024: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-24
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-24/assets
# Epoch 25/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0165 - accuracy: 0.9948
#
# Epoch 00025: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-25
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-25/assets
# Epoch 26/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0152 - accuracy: 0.9950
#
# Epoch 00026: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-26
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-26/assets
# Epoch 27/45
# 937/937 [==============================] - 7s 7ms/step - loss: 0.0151 - accuracy: 0.9952
#
# Epoch 00027: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-27
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-27/assets
# Epoch 28/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0155 - accuracy: 0.9952
#
# Epoch 00028: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-28
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-28/assets
# Epoch 29/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0144 - accuracy: 0.9955
#
# Epoch 00029: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-29
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-29/assets
# Epoch 30/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0131 - accuracy: 0.9957
#
# Epoch 00030: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-30
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-30/assets
# Epoch 31/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0127 - accuracy: 0.9962
#
# Epoch 00031: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-31
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-31/assets
# Epoch 32/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0137 - accuracy: 0.9956
#
# Epoch 00032: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-32
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-32/assets
# Epoch 33/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0128 - accuracy: 0.9964
#
# Epoch 00033: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-33
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-33/assets
# Epoch 34/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0131 - accuracy: 0.9960
#
# Epoch 00034: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-34
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-34/assets
# Epoch 35/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0125 - accuracy: 0.9964
#
# Epoch 00035: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-35
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-35/assets
# Epoch 36/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0124 - accuracy: 0.9963
#
# Epoch 00036: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-36
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-36/assets
# Epoch 37/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0120 - accuracy: 0.9962
#
# Epoch 00037: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-37
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-37/assets
# Epoch 38/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0116 - accuracy: 0.9966
#
# Epoch 00038: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-38
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-38/assets
# Epoch 39/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0104 - accuracy: 0.9968
#
# Epoch 00039: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-39
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-39/assets
# Epoch 40/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0106 - accuracy: 0.9965
#
# Epoch 00040: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-40
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-40/assets
# Epoch 41/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0103 - accuracy: 0.9967
#
# Epoch 00041: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-41
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-41/assets
# Epoch 42/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0102 - accuracy: 0.9969
#
# Epoch 00042: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-42
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-42/assets
# Epoch 43/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0099 - accuracy: 0.9970
#
# Epoch 00043: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-43
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-43/assets
# Epoch 44/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0105 - accuracy: 0.9968
#
# Epoch 00044: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-44
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-44/assets
# Epoch 45/45
# 937/937 [==============================] - 7s 8ms/step - loss: 0.0102 - accuracy: 0.9969
#
# Epoch 00045: saving model to /content/drive/MyDrive/Colab Notebooks/based_model-45
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/based_model-45/assets
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0161 - accuracy: 0.9950
# 313/313 [==============================] - 1s 3ms/step - loss: 4.9258 - accuracy: 0.2125

# %% [markdown]
# Experiment 2 - Sudden drift of 30k

# %%
m2 = tf.keras.models.load_model(BASE_PATH + 'based_model-45')
train_model(m2, x_train_noisy[:30000], y_train[:30000], 'sudden_drift_30000')
results = m2.evaluate(x_test, y_test)
results = m2.evaluate(x_test_noisy, y_test)
# Out:
# Epoch 1/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.2510 - accuracy: 0.9310
#
# Epoch 00001: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-01
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-01/assets
# Epoch 2/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.1506 - accuracy: 0.9549
#
# Epoch 00002: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-02
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-02/assets
# Epoch 3/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.1207 - accuracy: 0.9606
#
# Epoch 00003: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-03
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-03/assets
# Epoch 4/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.1071 - accuracy: 0.9656
#
# Epoch 00004: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-04
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-04/assets
# Epoch 5/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0996 - accuracy: 0.9678
#
# Epoch 00005: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-05
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-05/assets
# Epoch 6/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0885 - accuracy: 0.9710
#
# Epoch 00006: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-06
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-06/assets
# Epoch 7/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0874 - accuracy: 0.9717
#
# Epoch 00007: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-07
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-07/assets
# Epoch 8/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0771 - accuracy: 0.9743
#
# Epoch 00008: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-08
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-08/assets
# Epoch 9/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0762 - accuracy: 0.9753
#
# Epoch 00009: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-09
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-09/assets
# Epoch 10/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0732 - accuracy: 0.9767
#
# Epoch 00010: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-10
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-10/assets
# Epoch 11/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0684 - accuracy: 0.9771
#
# Epoch 00011: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-11
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-11/assets
# Epoch 12/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0692 - accuracy: 0.9770
#
# Epoch 00012: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-12
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-12/assets
# Epoch 13/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0628 - accuracy: 0.9788
#
# Epoch 00013: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-13
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-13/assets
# Epoch 14/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0587 - accuracy: 0.9809
#
# Epoch 00014: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-14
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-14/assets
# Epoch 15/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0573 - accuracy: 0.9798
#
# Epoch 00015: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-15
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-15/assets
# Epoch 16/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0570 - accuracy: 0.9806
#
# Epoch 00016: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-16
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-16/assets
# Epoch 17/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0506 - accuracy: 0.9834
#
# Epoch 00017: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-17
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-17/assets
# Epoch 18/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0513 - accuracy: 0.9827
#
# Epoch 00018: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-18
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-18/assets
# Epoch 19/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0470 - accuracy: 0.9843
#
# Epoch 00019: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-19
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-19/assets
# Epoch 20/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0485 - accuracy: 0.9840
#
# Epoch 00020: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-20
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-20/assets
# Epoch 21/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0444 - accuracy: 0.9848
#
# Epoch 00021: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-21
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-21/assets
# Epoch 22/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0425 - accuracy: 0.9859
#
# Epoch 00022: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-22
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-22/assets
# Epoch 23/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0412 - accuracy: 0.9857
#
# Epoch 00023: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-23
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-23/assets
# Epoch 24/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0396 - accuracy: 0.9866
#
# Epoch 00024: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-24
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-24/assets
# Epoch 25/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0404 - accuracy: 0.9862
#
# Epoch 00025: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-25
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-25/assets
# Epoch 26/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0384 - accuracy: 0.9870
#
# Epoch 00026: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-26
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-26/assets
# Epoch 27/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0368 - accuracy: 0.9874
#
# Epoch 00027: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-27
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-27/assets
# Epoch 28/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0370 - accuracy: 0.9875
#
# Epoch 00028: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-28
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-28/assets
# Epoch 29/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0339 - accuracy: 0.9892
#
# Epoch 00029: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-29
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-29/assets
# Epoch 30/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0351 - accuracy: 0.9879
#
# Epoch 00030: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-30
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-30/assets
# Epoch 31/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0333 - accuracy: 0.9893
#
# Epoch 00031: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-31
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-31/assets
# Epoch 32/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0331 - accuracy: 0.9891
#
# Epoch 00032: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-32
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-32/assets
# Epoch 33/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0337 - accuracy: 0.9892
#
# Epoch 00033: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-33
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-33/assets
# Epoch 34/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0329 - accuracy: 0.9891
#
# Epoch 00034: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-34
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-34/assets
# Epoch 35/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0330 - accuracy: 0.9888
#
# Epoch 00035: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-35
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-35/assets
# Epoch 36/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0318 - accuracy: 0.9898
#
# Epoch 00036: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-36
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-36/assets
# Epoch 37/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0321 - accuracy: 0.9895
#
# Epoch 00037: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-37
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-37/assets
# Epoch 38/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0292 - accuracy: 0.9904
#
# Epoch 00038: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-38
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-38/assets
# Epoch 39/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0313 - accuracy: 0.9896
#
# Epoch 00039: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-39
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-39/assets
# Epoch 40/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0286 - accuracy: 0.9907
#
# Epoch 00040: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-40
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-40/assets
# Epoch 41/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0302 - accuracy: 0.9903
#
# Epoch 00041: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-41
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-41/assets
# Epoch 42/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0281 - accuracy: 0.9908
#
# Epoch 00042: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-42
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-42/assets
# Epoch 43/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0289 - accuracy: 0.9901
#
# Epoch 00043: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-43
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-43/assets
# Epoch 44/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0265 - accuracy: 0.9914
#
# Epoch 00044: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-44
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-44/assets
# Epoch 45/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0273 - accuracy: 0.9910
#
# Epoch 00045: saving model to /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-45
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/sudden_drift_30000-45/assets
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0265 - accuracy: 0.9918
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0807 - accuracy: 0.9780

# %% [markdown]
# Experiment 3 - train full mnsit and 30k drift together

# %%
m3 = tf.keras.models.load_model(BASE_PATH + 'base_model')
train_model(m3, np.vstack((x_train, x_train_noisy[:30000])), np.vstack((y_train, y_train[:30000])), 'mnist_and_30k')
results = m3.evaluate(x_test, y_test)
results = m3.evaluate(x_test_noisy, y_test)
# Out:
# Epoch 1/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.8734 - accuracy: 0.7287
#
# Epoch 00001: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-01
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-01/assets
# Epoch 2/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.2316 - accuracy: 0.9282
#
# Epoch 00002: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-02
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-02/assets
# Epoch 3/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.1493 - accuracy: 0.9529
#
# Epoch 00003: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-03
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-03/assets
# Epoch 4/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.1144 - accuracy: 0.9641
#
# Epoch 00004: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-04
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-04/assets
# Epoch 5/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0939 - accuracy: 0.9706
#
# Epoch 00005: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-05
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-05/assets
# Epoch 6/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0821 - accuracy: 0.9744
#
# Epoch 00006: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-06
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-06/assets
# Epoch 7/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0734 - accuracy: 0.9775
#
# Epoch 00007: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-07
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-07/assets
# Epoch 8/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0637 - accuracy: 0.9803
#
# Epoch 00008: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-08
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-08/assets
# Epoch 9/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0580 - accuracy: 0.9814
#
# Epoch 00009: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-09
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-09/assets
# Epoch 10/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0546 - accuracy: 0.9826
#
# Epoch 00010: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-10
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-10/assets
# Epoch 11/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0495 - accuracy: 0.9849
#
# Epoch 00011: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-11
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-11/assets
# Epoch 12/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0456 - accuracy: 0.9853
#
# Epoch 00012: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-12
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-12/assets
# Epoch 13/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0443 - accuracy: 0.9860
#
# Epoch 00013: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-13
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-13/assets
# Epoch 14/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0425 - accuracy: 0.9860
#
# Epoch 00014: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-14
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-14/assets
# Epoch 15/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0404 - accuracy: 0.9868
#
# Epoch 00015: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-15
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-15/assets
# Epoch 16/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0357 - accuracy: 0.9887
#
# Epoch 00016: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-16
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-16/assets
# Epoch 17/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0357 - accuracy: 0.9883
#
# Epoch 00017: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-17
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-17/assets
# Epoch 18/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0353 - accuracy: 0.9888
#
# Epoch 00018: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-18
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-18/assets
# Epoch 19/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0314 - accuracy: 0.9897
#
# Epoch 00019: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-19
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-19/assets
# Epoch 20/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0311 - accuracy: 0.9901
#
# Epoch 00020: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-20
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-20/assets
# Epoch 21/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0299 - accuracy: 0.9907
#
# Epoch 00021: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-21
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-21/assets
# Epoch 22/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0296 - accuracy: 0.9907
#
# Epoch 00022: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-22
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-22/assets
# Epoch 23/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0283 - accuracy: 0.9910
#
# Epoch 00023: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-23
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-23/assets
# Epoch 24/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0278 - accuracy: 0.9908
#
# Epoch 00024: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-24
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-24/assets
# Epoch 25/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.0261 - accuracy: 0.9915
#
# Epoch 00025: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-25
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-25/assets
# Epoch 26/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0247 - accuracy: 0.9924
#
# Epoch 00026: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-26
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-26/assets
# Epoch 27/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0246 - accuracy: 0.9920
#
# Epoch 00027: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-27
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-27/assets
# Epoch 28/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0241 - accuracy: 0.9921
#
# Epoch 00028: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-28
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-28/assets
# Epoch 29/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0236 - accuracy: 0.9923
#
# Epoch 00029: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-29
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-29/assets
# Epoch 30/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0230 - accuracy: 0.9927
#
# Epoch 00030: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-30
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-30/assets
# Epoch 31/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0218 - accuracy: 0.9931
#
# Epoch 00031: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-31
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-31/assets
# Epoch 32/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.0213 - accuracy: 0.9931
#
# Epoch 00032: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-32
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-32/assets
# Epoch 33/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0207 - accuracy: 0.9934
#
# Epoch 00033: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-33
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-33/assets
# Epoch 34/45
# 1406/1406 [==============================] - 11s 8ms/step - loss: 0.0206 - accuracy: 0.9935
#
# Epoch 00034: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-34
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-34/assets
# Epoch 35/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.0196 - accuracy: 0.9936
#
# Epoch 00035: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-35
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-35/assets
# Epoch 36/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.0192 - accuracy: 0.9939
#
# Epoch 00036: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-36
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-36/assets
# Epoch 37/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0196 - accuracy: 0.9941
#
# Epoch 00037: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-37
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-37/assets
# Epoch 38/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0194 - accuracy: 0.9937
#
# Epoch 00038: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-38
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-38/assets
# Epoch 39/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0194 - accuracy: 0.9937
#
# Epoch 00039: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-39
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-39/assets
# Epoch 40/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.0183 - accuracy: 0.9941
#
# Epoch 00040: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-40
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-40/assets
# Epoch 41/45
# 1406/1406 [==============================] - 11s 7ms/step - loss: 0.0178 - accuracy: 0.9942
#
# Epoch 00041: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-41
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-41/assets
# Epoch 42/45
# 1406/1406 [==============================] - 11s 8ms/step - loss: 0.0177 - accuracy: 0.9944
#
# Epoch 00042: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-42
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-42/assets
# Epoch 43/45
# 1406/1406 [==============================] - 10s 7ms/step - loss: 0.0177 - accuracy: 0.9946
#
# Epoch 00043: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-43
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-43/assets
# Epoch 44/45
# 1406/1406 [==============================] - 11s 8ms/step - loss: 0.0185 - accuracy: 0.9938
#
# Epoch 00044: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-44
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-44/assets
# Epoch 45/45
# 1406/1406 [==============================] - 11s 8ms/step - loss: 0.0165 - accuracy: 0.9949
#
# Epoch 00045: saving model to /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-45
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/mnist_and_30k-45/assets
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9946
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0739 - accuracy: 0.9790

# %% [markdown]
# Experiment 4 - half mnist + 10k mixed data

# %%
k1 = tf.keras.models.load_model(BASE_PATH + 'base_model')
train_model(k1, x_train[:30000], y_train[:30000], '30k_normal')
results = k1.evaluate(x_test, y_test)
results = k1.evaluate(x_test_noisy, y_test)
# Out:
# Epoch 1/45
# 468/468 [==============================] - 4s 7ms/step - loss: 1.2525 - accuracy: 0.6096
#
# Epoch 00001: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-01
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-01/assets
# Epoch 2/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.3624 - accuracy: 0.8873
#
# Epoch 00002: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-02
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-02/assets
# Epoch 3/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.2217 - accuracy: 0.9328
#
# Epoch 00003: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-03
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-03/assets
# Epoch 4/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.1569 - accuracy: 0.9531
#
# Epoch 00004: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-04
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-04/assets
# Epoch 5/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.1280 - accuracy: 0.9620
#
# Epoch 00005: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-05
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-05/assets
# Epoch 6/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.1094 - accuracy: 0.9662
#
# Epoch 00006: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-06
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-06/assets
# Epoch 7/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0939 - accuracy: 0.9729
#
# Epoch 00007: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-07
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-07/assets
# Epoch 8/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0798 - accuracy: 0.9763
#
# Epoch 00008: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-08
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-08/assets
# Epoch 9/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0743 - accuracy: 0.9778
#
# Epoch 00009: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-09
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-09/assets
# Epoch 10/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0675 - accuracy: 0.9796
#
# Epoch 00010: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-10
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-10/assets
# Epoch 11/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0589 - accuracy: 0.9831
#
# Epoch 00011: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-11
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-11/assets
# Epoch 12/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0564 - accuracy: 0.9837
#
# Epoch 00012: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-12
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-12/assets
# Epoch 13/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0532 - accuracy: 0.9838
#
# Epoch 00013: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-13
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-13/assets
# Epoch 14/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0489 - accuracy: 0.9852
#
# Epoch 00014: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-14
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-14/assets
# Epoch 15/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0452 - accuracy: 0.9862
#
# Epoch 00015: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-15
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-15/assets
# Epoch 16/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0429 - accuracy: 0.9868
#
# Epoch 00016: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-16
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-16/assets
# Epoch 17/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0390 - accuracy: 0.9883
#
# Epoch 00017: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-17
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-17/assets
# Epoch 18/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0372 - accuracy: 0.9889
#
# Epoch 00018: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-18
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-18/assets
# Epoch 19/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0358 - accuracy: 0.9892
#
# Epoch 00019: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-19
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-19/assets
# Epoch 20/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0314 - accuracy: 0.9903
#
# Epoch 00020: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-20
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-20/assets
# Epoch 21/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0304 - accuracy: 0.9916
#
# Epoch 00021: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-21
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-21/assets
# Epoch 22/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0310 - accuracy: 0.9908
#
# Epoch 00022: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-22
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-22/assets
# Epoch 23/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0296 - accuracy: 0.9907
#
# Epoch 00023: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-23
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-23/assets
# Epoch 24/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0287 - accuracy: 0.9916
#
# Epoch 00024: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-24
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-24/assets
# Epoch 25/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0260 - accuracy: 0.9918
#
# Epoch 00025: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-25
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-25/assets
# Epoch 26/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0233 - accuracy: 0.9932
#
# Epoch 00026: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-26
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-26/assets
# Epoch 27/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0250 - accuracy: 0.9921
#
# Epoch 00027: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-27
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-27/assets
# Epoch 28/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0234 - accuracy: 0.9933
#
# Epoch 00028: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-28
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-28/assets
# Epoch 29/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0233 - accuracy: 0.9930
#
# Epoch 00029: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-29
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-29/assets
# Epoch 30/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0214 - accuracy: 0.9935
#
# Epoch 00030: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-30
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-30/assets
# Epoch 31/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0228 - accuracy: 0.9934
#
# Epoch 00031: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-31
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-31/assets
# Epoch 32/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0216 - accuracy: 0.9937
#
# Epoch 00032: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-32
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-32/assets
# Epoch 33/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0205 - accuracy: 0.9938
#
# Epoch 00033: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-33
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-33/assets
# Epoch 34/45
# 468/468 [==============================] - 3s 7ms/step - loss: 0.0194 - accuracy: 0.9945
#
# Epoch 00034: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-34
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-34/assets
# Epoch 35/45
# 468/468 [==============================] - 4s 7ms/step - loss: 0.0190 - accuracy: 0.9949
#
# Epoch 00035: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-35
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-35/assets
# Epoch 36/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0203 - accuracy: 0.9937
#
# Epoch 00036: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-36
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-36/assets
# Epoch 37/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0195 - accuracy: 0.9944
#
# Epoch 00037: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-37
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-37/assets
# Epoch 38/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0184 - accuracy: 0.9946
#
# Epoch 00038: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-38
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-38/assets
# Epoch 39/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0180 - accuracy: 0.9948
#
# Epoch 00039: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-39
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-39/assets
# Epoch 40/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0180 - accuracy: 0.9948
#
# Epoch 00040: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-40
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-40/assets
# Epoch 41/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0162 - accuracy: 0.9957
#
# Epoch 00041: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-41
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-41/assets
# Epoch 42/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0174 - accuracy: 0.9951
#
# Epoch 00042: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-42
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-42/assets
# Epoch 43/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0162 - accuracy: 0.9957
#
# Epoch 00043: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-43
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-43/assets
# Epoch 44/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0166 - accuracy: 0.9948
#
# Epoch 00044: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-44
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-44/assets
# Epoch 45/45
# 468/468 [==============================] - 4s 8ms/step - loss: 0.0165 - accuracy: 0.9952
#
# Epoch 00045: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal-45
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal-45/assets
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0204 - accuracy: 0.9939
# 313/313 [==============================] - 1s 3ms/step - loss: 7.1144 - accuracy: 0.1163

# %%
x_gc_train = np.vstack((x_train[30000:35000], x_train_noisy[:5000]))
y_gc_train = np.vstack((y_train[30000:35000], y_train[:5000]))

idx = [i for i in range(len(x_gc_train))]
np.random.shuffle(idx)

x_gc_train = x_gc_train[idx]
y_gc_train = y_gc_train[idx]

x_gc_train.shape
y_gc_train.shape
# Out:
# (10000, 10)

# %%
train_model(k1, x_gc_train, y_gc_train, '30k_normal_added_10k_mix')
results = k1.evaluate(x_test, y_test)
results = k1.evaluate(x_test_noisy, y_test)
# Out:
# Epoch 1/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.2115 - accuracy: 0.9365
#
# Epoch 00001: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-01
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-01/assets
# Epoch 2/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.1164 - accuracy: 0.9631
#
# Epoch 00002: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-02
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-02/assets
# Epoch 3/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0993 - accuracy: 0.9669
#
# Epoch 00003: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-03
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-03/assets
# Epoch 4/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0897 - accuracy: 0.9710
#
# Epoch 00004: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-04
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-04/assets
# Epoch 5/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0732 - accuracy: 0.9760
#
# Epoch 00005: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-05
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-05/assets
# Epoch 6/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0677 - accuracy: 0.9772
#
# Epoch 00006: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-06
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-06/assets
# Epoch 7/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0624 - accuracy: 0.9804
#
# Epoch 00007: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-07
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-07/assets
# Epoch 8/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0595 - accuracy: 0.9819
#
# Epoch 00008: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-08
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-08/assets
# Epoch 9/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0492 - accuracy: 0.9834
#
# Epoch 00009: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-09
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-09/assets
# Epoch 10/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0513 - accuracy: 0.9843
#
# Epoch 00010: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-10
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-10/assets
# Epoch 11/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0518 - accuracy: 0.9827
#
# Epoch 00011: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-11
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-11/assets
# Epoch 12/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0514 - accuracy: 0.9832
#
# Epoch 00012: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-12
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-12/assets
# Epoch 13/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0404 - accuracy: 0.9877
#
# Epoch 00013: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-13
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-13/assets
# Epoch 14/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0406 - accuracy: 0.9867
#
# Epoch 00014: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-14
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-14/assets
# Epoch 15/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0392 - accuracy: 0.9871
#
# Epoch 00015: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-15
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-15/assets
# Epoch 16/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0375 - accuracy: 0.9874
#
# Epoch 00016: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-16
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-16/assets
# Epoch 17/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0368 - accuracy: 0.9881
#
# Epoch 00017: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-17
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-17/assets
# Epoch 18/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0345 - accuracy: 0.9891
#
# Epoch 00018: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-18
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-18/assets
# Epoch 19/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0333 - accuracy: 0.9893
#
# Epoch 00019: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-19
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-19/assets
# Epoch 20/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0301 - accuracy: 0.9909
#
# Epoch 00020: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-20
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-20/assets
# Epoch 21/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0301 - accuracy: 0.9899
#
# Epoch 00021: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-21
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-21/assets
# Epoch 22/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0277 - accuracy: 0.9916
#
# Epoch 00022: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-22
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-22/assets
# Epoch 23/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0313 - accuracy: 0.9901
#
# Epoch 00023: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-23
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-23/assets
# Epoch 24/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0269 - accuracy: 0.9926
#
# Epoch 00024: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-24
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-24/assets
# Epoch 25/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0295 - accuracy: 0.9905
#
# Epoch 00025: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-25
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-25/assets
# Epoch 26/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0263 - accuracy: 0.9924
#
# Epoch 00026: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-26
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-26/assets
# Epoch 27/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0276 - accuracy: 0.9919
#
# Epoch 00027: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-27
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-27/assets
# Epoch 28/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0257 - accuracy: 0.9927
#
# Epoch 00028: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-28
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-28/assets
# Epoch 29/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0256 - accuracy: 0.9925
#
# Epoch 00029: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-29
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-29/assets
# Epoch 30/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0259 - accuracy: 0.9927
#
# Epoch 00030: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-30
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-30/assets
# Epoch 31/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0259 - accuracy: 0.9929
#
# Epoch 00031: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-31
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-31/assets
# Epoch 32/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0212 - accuracy: 0.9945
#
# Epoch 00032: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-32
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-32/assets
# Epoch 33/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0231 - accuracy: 0.9932
#
# Epoch 00033: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-33
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-33/assets
# Epoch 34/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0228 - accuracy: 0.9934
#
# Epoch 00034: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-34
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-34/assets
# Epoch 35/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0217 - accuracy: 0.9940
#
# Epoch 00035: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-35
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-35/assets
# Epoch 36/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0206 - accuracy: 0.9941
#
# Epoch 00036: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-36
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-36/assets
# Epoch 37/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0199 - accuracy: 0.9944
#
# Epoch 00037: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-37
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-37/assets
# Epoch 38/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0223 - accuracy: 0.9933
#
# Epoch 00038: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-38
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-38/assets
# Epoch 39/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0198 - accuracy: 0.9945
#
# Epoch 00039: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-39
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-39/assets
# Epoch 40/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0203 - accuracy: 0.9948
#
# Epoch 00040: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-40
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-40/assets
# Epoch 41/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0204 - accuracy: 0.9943
#
# Epoch 00041: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-41
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-41/assets
# Epoch 42/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0235 - accuracy: 0.9930
#
# Epoch 00042: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-42
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-42/assets
# Epoch 43/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0215 - accuracy: 0.9937
#
# Epoch 00043: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-43
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-43/assets
# Epoch 44/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0220 - accuracy: 0.9946
#
# Epoch 00044: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-44
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-44/assets
# Epoch 45/45
# 156/156 [==============================] - 1s 8ms/step - loss: 0.0193 - accuracy: 0.9941
#
# Epoch 00045: saving model to /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-45
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/30k_normal_added_10k_mix-45/assets
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0267 - accuracy: 0.9919
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1049 - accuracy: 0.9720
